# %% [markdown]
# ### Nearest link detection

# %%
import lxml.html as LH
import itertools

def find_nearest(elt):
    preceding = elt.xpath('preceding::*/@href')[::-1]
    
    
    el2 = doc.xpath("/html/body//a[contains(@href,'edf')]/@href")
    here = el2
    print('HERE -> {}'.format(here))
    following = elt.xpath('following::*/@href')
    parent = elt.xpath('parent::*/@href')

    for href in roundrobin(parent, preceding, following):
        return href

def roundrobin(*iterables):
    "roundrobin('ABC', 'D', 'EF') --> A D E B F C"
    # http://docs.python.org/library/itertools.html#recipes
    # Author: George Sakkis
    pending = len(iterables)
    nexts = itertools.cycle(iter(it).__next__ for it in iterables)
    while pending:
        try:
            for n in nexts:
                yield n()
        except StopIteration:
            pending -= 1
            nexts = itertools.cycle(itertools.islice(nexts, pending))

to_find = "risque de correction sous"
doc = LH.fromstring(tekst)

for x in doc.xpath('//*[contains(text(),{s!r})]'.format(s = to_find)):
    print(find_nearest(x))
# Out:
# HERE -> ['/actions/actualites/news/edf-risque-de-correction-sous-les-resistances-at-756851.html']
# /opcvm/actualites/generales/ag2r-la-mondiale-recompense-pour-sa-strategie-d-investissement-dans-les-pme-et-les-eti-811464.html

# %% [markdown]
# #### Find nearest II

# %%
import lxml.html as LH
import itertools

def find_nearest(elt):
    preceding = elt.xpath('preceding::*/@href')[::-1]
    
    
    el2 = doc.xpath("/html/body//a[contains(@href,'EDF')]/@href")
    here = el2
    #print('HERE -> {}'.format(here))
    current = None
    
    following = elt.xpath('following::*/@href')
    parent = elt.xpath('parent::*/@href')
    current = elt.xpath('@href')

    print('*'*50 + '\n')
    print('\npreceding : {}\n\ncurrent : {}\n\nfollowing : {}\nparent : {}'.format(preceding, current, following, parent))
    if current is not None:
        return current
    else:
        for href in roundrobin(parent, preceding, following):
            return href

def roundrobin(*iterables):
    "roundrobin('ABC', 'D', 'EF') --> A D E B F C"
    # http://docs.python.org/library/itertools.html#recipes
    # Author: George Sakkis
    pending = len(iterables)
    nexts = itertools.cycle(iter(it).__next__ for it in iterables)
    while pending:
        try:
            for n in nexts:
                yield n()
        except StopIteration:
            pending -= 1
            nexts = itertools.cycle(itertools.islice(nexts, pending))


to_find = "EDF"
doc = LH.fromstring(tekst)

for x in doc.xpath('//*[contains(text(),{s!r})]'.format(s = to_find)):
    print('find nearest = {}'.format(find_nearest(x)))
# Out:
# **************************************************
#
#
# ...

# %%
tekst = '''
<!DOCTYPE html>
<html lang="fr" class="">
<head>
	<!-- 59 -->
	<meta charset="utf-8">
		<meta name="viewport" content="width=device-width, initial-scale=1.0, user-scalable=0" />
		<meta name="HandheldFriendly" content="true">
		<script> var isResponsive = true; </script>
	<meta name="apple-itunes-app" content="app-id=325643675, affiliate-data=affId=1194513">
	<meta http-equiv="content-language" content="fr">
	<meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">
	<meta name="theme-color" content="#35424f" />
	<meta name="robots" content="max-snippet:-1, max-image-preview:large, max-video-preview:-1">
	<meta name="twitter:dnt" content="on">

	<title>News Bourse du 17/12/2019</title>
	<script type="text/javascript">
		window.baseDomain = 'https://www.boursier.com';
		window.ssoKeys = { "FB": '396473187066093', "LI": '772sq6ivh22rxn', "TW" : 'AIhzceHmPiDqWdCwo2vcA' };
	</script>

	<!-- Styles -->
	
	<link href="/Content/css?v=r9j3_6At2qCxemY8tp4wNZEVxKd77NzorXp-2LEUKGk1" rel="stylesheet"/>


	<link rel="search" type="application/opensearchdescription+xml" href="/syndication/recherche" title="Boursier.com" />
	<link rel="shortcut icon" href="/favicon.ico" />
	<link rel="image_src" href="/Content/img/logo.png" />

		<link rel="stylesheet" href="/ui/css/global.css?637078480600000000" />
		<link rel="stylesheet" href="/ui/css/quizz-resultats.css?636849714920000000" />
		<link href="/UI/css/colorbox.css" rel="stylesheet" type="text/css" />
		<link href="/ui/css/modal.css?636849714920000000" rel="stylesheet" type="text/css" />
<link href="/Content/migrate?v=-61F0tCSUnAmbO0Oy57tgQ05wbHcj2k5_V__SdG3UOE1" rel="stylesheet"/>
	<!-- V5 -->
	<link href="/UI/v5/bundle?v=AYiTpHDfhjr1SdewF-Tq1j50OELllyEGx2AWlJkjOFQ1" rel="stylesheet"/>

	<!-- V5 -->

	<!-- Scripts -->
	<script src="/bundles/jquery?v=s6LHZm33GCIH8eutynJ9FM_yTzIbKEVHC3z-sBRx1uI1"></script>

	<script src="/bundles/Bootstrap/js?v=RKZehS2z70rY7zIJ8lfj7V4jT1pO4Segdbwy8N5DHBo1"></script>

	<script src="/Scripts/js?v=va5gbMDNxfYvV40C3PTOiFCZyL6mNF6IKAzSgRQhWtY1"></script>

	<!-- Le HTML5 shim, for IE6-8 support of HTML5 elements -->
<!--[if lt IE 9]>
	<script src="/scripts/html5shiv.js"></script>
<![endif]-->

<!--[if lt IE 9]><script type="text/javascript">$('html').addClass('BIE9'); </script><![endif]-->
<!--[if IE 8]><script type="text/javascript">$('html').addClass('IE8'); </script><![endif]-->
<!--[if IE 7]><script type="text/javascript">$('html').addClass('IE7'); </script><![endif]-->

	<meta name="description" content="Retrouvez toutes les actualit&#233;s boursi&#232;res et &#233;conomiques sur la France, les Etats-Unis, et l&#39;Europe" />
<script type="text/javascript"> Boursier.html.applyRefresh(240); </script>
	
	
	



	<script type="text/javascript">
		(function (h) { h.className = h.className.replace('no-', '') })(document.documentElement);
	</script>
	<!-- tag Analytics -->
	
<script type="text/javascript">
<!--

	function __tcvarsCreate() {
		//TC Declared Variables
		var tc_vars = {};

	
		tc_vars.content_id = '';
		tc_vars.custom1 = '';
		tc_vars.custom2 = '';
		tc_vars.custom3 = 'General';
		tc_vars.custom4 = '';
		tc_vars.custom5 = '';
		tc_vars.custom6 = '';
		tc_vars.error = '200';
		tc_vars.search_page = 'news-du-jour';
		tc_vars.content_level1 = 'ArticlesList';
		tc_vars.content_level2 = '';
		tc_vars.content_label = '';
		tc_vars.content_class = 'news-du-jour';
	

		return tc_vars;
	}


	//-->
</script>

	<script src="//cdn-static.boursier.com/e/di/cmp.js?20191217"></script>
<!-- Begin tagcommander  -->
<script type="didomi/javascript" src="//cdn-static.boursier.com/e/tc/a_boursier.js?20191217" async></script>
<!--  end tagcommander -->
<link rel="manifest" href="/manifest.json">
<!-- OneSignal - All --><script type="didomi/javascript" src="https://cdn.onesignal.com/sdks/OneSignalSDK.js" data-vendor="c:onesignal-4VMWFzzM" async></script><script>
  var OneSignal = window.OneSignal || [];
  OneSignal.push(function() {
    OneSignal.init({
      appId: "fa400081-63b8-4a86-82e4-d572ffbb20f8",
    });
  });
</script><!-- AB Tasty - Boursier --><script type="didomi/javascript" data-vendor="c:ab-tasty">
               (function (i, s, o, g, r, a, m) {
               i[r] = i[r] || [], i["abtiming"] = 1 * new Date();
               a = s.createElement(o),
               m = s.getElementsByTagName(o)[0]; a.async = 1; a.src = g; m.parentNode.insertBefore(a, m)
               })(window, document, "script", "//try.abtasty.com/5f299eba7ea5694e0ffd74138f01004a.js", "_abtasty");
</script>

</head>

<body id="content">
	<div class="admin" id="home-link-admin" data-ajax-href="/ajax/master/administration"></div>
	<div id="modal-message" data-ajax-href="/ajax/master/popinmessage"></div>

	<div class="search-overlay" id="search-overlay"></div>
	<div class="connection-overlay" id="connection-overlay"></div>

	
	


<div id="overall">

	<div data-id="infos-boursier_panel" id="infos-boursier_panel" class="init stuck">
		
		<div class="bg">
			<div id="headerblock" class="dyn" data-ajax-href="/navigation/header" data-ajax-success="initSlider"></div>
		</div>
	</div>

	<header data-id="header" class="page-head">
		<!-- Top -->
		<div id="logo-user_tools">
			<div class="wrapper">
				<span class="ico-burger toggle-button" data-toggle-element="#main-menu #infos-boursier_panel #form-search.visible .sub-menu--connected__wrapper.visible .ico-burger #user_menu.visible" data-toggle-class="visible">
					<span></span>
				</span>
				<div class="logo">
					<a href="/" title="Actualité financière – Cours de Bourse en temps réel, Conseils – Boursier.com">
							<span>Boursier</span>
					</a>
				</div>

				<span class="search-toggle toggle-button" data-toggle-element="#form-search .sub-menu--connected__wrapper.visible #user_menu.visible" data-toggle-class="visible">
					<span class="icon2016-search"></span>
				</span>

				<form action="/recherche/synthese" method="post" id="form-search">
					
					<input type="text" class="form-text" name="q" required>
					<button type="submit" name="sa" class="icon2016-search" value="&nbsp;"></button>
					<input name="cx" type="hidden" value="008493178372379324166:oczdasvhbii">
				</form>
				<!-- connecté / déconnecté -->

				<div id="box-connection" data-ajax-href="/user/connection" data-ajax-success="BC.AJAX.initHeaderConnection"></div>

			</div><!-- /wrapper -->
		</div><!-- /Top -->
		<!-- /m-infos -->
		<div class="sub-menu--connected__wrapper">
			<div class="wrapper">
				<nav role="navigation">
					<ul class="sub-menu--connected__list">
						<li class="sub-menu--connected__list-item"><a href="/membres/mes-infos/coordonnees" rel="nofollow">Mes infos</a></li>
						<li class="sub-menu--connected__list-item hidedesktop"><a href="/membres/listes/consulter/">Mes listes</a></li>
						<li class="sub-menu--connected__list-item hidedesktop"><a href="/membres/portefeuilles/consulter/">Mes portefeuilles</a></li>
						<li class="sub-menu--connected__list-item"><a href="/membres/mes-infos/profil" rel="nofollow">Mon profil forum</a></li>
						<li class="sub-menu--connected__list-item"><a href="/membres/mes-infos/newsletters" rel="nofollow">Mes newsletters</a></li>
						<li class="sub-menu--connected__list-item">
							<a class="btn-more premium" href="/membres/abonnement?utm_source=boursier&amp;utm_medium=boutonmenuprofil&amp;utm_campaign=privileges" target="_blank" rel="nofollow">
								<span class="bt-label">M'abonner aux conseils Privilèges</span>
							</a>
						</li>
						<li class="sub-menu--connected__list-item">
							<a onclick="return confirm('Etes-vous sûr de vouloir vous déconnecter ?')" href="/membres/inscription/deconnexion">D&eacute;connexion</a>
						</li>
					</ul>

					<span class="toggle-button toggle-on-scroll icon2016 icon2016-close" data-toggle-element=".sub-menu--connected__wrapper" data-toggle-class="visible"></span>
				</nav>
			</div>
		</div>

		<!-- Menu -->




<div id="main-menu">
	<ul id="burger-menu" class="toggle-desktop toggleit vertical menu modern" data-pane-index="0">
		<li class="burger-menu__item accueil">
			
			<a href="/" class="main-menu accueil">
				Accueil
			</a>
		</li>

		<li class="burger-menu__item cotations">
			<a class="main-menu">
				Bourse
			</a>
			<ul class="vertical menu ssmenus-secondary">
				<li class="ssmenu__title--secondary">
					<a class="secondary-link">Cours de A à Z</a>
					<ul class="vertical menu">
						<li><a href="/actions/paris?marketId=99">Paris - SRD</a></li>
						<li><a href="/actions/paris?marketId=-1&amp;indexId=39991">Paris - CAC40</a></li>
						<li><a href="/actions/paris?marketId=8">Paris - Euronext Growth</a></li>
						<li><a href="/actions/paris?marketId=9">Paris - Euronext Access</a></li>
						<li><a href="/actions/new-york">New York</a></li>
						<li><span class="gothere L1f4a42cb464f49c21f41c1c3c543484843c2 ">Bruxelles</span></li>
						<li><span class="gothere L1f4a42cb464f49c21f4a4ec2cb43c14b4a4e ">Amsterdam</span></li>
					</ul>
				</li>
				<li class="ssmenu__title--secondary">
					<a class="secondary-link">Palmarès</a>

					<ul class="vertical menu">
						<li><a href="/palmares/paris">Paris</a></li>
						<li><span class="gothere L1fc04a484e4ac143c21f4943cc1ec64fc147 ">New York</span></li>
						<li><span class="gothere L1fc04a484e4ac143c21f41c1c3c543484843c2 ">Bruxelles</span></li>
						<li><span class="gothere L1fc04a484e4ac143c21f4a4ec2cb43c14b4a4e ">Amsterdam</span></li>
						<li><span class="gothere L1f4a42cb464f49c21f44c14a4942431e424fcb4343c21ecc4a48481ec2cbc14343cb ">Fran&#231;aises &#224; New York</span></li>
					</ul>
				</li>
				<li class="ssmenu__title--secondary">
					<a class="secondary-link">Le coin du Trader</a>
					<ul class="vertical menu">
						<li><span class="gothere L1fc04a484e4ac143c21fc44f48c34e43c21e4a494fc14e4ac3c5 ">Volumes anormaux</span></li>
						<li><span class="gothere L1fc04a484e4ac143c21fc44a4843c3c1c21e4843c21ec048c3c21e4342454a494c4343c2 ">Volumes importants</span></li>
					</ul>
				</li>
				<li class="ssmenu__title--secondary">
					<a class="secondary-link">Cotations</a>
					<ul class="vertical menu">
						<li><a href="/indices">Indices</a></li>
						<li><a href="/devises">Devises</a></li>
					</ul>
				</li>
				<li class="ssmenu__title--secondary">
					<a class="secondary-link">Matières Premières</a>
					<ul class="vertical menu">
						<li><span class="gothere L1f4e4acb4643c143c21ec0c1434e4643c143c21f424fc3c1c21f41c14349cb1e35b220202026242c2c2b202618bcb11945cb4e48 ">Brent</span></li>
						<li><span class="gothere L1f4e4acb4643c143c21ec0c1434e4643c143c21f424fc3c1c21f4f4942431e4b1e4fc11e35b2202020262423232a232c18b2b51945cb4e48 ">Once d&#39;Or</span></li>
					</ul>
				</li>
				<li class="ssmenu__title--secondary">
					<a class="secondary-link">Vidéos</a>
                    <ul class="vertical menu">
                        <li><a href="/videos/marches">Point des march&#233;s</a></li>
                        <li><a href="/videos/podcasts-europe1-bourse">Podcasts Europe1 Bourse</a></li>
                        <li><a href="/videos/market-live-ig">Market Live IG</a></li>
                        
                        <li><a href="/videos/bnp-paribas-easy">BNP Paribas Easy</a></li>
                    </ul>
				</li>
			</ul>
		</li>

		<li class="burger-menu__
a>
					<ul class="vertical menu">
						<li><span class="gothere L1f4cc3464b43 toe">Accueil</span></li>
						<li><span class="gothere L1f4cc3464b431f4b4341c3cb43c11e43491e414fc3c1c243 toe">Novice</span></li>
						<li><span class="gothere L1f4cc3464b431fc2431ec043c1444342cb464f494943c11e43491e414fc3c1c243 toe">Avanc&#233;</span></li>
						<li><span class="gothere L1f4cc3464b431f4b43c4434946c11ecbc14a4b43c11e43491e414fc3c1c243 toe">Expert</span></li>
						<li><span class="gothere L1f4cc3464b431fcb43484342454ac14c434e4349cb toe">Guides Bourse Gratuits</span></li>
					</ul>
				</li>
			</ul>
		</li>

		<li class="burger-menu__item forums">
			<a class="main-menu">
				Forum
			</a>
			<ul class="vertical menu ssmenus-secondary">
				<li class="ssmenu__title--secondary">
					<a class="secondary-link" data-index="0">Réactions sur...</a>
					<ul class="vertical menu">
						<li><span class="gothere L1f444fc1c34e ">Toute l&#39;actualit&#233;</span></li>
						<li><span class="gothere L1f444fc1c34e1f4a42cbc34a4846cb43c21f414fc3c1c243 ">Bourse, Finance</span></li>
						<li><span class="gothere L1f444fc1c34e1f4a42cbc34a4846cb43c21f4c434943c14a4843c2 ">Actualit&#233; G&#233;n&#233;rale</span></li>
						<li><span class="gothere L1f444fc1c34e1f4a42cbc34a4846cb43c21f43424f494f4e4643 ">Economie</span></li>
						<li><span class="gothere L1f444fc1c34e1f4a42cbc34a4846cb43c21f4649cb43c1c44643ccc2 ">Interviews</span></li>
					</ul>
				</li>

				<li class="ssmenu__title--secondary">
					<a class="secondary-link" data-index="1">Thématiques</a>

					<ul class="vertical menu">
						<li><span class="gothere L1f444fc1c34e1fcb45434e4acb46cac3431f4a494a48c6c2431ecb4342454946cac343 ">Analyse Technique</span></li>
						<li><span class="gothere L1f444fc1c34e1fcb45434e4acb46cac3431f4649cbc14f4bc342cb464f491e414fc3c1c243 ">Introductions en Bourse</span></li>
						<li><span class="gothere L1f444fc1c34e1fcb45434e4acb46cac3431f4b4341c3cb43c1 ">D&#233;butant en Bourse</span></li>
						<li><span class="gothere L1f444fc1c34e1fcb45434e4acb46cac3431f43424f494f4e4643 ">Economie</span></li>
						<li><span class="gothere L1f444fc1c34e1fcb45434e4acb46cac3431f464e4e4f4146484643c11ec0484a42434e4349cb ">Immobilier, Patrimoine, OPCVM</span></li>
						<li><span class="gothere L1f444fc1c34e1fcb45434e4acb46cac3431f4146c2cbc14fcb ">Le Bistrot du Boursier</span></li>
					</ul>
				</li>

				<li class="ssmenu__title--secondary">
					<a class="secondary-link" data-index="0">Sujets les plus commentés</a>

					<ul class="vertical menu">
							<li><span class="gothere L1f444fc1c34e1f4a42cbc34a4846cb43c21f4c434943c14a4843c21f41c143c546cb1e46481e491ec61e4a1ec048c3c21e4b431ec2461e49461e4b431e4e4a46c21e4b46cb1e4d4f4549c24f491e4621262b252c211945cb4e48">Brexit: &quot;Il n&#39;y a plus de &#39;si&#39; ni de &#39;mais&#39;&quot;, dit Johnson <span class="icon2016-comment-1">88</span></span></li>
							<li><span class="gothere ">Services publics : 1 Fran&#231;ais sur 2 pr&#234;t &#224; payer plus d&#39;imp&#244;ts pour am&#233;liorer les prestations <span class="icon2016-comment-1">66</span></span></li>
							<li><span class="gothere L1f444fc1c34e1f4a42cbc34a4846cb43c21f4c434943c14a4843c21fc44642cb4f46c1431e4342c14ac24a49cb431e4b43c21e424f49c243c1c44acb43c3c1c21ec3491e4e4a494b4acb1e4546c2cb4fc146cac3431ec04fc3c11e48431e41c143c546cb1e4b46cb1e4d4f4549c24f491e4621262b2523241945cb4e48">Victoire &#233;crasante des conservateurs, un mandat &quot;historique&quot; pour le Brexit, dit Johnson <span class="icon2016-comment-1">59</span></span></li>
							<li><span class="gothere L1f444fc1c34e1f4a42cbc34a4846cb43c21f4c434943c14a4843c21fc04ac21e4b431ecbc143c4431e4b431e484a1e4cc143c4431e4a1e494f43481e4a1e42431ec2cb4a4b431e4b46cb1e484a1e424ccb1e4245434e46494fcbc21e4621262b25212b1945cb4e48">Pas de tr&#234;ve de la gr&#232;ve &#224; No&#235;l &#224; ce stade, dit la CGT-Cheminots <span class="icon2016-comment-1">51</span></span></li>
					</ul>
				</li>
				<li class="ssmenu__title--secondary">

					<a class="secondary-link" data-index="0">Valeurs actives</a>

					<ul class="vertical menu">
							<li>
								<span class="gothere L1f4a42cb464f49c21f444fc1c34e1fc44f48cb4a48464a1eb43120202a2a26262323252518b4311945cb4e48 ">Voltalia</span>
							</li>
							<li>
								<span class="gothere L1f4a42cb464f49c21f444fc1c34e1f43494c46431e43c51e4c4b441ec2c343cd1eb43120202a202120252b252518b4311945cb4e48 ">Engie (EX GDF SUEZ)</span>
							</li>
							<li>
								<span class="gothere L1f4a42cb464f49c21f444fc1c34e1f424a421e2b201eb4312020202223202020202518b4311945cb4e48 ">CAC 40</span>
							</li>
							<li>
								<span class="gothere L1f4a42cb464f49c21f444fc1c34e1f43c3c14fc0484ac24e4a1eb43120202020202b2b252a2018b4311945cb4e48 ">Europlasma</span>
							</li>
							<li>
								<span class="gothere L1f4a42cb464f49c21f444fc1c34e1f4a46c141c3c21e4cc14fc3c01e43c51e434a4bc21eb9b8202020202122232a262018b4311945cb4e48 ">Airbus Group (ex-EADS)</span>
							</li>
							<li>
								<span class="gothere L1f4a42cb464f49c21f444fc1c34e1f4e43cb454a494fc11eb43120202a2a212a2c2c2a2018b4311945cb4e48 ">M&#233;thanor</span>
							</li>
							<li>
								<span class="gothere L1f4a42cb464f49c21f444fc1c34e1f4ac142454fc21eb431202020202a25212b2c2618b4311945cb4e48 ">Archos</span>
							</li>
					</ul>
				</li>
			</ul>
		</li>

		<li class="burger-menu__item privileges">
			<a class="premium main-menu" data-index="0">Privilèges</a>
			<ul class="vertical menu ssmenus-secondary">
				<li class="ssmenu__title--secondary">
					<a class="secondary-link" data-index="1">Articles</a>

					<ul class="vertical menu">
						<li><span class="gothere L1fc0c146c44648434c43c2 ">Accueil Privil&#232;ges</span></li>
						<li><span class="gothere L1fc0c146c44648434c43c21f424f49c2434648c21fc143424f1e4bc31e4d4fc3c11f2a ">La Reco du Jour</span></li>
						<li><span class="gothere L1fc0c146c44648434c43c21f424f49c2434648c21f4a42cb464f49c21f2a ">Conseils Actions</span></li>
						<li><span class="gothere L1fc0c146c44648434c43c21f4649444fc14e4acb464f49c21f43c54248c3c246c443c21f2a ">Infos Exclusives</span></li>

					</ul>
				</li>

				<li class="ssmenu__title--secondary">
					<a class="secondary-link" data-index="2">Opportunités</a>


					<ul class="vertical menu">
						<li class="mag-premium">
							<span class="gothere L1fc0c146c44648434c43c21f4b4fcc49484f4a4b1f4fc0c04fc1cbc34946cb43c21f484ac2cb1fc04b44">N°1219 - le 10/12/2019</span>
							<img alt="Lettre Opportunités Bourse" src="/UI/v5/images/core/menu-premium_mag-cover.png" />
							<span class="gothere L1fc0c146c44648434c43c21f4b4fcc49484f4a4b1f4fc0c04fc1cbc34946cb43c21f484ac2cb1fc04b44 btn-more premium">
								<span class="bt-label">Télécharger</span>
							</span>
						</li>
					</ul>
				</li>

				<li class="ssmenu__title--secondary">
					<a class="secondary-link" data-index="3">Portefeuilles</a>

					<ul class="vertical menu">
						<li class="portfolio">
										<span class="gothere L1fc0c146c44648434c43c21fc04fc1cb434443c346484843c21f4b43444349c24644">
				<span class="indice-title">
					Perf. depuis le 10/11/1991
				</span>
				<strong class="indice-box">
					<span class="s-btn iconm-defensif">
						D&#233;fensif
						<b class="up">+413,75%</b>
					</span>
					<span class="indice">Indice CAC 40 <span class="up">+249,22%</span></span>
				</strong>
			</span>

										<span class="gothere L1fc0c146c44648434c43c21fc04fc1cb434443c346484843c21f43cac346484641c143">
				<span class="indice-title">
					Perf. depuis le 30/06/2001
				</span>
				<strong class="indice-box">
					<span class="s-btn iconm-equilibre">
						Equilibr&#233;
						<b class="up">+226,81%</b>
					</span>
					<span class="indice">Indice CAC 40 <span class="up">+8,78%</span></span>
				</strong>
			</span>

										<span class="gothere L1fc0c146c44648434c43c21fc04fc1cb434443c346484843c21f4bc6494a4e46cac343">
				<span class="indice-title">
					Perf. depuis le 02/12/2015
				</span>
				<strong class="indice-box">
					<span class="s-btn iconm-dynamique">
						Dynamique
						<b class="up">+20,48%</b>
					</span>
					<span class="indice">Indice CAC 40 <span class="up">+21,15%</span></span>
				</strong>
			</span>


							<span class="btn-more premium gothere L1fc0c146c44648434c43c21fc04fc1cb434443c346484843c2">
								<span class="bt-label">Découvrez nos 3 portefeuilles</span>
								<span class="bt-icon icon2016-right-small"></span>
							</span>
						</li>
					</ul>
				</li>
				<li class="ssmenu__title--secondary shortlist-donnees">
					<a class="secondary-link" data-index="0">données boursières</a>

					<ul class="vertical menu">
						<li>
							<a class="secondary-link" data-index="1">Données boursières</a>

							<ul class="vertical menu">
								<li><span class="gothere L1fc0c146c44648434c43c21f4649444fc14e4acb464f49c21f4a42454acbc21e4649c2464b43c1c21f2a ">Achats des Insiders</span></li>
								<li><span class="gothere L1fc0c146c44648434c43c21f4649444fc14e4acb464f49c21fc44a4843c3c1c21e4fc0434a414843c2 ">Valeurs Op&#233;ables</span></li>
							</ul>
						</li>
					</ul>
				</li>
			</ul>
		</li>
	</ul>

	<span class="btn-close icon2016-close" id="close-menu"></span>
</div>

		<script>
			(function () {
				var active = "actualites";
				$("#burger-menu li[class~=" + active + "] a").addClass("on");
			})();
		</script>
		<!-- /Menu -->

		<div class="quick-menu toggle-desktop">
			<a data-target="highlight" class="active">A la une</a>
			<a data-target="live">Fil info</a>
			<a data-target="mychoice">Listes/PF</a>
			<a data-target="privileges">Privileges</a>
		</div>

	</header><!-- /Header -->

		<div id="banner-wrapper">
			<div id="banner">
				<div>
					<!-- Generic > Mega Bannière --><div id="ad-anx-banner">
</div>
				</div>
			</div><!-- /.banner -->
		</div><!-- /#banner-wrapper -->

	<!-- barre d'indices [ a mettre "V5/_LayoutHeaderMarket" ] -->
	
	<!-- Contenu de la page -->

			<!-- breadcrumb -->
			<div id="date-breadcrumb">
                <div class="wrapper">

                    <div class="siteMapPath" itemscope itemtype="http://schema.org/BreadcrumbList"><div itemprop="itemListElement" itemscope itemtype="http://schema.org/ListItem"><a href="https://www.boursier.com/" itemprop="item" title="Retour à l&#39;accueil"><span itemprop="name">Accueil</span></a><meta content="1" itemprop="position" /></div> &raquo <div itemprop="itemListElement" itemscope itemtype="http://schema.org/ListItem"><span itemprop="name">Actualit&#233;s</span><meta content="2" itemprop="position" /><link href="https://www.boursier.com/actualites/news-du-jour" itemprop="item" /></div></div>
                </div>
			</div><!-- fin breadcrumb -->

	 





	<section class="palmares-bourse">
		<div class="wrapper">

					<h1>Actualit&#233;s du mardi 17 d&#233;cembre 2019</h1>



		</div>
	</section>




	<section class="grid-12">

		<div class="wrapper">
			<div class="row">
				<div class="col col-8 medium-12">
					
	
	<div class="agenda-news">
		<p>
			Les actualités Bourse, économie, finance et patrimoine avec le fil info de Boursier.com. Retrouvez en un coup d'oeil toutes les actualités des sociétés cotées, les avis des analystes financiers ou encore les meilleurs conseils boursiers de la rédaction publiés le <strong>mardi 17 décembre 2019</strong>.
		</p>
		<div id="menu-agenda_news">
			<p class="label">Accéder aux actualités du</p>
			<div class="styled styled-gray"></div>		
		</div>
	</div>

	

<div class="news-list" id="listing">
	
		 <div class="items">
				<div class="item "><time class="date" datetime="2019-12-17T14:13:00">14h13</time><div class="data"><a  href="/actions/actualites/news/lagardere-voit-rouge-811495.html" class=""><b>Lagardère</b> : voit rouge</a></div></div>
					<div class="item "><time class="date" datetime="2019-12-17
img alt="Small&Mid Cap" class="icon partner-icon" src="/Content/img/ico-snmd.png" /></a></div></div>
					<div class="item "><time class="date" datetime="2019-12-17T09:16:00">09h16</time><div class="data"><a  href="/actions/actualites/news/airbus-grimpe-apres-la-suspension-de-la-production-du-737-max-de-boeing-811466.html" class=""><b>Airbus</b> grimpe après la suspension de la production du 737 MAX de Boeing <span class="icon2016-comment-1">1</span></a></div></div>
					<div class="item "><time class="date" datetime="2019-12-17T09:10:00">09h10</time><div class="data"><a  href="/opcvm/actualites/generales/lbo-france-achete-l-immeuble-grand-angle-a-saint-denis-811472.html" class="">LBO France achète l'immeuble Grand Angle à Saint Denis</a></div></div>
					<div class="item "><time class="date" datetime="2019-12-17T09:01:00">09h01</time><div class="data"><a  href="/actualites/news/le-cac40-ouvre-en-baisse-de-0-04-811465.html" class=""><b>Le CAC40 ouvre en baisse de 0,04%</b></a></div></div>
					<div class="item "><time class="date" datetime="2019-12-17T08:58:00">08h58</time><div class="data"><a  href="/actualites/reuters/le-marche-automobile-europeen-encore-en-hausse-en-novembre-selon-l-acea-239478.html" class="">Le marché automobile européen encore en hausse en novembre selon l'ACEA</a></div></div>
					<div class="item "><time class="date" datetime="2019-12-17T08:54:40">08h54</time><div class="data"><a  href="/actualites/reuters/les-valeurs-a-suivre-a-paris-et-en-europe-239479.html" class="">Les valeurs à suivre à Paris et en Europe</a></div></div>
					<div class="item "><time class="date" datetime="2019-12-17T08:52:00">08h52</time><div class="data"><a  href="/actions/actualites/news/kerlink-se-deploie-a-schiphol-811463.html" class=""><b>Kerlink</b> se déploie à Schiphol <span class="icon2016-comment-1">1</span><img alt="Small&Mid Cap" class="icon partner-icon" src="/Content/img/ico-snmd.png" /></a></div></div>
					<div class="item "><time class="date" datetime="2019-12-17T08:45:00">08h45</time><div class="data"><a  href="/actions/actualites/news/automobile-mois-de-novembre-contraste-pour-renault-et-psa-en-europe-811462.html" class=""><b>Automobile</b> : mois de novembre contrasté pour Renault et PSA en Europe</a></div></div>
					<div class="item "><time class="date" datetime="2019-12-17T08:42:00">08h42</time><div class="data"><a  href="/actions/actualites/news/voluntis-va-collaborer-avec-salesforce-811461.html" class=""><b>Voluntis</b> va collaborer avec Salesforce<img alt="Small&Mid Cap" class="icon partner-icon" src="/Content/img/ico-snmd.png" /></a></div></div>
					<div class="item "><time class="date" datetime="2019-12-17T08:30:00">08h30</time><div class="data"><a  href="/indices/actualites/news/preouverture-paris-le-cac40-de-retour-sur-les-6-000-points-des-aujourd-hui-811458.html" class=""><b>Préouverture Paris</b> : le CAC40 de retour sur les 6.000 points dès aujourd'hui?</a></div></div>
					<div class="item "><time class="date" datetime="2019-12-17T08:20:00">08h20</time><div class="data"><a  href="/actions/actualites/news/boostheat-france-partenariat-national-avec-unergies-811457.html" class="">Boostheat France : partenariat national avec Unergies<img alt="Small&Mid Cap" class="icon partner-icon" src="/Content/img/ico-snmd.png" /></a></div></div>
					<div class="item "><time class="date" datetime="2019-12-17T08:20:00">08h20</time><div class="data"><a  href="/opcvm/actualites/generales/ag2r-la-mondiale-recompense-pour-sa-strategie-d-investissement-dans-les-pme-et-les-eti-811464.html" class="">AG2R La Mondiale récompensé pour sa stratégie d'investissement dans les PME et les ETI</a></div></div>
					<div class="item "><time class="date" datetime="2019-12-17T08:20:00">08h20</time><div class="data"><a  href="/actions/actualites/news/edf-risque-de-correction-sous-les-resistances-at-756851.html" class=""><b>EDF</b> : risque de correction sous les résistances (AT)</a></div></div>
					<div class="item "><time class="date" datetime="2019-12-17T08:19:00">08h19</time><div class="data"><a  href="/actions/actualites/news/stmicroelectronics-les-resistances-sont-proches-at-756881.html" class=""><b>STMicroelectronics</b> : les résistances sont proches (AT)</a></div></div>
					<div class="item priv part70"><time class="date" datetime="2019-12-17T08:19:00">08h19</time><div class="data"><a  href="/actions/actualites/conseils/des-gains-merites-42340.html" class="">Pierre et Vacances Center Parcs : des gains mérités&nbsp;!<img alt='' class='icon' src='/ui/img/partner-70.png' /></a></div></div>
					<div class="item "><time class="date" datetime="2019-12-17T08:18:00">08h18</time><div class="data"><a  href="/actions/actualites/news/boeing-decide-enfin-de-suspendre-la-production-du-737-max-811456.html" class=""><b>Boeing</b> décide enfin de suspendre la production du 737 MAX <span class="icon2016-comment-1">8</span></a></div></div>
					<div class="item "><time class="date" datetime="2019-12-17T08
img alt="Small&Mid Cap" class="icon partner-icon" src="/Content/img/ico-snmd.png" /></a></div></div>
					<div class="item "><time class="date" datetime="2019-12-17T07:34:00">07h34</time><div class="data"><a  href="/actions/actualites/news/fermentalg-dsm-nutritional-products-qualifie-le-dha-811446.html" class="">Fermentalg : DSM Nutritional Products qualifie le DHA<img alt="Small&Mid Cap" class="icon partner-icon" src="/Content/img/ico-snmd.png" /></a></div></div>
					<div class="item "><time class="date" datetime="2019-12-17T07:32:00">07h32</time><div class="data"><a  href="/actions/actualites/news/carrefour-retour-possible-sur-les-supports-at-756796.html" class=""><b>Carrefour</b> : retour possible sur les supports (AT)</a></div></div>
					<div class="item "><time class="date" datetime="2019-12-17T07:31:00">07h31</time><div class="data"><a  href="/actions/actualites/news/renault-retour-possible-sur-les-supports-at-756837.html" class=""><b>Renault</b> : retour possible sur les supports (AT) <span class="icon2016-comment-1">5</span></a></div></div>
					<div class="item "><time class="date" datetime="2019-12-17T07:31:00">07h31</time><div class="data"><a  href="/actions/actualites/news/nicox-exerce-la-derniere-tranche-de-l-emprunt-obligataire-avec-kreos-capital-811445.html" class="">Nicox exerce la dernière tranche de l'emprunt obligataire avec Kreos Capital<img alt="Small&Mid Cap" class="icon partner-icon" src="/Content/img/ico-snmd.png" /></a></div></div>
					<div class="item "><time class="date" datetime="2019-12-17T07:29:00">07h29</time><div class="data"><a  href="/actions/actualites/news/vallourec-les-signaux-haussiers-sont-intacts-at-756798.html" class=""><b>Vallourec</b> : les signaux haussiers sont intacts (AT) <span class="icon2016-comment-1">18</span></a></div></div>
					<div class="item "><time class="date" datetime="2019-12-17T07:24:00">07h24</time><div class="data"><a  href="/indices/actualites/news/nasdaq-composite-les-resistances-sont-proches-at-756885.html" class=""><b>Nasdaq Composite</b> : les résistances sont proches (AT)</a></div></div>
					<div class="item "><time class="date" datetime="2019-12-17T07:23:00">07h23</time><div class="data"><a  href="/actions/actualites/news/oceasoft-succes-de-l-offre-publique-d-achat-simplifiee-811444.html" class="">Oceasoft : succès de l'offre publique d'achat simplifiée<img alt="Small&Mid Cap" class="icon partner-icon" src="/Content/img/ico-snmd.png" /></a></div></div>
					<div class="item "><time class="date" datetime="2019-12-17T07:13:00">07h13</time><div class="data"><a  href="/actualites/reuters/la-ftc-donne-son-accord-au-rachat-de-spark-par-roche-239474.html" class="">La FTC donne son accord au rachat de Spark par Roche</a></div></div>
					<div class="item "><time class="date" datetime="2019-12-17T07:04:00">07h04</time><div class="data"><a  href="/actions/actualites/news/cgg-les-resistances-sont-proches-at-770094.html" class=""><b>CGG</b> : les résistances sont proches (AT)</a></div></div>
					<div class="item "><time class="date" datetime="2019-12-17T07:00:00">07h00</time><div class="data"><a  href="/actualites/news/revue-de-presse-du-mardi-17-decembre-811443.html" class=""><b>Revue de presse du mardi 17 décembre</b></a></div></div>
					<div class="item "><time class="date" datetime="2019-12-17T06:56:45">06h56</time><div class="data"><a  href="/actualites/reuters/brexit-johnson-entend-empecher-toute-extension-de-la-periode-de-transition-selon-la-presse-239476.html" class="">Brexit: Johnson entend empêcher toute extension de la période de transition, selon la presse <span class="icon2016-comment-1">30</span></a></div></div>
					<div class="item "><time class="date" datetime="2019-12-17T06:52:14">06h52</time><div class="data"><a  href="/actualites/reuters/boeing-va-suspendre-en-janvier-la-production-des-737-239472.html" class="">Boeing va suspendre en janvier la production des 737</a></div></div>
					<div class="item "><time class="date" datetime="2019-12-17T06:41:00">06h41</time><div class="data"><a  href="/opcvm/actualites/generales/partners-finances-plus-de-100-recrutements-en-2019-811460.html" class="">Partners Finances : plus de 100 recrutements en 2019</a></div></div>
					<div class="item "><time class="date" datetime="2019-12-17T06:40:00">06h40</time><div class="data"><a  href="/indices/actualites/news/dow-jones-industrial-le-mouvement-reste-haussier-at-756756.html" class=""><b>Dow Jones Industrial</b> : le mouvement reste haussier (AT)</a></div></div>
					<div class="item "><time class="date" datetime="2019-12-17T06:30:00">06h30</time><div class="data"><a  href="/actualites/news/agenda-a-suivre-aujourd-hui-sur-les-marches-financiers-811442.html" class="">Agenda : à suivre aujourd'hui sur les marchés financiers</a></div></div>
					<div class="item "><time class="date" datetime="2019-12-17T06:20:00">06h20</time><div class="data"><a  href="/indices/actualites/news/cac-40-le-mouvement-reste-haussier-at-756755.html" class=""><b>CAC 40</b> : le mouvement reste haussier (AT)</a></div></div>
					<div class="item "><time class="date" datetime="2019-12-17T06:02:00">06h02</time><div class="data"><a  href="/actualites/reuters/reunion-ce-mardi-du-conseil-de-surveillance-de-fca-239473.html" class="">Réunion ce mardi du conseil de surveillance de FCA</a></div></div>
					<div class="item "><time class="date" datetime="2019-12-17T06:00:00">06h00</time><div class="data"><a  href="/devises/actualites/news/eur-usd-les-signaux-haussiers-sont-intacts-at-756760.html" class=""><b>EUR/USD</b> : les signaux haussiers sont intacts (AT)</a></div></div>
					<div class="item "><time class="date" datetime="2019-12-17T05:49:00">05h49</time><div class="data"><a  href="/actualites/news/bitcoin-ripple-ethereum-retrouvez-les-cours-des-principales-cryptomonnaies-753681.html" class=""><b>Bitcoin, Ripple, Ethereum... Retrouvez les cours des principales cryptomonnaies&nbsp;!</b></a></div></div>
					<div class="item "><time class="date" datetime="2019-12-17T05:01:00">05h01</time><div class="data"><div class="media"><img width="90" data-script="link=/actualites/economie/pollution-de-l-air-marseille-en-pleine-bouillabaisse-42800.html" class="visual" alt="paris" src="//cdn-static.boursier.com/illustrations/photos/200/pollution.jpg" /></div><a  href="/actualites/economie/pollution-de-l-air-marseille-en-pleine-bouillabaisse-42800.html" class="">Pollution de l'air : Marseille en pleine bouillabaisse <span class="icon2016-comment-1">13</span></a></div></div>
					<div class="item "><time class="date" datetime="2019-12-17T03:59:00">03h59</time><div class="data"><a  href="/actualites/galeries/les-villes-ou-trouver-rapidement-un-emploi-292,7042.html" class="">Les villes où trouver rapidement un emploi </a></div></div>
					<div class="item "><time class="date" datetime="2019-12-17T00:19:00">00h19</time><div class="data"><a  href="/actualites/reuters/la-sncf-presse-les-usagers-de-ne-pas-voyager-mardi-239468.html" class="">La SNCF presse les usagers de ne pas voyager mardi <span class="icon2016-comment-1">5</span></a></div></div>
					
		</div>
		
		
	
</div>


	
	<div class="col col-12">
		
	</div>

	<ul class="selectdropdown">
		<li><a>Sélectionnez une date</a></li>
		
			<li><a href="/actualites/news-du-jour/20191217">Aujourd&#39;hui</a></li>
		
			<li><a href="/actualites/news-du-jour/20191216">lundi 16 d&#233;cembre 2019</a></li>
		
			<li><a href="/actualites/news-du-jour/20191215">dimanche 15 d&#233;cembre 2019</a></li>
		
			<li><a href="/actualites/news-du-jour/20191214">samedi 14 d&#233;cembre 2019</a></li>
		
			<li><a href="/actualites/news-du-jour/20191213">vendredi 13 d&#233;cembre 2019</a></li>
		
			<li><a href="/actualites/news-du-jour/20191212">jeudi 12 d&#233;cembre 2019</a></li>
		
			<li><a href="/actualites/news-du-jour/20191211">mercredi 11 d&#233;cembre 2019</a></li>
		
			<li><a href="/actualites/news-du-jour/20191210">mardi 10 d&#233;cembre 2019</a></li>
		
			<li><a href="/actualites/news-du-jour/20191209">lundi 9 d&#233;cembre 2019</a></li>
		
			<li><a href="/actualites/news-du-jour/20191208">dimanche 8 d&#233;cembre 2019</a></li>
		
			<li><a href="/actualites/news-du-jour/20191207">samedi 7 d&#233;cembre 2019</a></li>
		
			<li><a href="/actualites/news-du-jour/20191206">vendredi 6 d&#233;cembre 2019</a></li>
		
			<li><a href="/actualites/news-du-jour/20191205">jeudi 5 d&#233;cembre 2019</a></li>
		
			<li><a href="/actualites/news-du-jour/20191204">mercredi 4 d&#233;cembre 2019</a></li>
		
			<li><a href="/actualites/news-du-jour/20191203">mardi 3 d&#233;cembre 2019</a></li>
		
			<li><a href="/actualites/news-du-jour/20191202">lundi 2 d&#233;cembre 2019</a></li>
		
			<li><a href="/actualites/news-du-jour/20191201">dimanche 1 d&#233;cembre 2019</a></li>
		
			<li><a href="/actualites/news-du-jour/20191130">samedi 30 novembre 2019</a></li>
		
			<li><a href="/actualites/news-du-jour/20191129">vendredi 29 novembre 2019</a></li>
		
			<li><a href="/actualites/news-du-jour/20191128">jeudi 28 novembre 2019</a></li>
		
			<li><a href="/actualites/news-du-jour/20191127">mercredi 27 novembre 2019</a></li>
		
			<li><a href="/actualites/news-du-jour/20191126">mardi 26 novembre 2019</a></li>
		
			<li><a href="/actualites/news-du-jour/20191125">lundi 25 novembre 2019</a></li>
		
			<li><a href="/actualites/news-du-jour/20191124">dimanche 24 novembre 2019</a></li>
		
			<li><a href="/actualites/news-du-jour/20191123">samedi 23 novembre 2019</a></li>
		
			<li><a href="/actualites/news-du-jour/20191122">vendredi 22 novembre 2019</a></li>
		
			<li><a href="/actualites/news-du-jour/20191121">jeudi 21 novembre 2019</a></li>
		
			<li><a href="/actualites/news-du-jour/20191120">mercredi 20 novembre 2019</a></li>
		
			<li><a href="/actualites/news-du-jour/20191119">mardi 19 novembre 2019</a></li>
		
			<li><a href="/actualites/news-du-jour/20191118">lundi 18 novembre 2019</a></li>
		
			<li><a href="/actualites/news-du-jour/20191117">dimanche 17 novembre 2019</a></li>
		
	</ul>

				</div>
					
				<div class="col col-4 medium-12 right aside--block">
					
	<div class="no-sticky courtier">
		<div class="courtier-block">
			<!-- Generic > Vignette 1 --><div id="ad-anx-sidebar1">
</div><!-- Generic > Vignette 2 --><div id="ad-anx-sidebar2">
</div><!-- Generic > Vignette 3 --><div id="ad-anx-sidebar3">
</div><!-- Generic > Vignette 4 --><div id="ad-anx-sidebar4">
</div><!-- Generic > Vignette 5 --><div id="ad-anx-sidebar5">
</div><!-- Generic > Vignette LMNP -->
<a data-vendor="c:google" href="https://argent.boursier.com/immobilier/services/decouvrez-le-dispositif-lmnp-2019-2020-41.html?xtor=AD-4-[hpcoldroite]" target="_blank"><img src="https://cdn-static.boursier.com/illustrations/campaigns/btn-investir-retraite-300x66.png" alt="" width="300" height="66" style="width:300px !important; height:66px !important" border="0" /></a>
		</div>
	</div>
	<div class="ad-container bottom--margin">
		<div class="sticky-container" data-sticky-container>
			<div class="box courtier stickyads sticky" id="first-ads" data-sticky data-anchor="first-ads">
				<div class="stack" id="middle_col__pave1">
					<!-- Generic > Pavé 1 --><div id="ad-anx-mpu1">
</div>
				</div>
			</div>
		</div>
	</div>

		

		<div>
			<div class="sticky-container" data-sticky-container>
				<div class="box courtier stickyads sticky" id="second-ads" data-sticky data-anchor="second-ads">
					<div data-id="liste-pf" id="liste-pf" data-target="mychoice" class="stack">
						<div data-script="mode=sync;autosize=0;defaut=0" class="tabs">
							<h2 class="tab on">
								<a href="#" class="title">Mes listes</a>
							</h2>
							<h2 class="tab">
								<a href="#" class="title">Mes portefeuilles</a>
							</h2>
						</div>
						<div class="tabs-content">
							<div style="display: block;">
								<div id="block-mes-listes" class="block-mes-listes-home" data-ajax-href="/ajax/membres/listes/ajaxmylist"></div>
							</div>
							<div style="display: none;">
								<div id="block-mon-portefeuille" class="block-mes-listes-home" data-ajax-href="/ajax/membres/portefeuilles/ajaxmyportfolio"></div>
							</div>
						</div>
					</div>
				</div>
			</div>
		</div>



		<!-- Boutique-->
			
				</div>

			</div><!-- /.row -->
		</div><!-- /.wrapper -->
	</section><!-- /.grid-12 -->




</div><!-- /#overall -->


<script>
	(function (h) { h.className = h.className.replace('no-', '') })(document.documentElement);
</script>

<script>
	initSlider = function () {
		const htmlClass = document.getElementsByTagName('html')
		const bodyClass = document.getElementsByClassName('home');
		const bodyMobile = document.getElementsByClassName('mobile');
		const perfBarActive = document.getElementsByClassName('perfBar');
		const dressClass = document.getElementsByClassName('dress');
		const overall = document.getElementById('overall');

		const openInfosBoursier = document.getElementById('toggle-infos-panel');
		const infosBoursier = document.getElementById('infos-boursier');
		const indexCompact = document.getElementById('indexes-compact');

		const slider = $("#infos-boursier.slick-slider");

		const scrolly_table = document.getElementsByClassName('scrolly-table');

		const st = window.pageYOffset || document.documentElement.scrollTop;
		const closeLimiter = 70;

		const tablet = htmlClass[0].offsetWidth <= 999;

		slider.on('init', function () {
			$('#infos-boursier_panel .loading').fadeOut(500, function () {
				$('#infos-boursier_panel').removeClass('init');
				
				if (!bodyMobile[0] && !tablet && st < closeLimiter) {
					htmlClass[0].classList.add('perfBar');
				}
				else
				{
					htmlClass[0].classList.remove('perfBar');
				}
			});
		});

		slider.slick({
			dots: false,
			arrows: true,
			speed: 300,
			slidesToShow: 3,
			slidesToScroll: 1,
			slide: ".ib-box",
			infinite: false,
			variableWidth: true,

			responsive: [
				{
					breakpoint: 1180,
					settings: {
						slidesToShow: 2,
						slidesToScroll: 1,
						variableWidth: false

					}
				},
				{
					breakpoint: 930,
					settings: {
						slidesToShow: 1,
						slidesToScroll: 1,
						variableWidth: false

					}
				},
				{
					breakpoint: 640,
					vertical: true,
					verticalSwiping: false,
					settings: {
						slidesToShow: 3,
						slidesToScroll: 3
						//dots: true
					}
				}
			]
		});

		function myFunction() {
			if (perfBarActive[0]) {
				// common rules
				infosBoursier.style.display = "block";
				indexCompact.style.display = "none";

				openInfosBoursier.classList.add("open");
			}
			if (perfBarActive[0] && bodyMobile[0]) {
				openInfosBoursier.classList.remove("open");				
			}
			//else {

			//	infosBoursier.style.display = "none";
			//	indexCompact.style.display = "block";

			//	openInfosBoursier.classList.remove("open");
			//}
		}

		myFunction();

		openInfosBoursier.addEventListener("click", function (e) {
			e.preventDefault();
			e.stopPropagation();

			const st = window.pageYOffset || document.documentElement.scrollTop;

			if (perfBarActive[0]) {
				htmlClass[0].classList.remove('perfBar');
			} else {
				htmlClass[0].classList.add('perfBar');
			}
		});

		window.addEventListener('scroll', function () {
			const st = window.pageYOffset || document.documentElement.scrollTop;
			
			if (!bodyMobile[0] && !tablet) {				
				if (st > closeLimiter) {
					htmlClass[0].classList.remove('perfBar');
				} else if (!perfBarActive[0] && st < 80) {
					htmlClass[0].classList.add('perfBar');
				} else {

				}
			}
		});


		if (typeof (Storage) !== "undefined") {
			var scrollyTable = localStorage.getItem("scrollyTable");

			if (scrollyTable === "on") {

				for (var i = 0; i < scrolly_table.length; i++) {
					scrolly_table[i].classList.add('on');
				}
			}
		}

		if (!$('html').hasClass('mobile')) {
			$('#indexes-full .name').not('span').parent().parent().on('mouseenter', function (e) {
				e.preventDefault();

				var _thisParent = $(this).parent().parent();
				var _redirection = $(this).find('a').attr('href');
				var _imgPath = $(this).find('a').attr('data-tooltip-img');

				$('.tooltips img').attr('src', _imgPath);
				$('.tooltips a').attr('href', _redirection);

				$('#indexes-full table').removeClass('active');
				_thisParent.addClass('active');

			});
		}

		// TODO: meme code que InitOnglets() ???
		$('.tabs').each(function () {

			// Scope
			var $this = $(this), // ul.tabs courrant,
				$tabs = $('> .tab', $this), // liste des onglets
				$cont = $this.next('div.tabs-content:eq(0)'), // conteneur associe au ul.tabs
				id = this.id || null,
				cooki = $.cookie(id),
				param = $this.attr('data-script') ? nw.tools.paramToObj($this.attr('data-script')) : {}, // parametres des onglets
				i = 0,
				setup = {
					currentClass: 'on', // class utilisee sur un onglet actif
					disabledClass: 'off', // class utilisee sur un onglet desactive
					nbTabs: $tabs.length, // nombre  d'onglets
					url: '', // variable temporaire pour les chemins ajax
					index: 0, // variable temporaire pour l'index des onglets
					defaut: (param.defaut === 0) ? 0 : param.defaut || 'undefined',
					mode: param.mode || 'none', // mode async|sync|img|form|none
					event: param.event || 'click', // event click|over
					autoSize: param.autosize ? true : false // la taille des onglets adaptee au conteneur
				},
			// Applique la class "setup.curCla" lors du click sur un onglet (via son index)
				switchTab = function (index) {
					$tabs
							.filter('.' + setup.currentClass).removeClass(setup.currentClass).end()
							.filter(':eq(' + index + ')').addClass(setup.currentClass);
				},

			// Affiche le contenu
				switchContent = function (params) {
					if (setup.mode === 'async' && params.url !== '') {
						$cont.empty();
						$.ajax({
							url: params.url,
							success: function (data) {
								$cont.removeClass('box b-error').html(data);
								switchTab(setup.index);
								nw.tools.stopLoading($cont);
							},
							error: function () {
								$cont.addClass('box b-error').html(' D&eacute;sol&eacute;, une erreur est survenue.');
								nw.tools.stopLoading($cont);
							}
						});
					}
					else if (setup.mode === 'sync') {
						$cont.children('div:not(.tabs-content-visible)').css({ visibility: 'hidden', height: 0 }).filter(':eq(' + params.index + ')').css({ visibility: 'visible', height: '' });
					}
					else if (setup.mode === 'img') {
						//$cont.find('img').attr('src', '');
						$cont.find('img').attr('src', params.url);
					}
				};

			param.start = param.start | 0; // Pour gestion des onglet graph si suppression d'intraday (mode "img" uniquement)

			// Ajuste la taille des onglets si demandé
			//if (setup.autoSize) {mode=sync;autosize=true;defaut=0
			//	$this.addClass('autosize');
			//	var charTot = 0, // nombre total de caractere
			//		charTab = $tabs.map(function() {
			//			var len = $.trim($('> .btn', this).text()).length;
			//			charTot += len;
			//			return len;
			//		}), // tableau : nombre de caractere par onglet
			//		sizeTot = $this.width(), // taille total du conteneur
			//		sizeNew = 0,
			//		sizeRedux = sizeTot - 20 * charTab.length; // on reserve de la place pour les marges

			//	//$tabs.each(function(i) {
			//		//var size = Math.floor((sizeRedux * charTab[i]) / charTot);
			//		//$(this).width(size);
			//		//sizeNew += size;
			//	//});

			//	// Comble la différence de taille
			//	var diff = sizeTot - sizeNew,
			//		part = Math.ceil(diff / charTab.length);

			//	for (i = 0; diff > 0; i++) {
			//		var next = Math.min(diff, part),
			//			cible = $tabs.filter(':eq(' + i + ')');
			//		cible.width(cible.width() + next);
			//		diff -= next;
			//	}
			//}

			// Recupere le cookie et change la valeur par defaut
			if (cooki) {
				setup.defaut = Math.max(0, cooki - param.start);
			}

			// Affiche l'onglet par defaut
			if (typeof setup.defaut != 'undefined' && setup.defaut > -1) {
				switchTab(setup.defaut);
			}

			// Onglet desactive
			$this.delegate('.tab.' + setup.disabledClass, setup.event, function () { return false; });

			// Mode Asynchrone
			if (setup.mode === 'async') {

				// Affiche le contenu par defaut
				/*
				if ( typeof setup.defaut != 'undefined' && setup.defaut > -1) {
				setup.url = nw.tools.paramToObj($this.find('> .tab:eq(' + setup.defaut + ')').find('a').attr('data-script')).url;
				switchContent({ url: setup.url });
				}
				*/

				// Affiche le contenu Ã  l'événement
				$this.delegate('.tab:not(.' + setup.disabledClass + ')', setup.event, function (event) {
					var $li = $(this);
					setup.index = $this.find('.tab').index($li);
					setup.url = nw.tools.paramToObj($li.find('a').attr('data-script')).url;
					switchTab(setup.index);
					switchContent({ url: setup.url });
					return false;
				});

			}

				// Mode Synchrone
			else if (setup.mode === 'sync') {

				// Affiche le contenu par defaut
				if (typeof setup.defaut != 'undefined' && setup.defaut > -1) {
					switchContent({ index: setup.defaut });
				}

				// Affiche le contenu Ã  l'événement
				$this.delegate('.tab:not(.' + setup.disabledClass + ')', setup.event, function (event) {
					var $li = $(this);
					setup.index = $this.find('.tab').index($li);
					switchTab(setup.index);
					switchContent({ index: setup.index });
					if (id) {
						$.cookie(id, setup.index, { expires: 365, path: '/' })
					}
					return false;
				});
			}

				// Mode Switch Image
			else if (setup.mode === 'img') {
				if (!cooki && setup.defaut === 'undefined') {
					setup.defaut = 0;
					switchTab(setup.defaut);
				}

				// Affiche le contenu par defaut
				if (typeof setup.defaut != 'undefined' && setup.defaut > -1) {
					setup.url = nw.tools.paramToObj($this.find('> .tab:eq(' + setup.defaut + ')').find('a').attr('data-script')).url;
					switchContent({ url: setup.url });
				}

				// Affiche le contenu Ã  l'événement
				$this.delegate('.tab:not(.' + setup.disabledClass + ')', setup.event, function (event) {
					var $li = $(this),
						$a = $li.find('a');
					setup.index = $this.find('.tab').index($li);
					setup.url = nw.tools.paramToObj($a.attr('data-script')).url;
					switchTab(setup.index);
					switchContent({ url: setup.url });
					if (id) {
						//$.cookie(id, setup.index, { expires: 365, path: '/' });
						$.cookie(id, (setup.index + param.start), { expires: 365, path: '/' });

					}
					return false;
				});
			}

				// Mode Formulaire
			else if (setup.mode === 'form') {

				var $form = $this.parents('form:eq(0)'),
					name = nw.tools.paramToObj($this.attr('data-script')).name;

				// Submit le form Ã  l'événement
				$this.delegate('.tab:not(.' + setup.disabledClass + ')', setup.event, function (event) {
					var $li = $(this),
						$a = $li.find('a'),
						val = nw.tools.paramToObj($a.attr('data-script')).val;

					if (!$('input[name="' + name + '"]', $form).length) {
						$form.append('<input type="hidden" name="' + name + '" value="' + val + '" />');
					}
					$form.find('input[name="' + name + '"]').val(val).end().submit();
					return false;
				});
			}
		});
	}
</script>
	
		<div class="grid-12 section-separator" id="partenaires">
			<div class="wrapper">
				<div class="row">
					<h2>Partenaires de Boursier.com</h2>
					<div class="list-items">
						<!-- Generic > Partenaire 1 --><div id="ad-anx-footer1">
</div><!-- Generic > Partenaire 2 --><div id="ad-anx-footer2">
</div><!-- Generic > Partenaire 3 --><div id="ad-anx-footer3">
</div>
					</div>
				</div>
			</div>
		</div>
	
	<!--Donut#...#-->
<section id="pub-footer">
	<div class="wrapper">
		<div>
			<span class="title">Contenus</span>
			<p>Média, banque, société de gestion : affichez les informations de Boursier.com sur votre site et apportez toute l'expertise de nos journalistes à votre audience.</p>
			<a class="btn-more" href="/syndication" title="En savoir plus">
				<span class="bt-label">En savoir plus</span>
				<span class="bt-icon icon2016-more"></span>
			</a>
		</div>
		<hr />
		<div>
			<span class="title">Publicité</span>
			<p>Communiquez auprès de notre audience principalement masculine et CSP+, <b>1,3 million</b> d’internautes par mois</p>
			<a class="btn-more" href="/services/publicite" title="En savoir plus">
				<span class="bt-label">En savoir plus</span>
				<span class="bt-icon icon2016-more"></span>
			</a>
		</div>
		
	</div>
</section>

<footer id="footer" class="page-footer grid-12">
	<div class="wrapper">
		<div class="social">
			<ul>

				<li class="facebook">
					<a href="http://www.facebook.com/boursiercom" target="_blank" title="Facebook"><span class="icon2016-facebook"></span></a>
				</li>
				<li class="twitter">
					<a href="https://twitter.com/#!/Boursier_com" target="_blank" title="Twitter"><span class="icon2016-twitter"></span></a>
				</li>
			</ul>
		</div>

		<!-- Rubriques -->
		<div id="categories">
			<div class="row">
				<div class="col col-2">

					<h3>Bourse</h3>
					<nav>
						<ul>
							<li><a href="/actions/paris?marketId=99">Cours de A &#224; Z</a></li>
							<!--
						-->
							<li><a href="/palmares/paris">Palmar&#232;s</a></li>
							<!--
						-->
							<li><a href="/indices">Indices</a></li>
							<!--
						-->
							<li><a href="/devises">Devises</a></li>
							<!--
						-->
							<li><a href="/matieres-premieres/cours/brent-XC0009677409,GB.html">Brent</a></li>
							<li><a href="/crypto-monnaies/cours-du-bitcoin-et-des-crypto-monnaies">Crypto-monnaies</a></li>
						</ul>
					</nav>
				</div>
				<div class="col col-3">
					<h3>Actualités</h3>
					<nav>
						<ul>
							<li><a href="/actualites/news-du-jour">Actualit&#233;s du jour</a></li>
							<!--
						-->
							<li><a href="/videos/marches">Point des march&#233;s</a></li>
							<!--
						-->
							<li><a href="/actualites/galeries">Galeries photos</a></li>
							<!--
						-->
							<li><a href="/actualites/economie">Economie</a></li>
							<!--
						-->
							<li><a href="/actualites/macroeconomie">Macro-economie</a></li>
							<!--
						-->
							<li><a href="/secteurs">Actualit&#233;s par secteur</a></li>
							<!--
						-->
							<li><a href="/elections/presidentielle/resultats-2017">Résultats Présidentielle 2017</a></li>

							<li><a href="/elections/legislatives/resultats-2017">Résultats Législatives 2017</a></li>

						</ul>
					</nav>
				</div>
				<div class="col col-3">
					<h3>Placements / Produits</h3>
					<nav>
						<ul>
							<li><a href="/opcvm/">OPCVM</a></li>
							<!--
						-->
							<li><a href="/produits-de-bourse/recherche">Produits de Bourse</a></li>
							<!--
						-->
							<li><a href="/produits-de-bourse/actualites/conseils">Conseils</a></li>
							<!--
						-->
							<li><a href="/produits-de-bourse/actualites/news">Actualit&#233;s</a></li>
							<!--
						-->
							<li><a href="/produits-de-bourse/statistiques/variation/">Palmar&#232;s</a></li>
							<!--
						-->
							
						</ul>
					</nav>
				</div>
				<div class="col col-2">
					<h3 class="premium">Privilèges</h3>
					<nav>
						<ul>
							<li>
								<a href="/membres/abonnement?utm_source=boursier&amp;utm_medium=boutonnavabo&amp;utm_campaign=privileges">S'abonner</a>
							</li>
							<!--
						-->
							<li><a href="/privileges/conseils/reco-du-jour/1">Reco du jour</a></li>
							<!--
						-->
							<li><a href="/privileges/conseils/actions/1">Conseils Actions</a></li>
							<!--
						-->
							<li><a href="/privileges/portefeuilles">Portefeuilles types</a></li>
						</ul>
					</nav>
				</div>
				<div class="col col-2">
					<h3>Services</h3>
					<nav>

						<ul>
							<li>
								<span class="crypt" data-target="self" data-link="L3NlcnZpY2VzL2luZm9ybWF0aW9ucy9xdWktc29tbWVzLW5vdXM=">Qui sommes-nous ?</span>
							</li><!--
				
			
							--><li>
								<span class="crypt" data-target="self" data-link="L3NlcnZpY2VzL3B1YmxpY2l0ZQ==">Publicité</span>
							</li><!--
				
							--><li>
								<span class="crypt" data-target="self" data-link="L2FpZGUvZmFx">Aide</span>
							</li><!--
							-->
							
<li class="colophon__item">
	<a class="crypt" target="_self" href="/services/informations/mentions-legales">Mentions légales</a>
</li>

<li class="colophon__item">
	<a class="crypt" target="_self" href="/services/informations/conditions-generales">CGU/CGV</a>
</li>

<li class="colophon__item">
	<a class="crypt" target="_self" href="/services/informations/politique-confidentialite">Politique de confidentialité</a>
</li>

<li class="colophon__item">
	<a class="crypt" target="_self" href="/services/informations/cookies">Charte cookies</a>
</li>

							<!--
							--><li>
								<script>BC.mailto("service-clients", "boursier.com", "Signaler un contenu illicite")</script>
							</li>

						</ul>
					</nav>
				</div>
				
			</div>
		</div> <!-- /Rubriques -->
		<!-- Copyright -->
		<div id="copyright">
			<div class="container">
				<div class="logo"><a href="/" title="Actualité financière – Cours de Bourse en temps réel, Conseils – Boursier.com"><span>Bourse</span></a></div>
				<p>&copy; Copyright 1998-2019 Boursier.com. Tous droits réservés. Site édité par Investir Publications.</p>
			</div>
		</div> <!-- /Copyright -->
		<!-- Partenaires -->
		<div id="affiliates" class="row-fluid">
			<div class="container">
				<div>
					<ul>
						<li><span data-link="aHR0cDovL3d3dy5ib3Vyc2llci5jb20v" class="crypt">Boursier.com</span></li>
						<li><span data-link="aHR0cHM6Ly9hcmdlbnQuYm91cnNpZXIuY29tLw==" class="crypt">L'Argent &amp; Vous</span></li>
					</ul>
					<span id="ad-7clefs" data-link="L21lbWJyZXMvYWJvbm5lbWVudD91dG1fc291cmNlPWJvdXJzaWVyJnV0bV9tZWRpdW09Ym91dG9uaGF1dGFibyZ1dG1fY2FtcGFpZ249cHJpdmlsZWdlcw==" class="ad-7clefs crypt">Nos conseils boursiers pour 1€/mois</span>
				</div>
			</div>
		</div> <!-- /Partenaires -->
		<!-- Modal -->
		<!-- /Modal -->

	</div>

	<div id="modals2"></div>
</footer><!-- /Footer -->


<div id="modals-connexion"></div>
<!--EndDonut-->
	
	<div id="connectionInfo" data-ajax-href="/ajax/master/headersubscribe"></div>

	<script src="/bundles/jqueryval?v=pRzqn4QaBnW_W_VVXqHdGcHB33TkLj2ijGjPZe_z0t41"></script>

	<script src="/Scripts/js/bottom?v=rDxcLSkRDVv9ONOss6Rgm8vKzXin5Dtx4JZE-LT8Ghc1"></script>

	
	
	



	<!-- Tags -->
	<script src="/script/track?url=%2Factualites%2Fnews-du-jour"></script>
<script>if (window.BC && window.BC.tracker) { BC.tracker.run(); }</script>
<!-- Begin tagcommander  -->

<script type="didomi/javascript" src="//cdn-static.boursier.com/e/tc/au_boursier.js?20191217"></script>
<noscript><iframe src="//redirect451.tagcommander.com/utils/noscript.php?id=3&mode=iframe" width="1" height="1"></iframe></noscript>
<!--  end tagcommander -->

	
	
	
</body>

</html>
'''
