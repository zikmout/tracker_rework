# %%
with open('frd.html', 'r') as fd:
    out = fd.read()

# %%
print('out = {}'.format(out))
# Out:
# out =
#
#
# <!DOCTYPE html>
# <html lang="fr" class="">
# <head>
# 	<!-- 90 -->
# 	<meta charset="utf-8">
# 		<meta name="viewport" content="width=device-width, initial-scale=1.0, user-scalable=0" />
# 		<meta name="HandheldFriendly" content="true">
# 		<script> var isResponsive = true; </script>
# 	<meta name="apple-itunes-app" content="app-id=325643675, affiliate-data=affId=1194513">
# 	<meta http-equiv="content-language" content="fr">
# 	<meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">
# 	<meta name="theme-color" content="#35424f" />
# 	<meta name="robots" content="max-snippet:-1, max-image-preview:large, max-video-preview:-1">
# 	<meta name="twitter:dnt" content="on">
#
# 	<title>Bourse : cours, cotations des actions et conseils boursiers sur les titres - Cotation en temps r&eacute;el</title>
# 	<script type="text/javascript">
# 		window.baseDomain = 'https://www.boursier.com';
# ...

# %%
strt  = ```



 
<!DOCTYPE html>
<html lang="fr" class="">
<head>
	<!-- 90 -->
	<meta charset="utf-8">
		<meta name="viewport" content="width=device-width, initial-scale=1.0, user-scalable=0" />
		<meta name="HandheldFriendly" content="true">
		<script> var isResponsive = true; </script>
	<meta name="apple-itunes-app" content="app-id=325643675, affiliate-data=affId=1194513">
	<meta http-equiv="content-language" content="fr">
	<meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">
	<meta name="theme-color" content="#35424f" />
	<meta name="robots" content="max-snippet:-1, max-image-preview:large, max-video-preview:-1">
	<meta name="twitter:dnt" content="on">

	<title>Bourse : cours, cotations des actions et conseils boursiers sur les titres - Cotation en temps r&eacute;el</title>
	<script type="text/javascript">
		window.baseDomain = 'https://www.boursier.com';
		window.ssoKeys = { "FB": '396473187066093', "LI": '772sq6ivh22rxn', "TW" : 'AIhzceHmPiDqWdCwo2vcA' };
	</script>

	<!-- tag Analytics -->
	
<script type="text/javascript">
<!--

	function __tcvarsCreate() {
		//TC Declared Variables
		var tc_vars = {};

	
		tc_vars.content_id = '';
		tc_vars.custom1 = '';
		tc_vars.custom2 = '';
		tc_vars.custom3 = '';
		tc_vars.custom4 = '';
		tc_vars.custom5 = '';
		tc_vars.custom6 = '';
		tc_vars.error = '200';
		tc_vars.search_page = 'Index';
		tc_vars.content_level1 = 'Home';
		tc_vars.content_level2 = '';
		tc_vars.content_label = '';
		tc_vars.content_class = 'Index';
	

		return tc_vars;
	}


	//-->
</script>

	<script src="//cdn-static.boursier.com/e/di/cmp.js?20200626"></script>
<script type=deferred/javascript src="/bundles/positions?v=DqcCqbphLHBVXJmQwI8qXAihYKf6JF30F1frtCfyY1o1"></script>

<script src="//cdn.hubvisor.io/wrapper/01BYK28ENND8X5G8K0AJ2DPK7E/hubvisor.js" onerror="hubvisorErrorHandler" async></script><!-- DFP > All --><script type="deferred/javascript" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js" async></script>

<!-- Begin tagcommander  -->
<script type="deferred/javascript" src="//cdn-static.boursier.com/e/tc/a_boursier.js?v1&20200626" async></script>
<!--  end tagcommander -->
<link rel="manifest" href="/manifest.json">


	<!-- Styles -->
	
	<link href="/Content/css?v=7bTYQLir3cTfl5ARJZM81Qb0_50A2y68tb24GVYuwQA1" rel="stylesheet"/>


	<link rel="search" type="application/opensearchdescription+xml" href="/syndication/recherche" title="Boursier.com" />
	<link rel="shortcut icon" href="/favicon.ico" />
	<link rel="image_src" href="/Content/img/logo.png" />

		<link rel="stylesheet" href="/ui/css/global.css?637285949140000000" />
		<link rel="stylesheet" href="/ui/css/quizz-resultats.css?636849616400000000" />
		<link href="/UI/css/colorbox.css" rel="stylesheet" type="text/css" />
		<link href="/ui/css/modal.css?636849616400000000" rel="stylesheet" type="text/css" />
<link href="/Content/migrate?v=-61F0tCSUnAmbO0Oy57tgQ05wbHcj2k5_V__SdG3UOE1" rel="stylesheet"/>
	<!-- V5 -->
	<link href="/UI/v5/bundle?v=XrvTqOtJSmMT6dY3tTl6KZhvWyTfrDypUyJ_rswGH4U1" rel="stylesheet"/>

	<!-- V5 -->

	<!-- Scripts -->
	<script src="/bundles/jquery?v=s6LHZm33GCIH8eutynJ9FM_yTzIbKEVHC3z-sBRx1uI1"></script>

	<script src="/bundles/Bootstrap/js?v=RKZehS2z70rY7zIJ8lfj7V4jT1pO4Segdbwy8N5DHBo1"></script>

	<script src="/Scripts/js?v=va5gbMDNxfYvV40C3PTOiFCZyL6mNF6IKAzSgRQhWtY1"></script>

	<!-- Le HTML5 shim, for IE6-8 support of HTML5 elements -->
<!--[if lt IE 9]>
	<script src="/scripts/html5shiv.js"></script>
<![endif]-->

<!--[if lt IE 9]><script type="text/javascript">$('html').addClass('BIE9'); </script><![endif]-->
<!--[if IE 8]><script type="text/javascript">$('html').addClass('IE8'); </script><![endif]-->
<!--[if IE 7]><script type="text/javascript">$('html').addClass('IE7'); </script><![endif]-->

	<meta name="description" content="&amp;#9733;&amp;#9733;&amp;#9733;Bourse&amp;#9733;&amp;#9733;&amp;#9733; Cours de Bourse et conseils boursiers en ligne : Boursier.com propose des informations et recommandations pour bien investir et g&#233;rer son portefeuille en fonction de l&#39;actualit&#233; boursi&#232;re de la Bourse de Paris (CAC40) et de New York (Nasdaq, Dow Jones)" />
<script type="text/javascript"> Boursier.html.applyRefresh(240); </script>
	
	
	



	<script type="text/javascript">
		(function (h) { h.className = h.className.replace('no-', '') })(document.documentElement);
	</script>
</head>

<body class="home" id="content">
    <div class="admin" id="home-link-admin" data-ajax-href="/ajax/master/administration"></div>
    <div id="modal-message" data-ajax-href="/ajax/master/popinmessage"></div>

    <div class="search-overlay" id="search-overlay"></div>
    <div class="connection-overlay" id="connection-overlay"></div>


    


<div id="overall">

	<div data-id="infos-boursier_panel" id="infos-boursier_panel" class="init stuck">
		
		<div class="bg">
			<div id="headerblock" class="dyn" data-ajax-href="/navigation/header" data-ajax-success="initSlider"></div>
		</div>
	</div>

	<header data-id="header" class="page-head">
		<!-- Top -->
		<div id="logo-user_tools">
			<div class="wrapper">
				<span class="ico-burger toggle-button" data-toggle-element="#main-menu #infos-boursier_panel #form-search.visible .sub-menu--connected__wrapper.visible .ico-burger #user_menu.visible" data-toggle-class="visible">
					<span></span>
				</span>
				<div class="logo">
					<a href="/" title="Actualité financière – Cours de Bourse en temps réel, Conseils – Boursier.com">
							<h1>Bourse</h1>
					</a>
				</div>

				<span class="search-toggle toggle-button" data-toggle-element="#form-search .sub-menu--connected__wrapper.visible #user_menu.visible" data-toggle-class="visible">
					<span class="icon2016-search"></span>
				</span>

				<form action="/recherche/synthese" method="post" id="form-search">
					
					<input type="text" class="form-text" name="q" required>
					<button type="submit" name="sa" class="icon2016-search" value=" "></button>
					<input name="cx" type="hidden" value="008493178372379324166:oczdasvhbii">
				</form>
				<!-- connecté / déconnecté -->

				<div id="box-connection" data-ajax-href="/user/connection" data-ajax-success="BC.AJAX.initHeaderConnection"></div>

			</div><!-- /wrapper -->
		</div><!-- /Top -->
		<!-- /m-infos -->
		<div class="sub-menu--connected__wrapper">
			<div class="wrapper">
				<nav role="navigation">
					<ul class="sub-menu--connected__list">
						<li class="sub-menu--connected__list-item"><a href="/membres/mes-infos/coordonnees" rel="nofollow">Mes infos</a></li>
						<li class="sub-menu--connected__list-item hidedesktop"><a href="/membres/listes/consulter/">Mes listes</a></li>
						<li class="sub-menu--connected__list-item hidedesktop"><a href="/membres/portefeuilles/consulter/">Mes portefeuilles</a></li>
						<li class="sub-menu--connected__list-item"><a href="/membres/mes-infos/profil" rel="nofollow">Mon profil forum</a></li>
						<li class="sub-menu--connected__list-item"><a href="/membres/mes-infos/newsletters" rel="nofollow">Mes newsletters</a></li>
						<li class="sub-menu--connected__list-item">
							<a class="btn-more premium" href="/membres/abonnement?utm_source=boursier&amp;utm_medium=boutonmenuprofil&amp;utm_campaign=privileges" target="_blank" rel="nofollow">
								<span class="bt-label">M'abonner aux conseils Privilèges</span>
							</a>
						</li>
						<li class="sub-menu--connected__list-item">
							<a onclick="return confirm('Etes-vous sûr de vouloir vous déconnecter ?')" href="/membres/inscription/deconnexion">D&eacute;connexion</a>
						</li>
					</ul>

					<span class="toggle-button toggle-on-scroll icon2016 icon2016-close" data-toggle-element=".sub-menu--connected__wrapper" data-toggle-class="visible"></span>
				</nav>
			</div>
		</div>

		<!-- Menu -->




<div id="main-menu">
	<ul id="burger-menu" class="toggle-desktop toggleit vertical menu modern" data-pane-index="0">
		<li class="burger-menu__item accueil">
			
			<a href="/" class="main-menu accueil">
				Accueil
			</a>
		</li>

		<li class="burger-menu__item cotations">
			<a class="main-menu">
				Bourse
			</a>
			<ul class="vertical menu ssmenus-secondary">
				<li class="ssmenu__title--secondary">
					<a class="secondary-link">Cours de A à Z</a>
					<ul class="vertical menu">
						<li><a href="/actions/paris?marketId=99">Paris - SRD</a></li>
						<li><a href="/actions/paris?marketId=-1&amp;indexId=39991">Paris - CAC40</a></li>
						<li><a href="/actions/paris?marketId=8">Paris - Euronext Growth</a></li>
						<li><a href="/actions/paris?marketId=9">Paris - Euronext Access</a></li>
						<li><a href="/actions/new-york">New York</a></li>
						<li><span class="gothere L1f4a42cb464f49c21f41c1c3c543484843c2 ">Bruxelles</span></li>
						<li><span class="gothere L1f4a42cb464f49c21f4a4ec2cb43c14b4a4e ">Amsterdam</span></li>
					</ul>
				</li>
				<li class="ssmenu__title--secondary">
					<a class="secondary-link">Palmarès</a>

					<ul class="vertical menu">
						<li><a href="/palmares/paris">Paris</a></li>
						<li><span class="gothere L1fc04a484e4ac143c21f4943cc1ec64fc147 ">New York</span></li>
						<li><span class="gothere L1fc04a484e4ac143c21f41c1c3c543484843c2 ">Bruxelles</span></li>
						<li><span class="gothere L1fc04a484e4ac143c21f4a4ec2cb43c14b4a4e ">Amsterdam</span></li>
						<li><span class="gothere L1f4a42cb464f49c21f44c14a4942431e424fcb4343c21ecc4a48481ec2cbc14343cb ">Fran&#231;aises &#224; New York</span></li>
					</ul>
				</li>
				<li class="ssmenu__title--secondary">
					<a class="secondary-link">Le coin du Trader</a>
					<ul class="vertical menu">
						<li><span class="gothere L1fc04a484e4ac143c21fc44f48c34e43c21e4a494fc14e4ac3c5 ">Volumes anormaux</span></li>
						<li><span class="gothere L1fc04a484e4ac143c21fc44a4843c3c1c21e4843c21ec048c3c21e4342454a494c4343c2 ">Volumes importants</span></li>
					</ul>
				</li>
				<li class="ssmenu__title--secondary">
					<a class="secondary-link">Cotations</a>
					<ul class="vertical menu">
						<li><a href="/indices">Indices</a></li>
						<li><a href="/devises">Devises</a></li>
					</ul>
				</li>
				<li class="ssmenu__title--secondary">
					<a class="secondary-link">Matières Premières</a>
					<ul class="vertical menu">
						<li><span class="gothere L1f4e4acb4643c143c21ec0c1434e4643c143c21f424fc3c1c21f41c14349cb1e35b220202026242c2c2b202618bcb11945cb4e48 ">Brent</span></li>
						<li><span class="gothere L1f4e4acb4643c143c21ec0c1434e4643c143c21f424fc3c1c21f4f4942431e4b1e4fc11e35bb202020212c2b2c20212418b2b51945cb4e48 ">Once d&#39;Or</span></li>
					</ul>
				</li>
				<li class="ssmenu__title--secondary">
					<a class="secondary-link">Vidéos</a>
                    <ul class="vertical menu">
                        <li><span class="gothere L1fc4464b434fc21f4e4ac1424543c2 ">Point des march&#233;s</span></li>
                        <li><span class="gothere L1fc4464b434fc21fc04f4b424ac2cbc21e43c3c14fc0432a1e414fc3c1c243 ">Podcasts Europe1 Bourse</span></li>
                        <li><span class="gothere L1fc4464b434fc21f4149c01ec04ac146414ac21e434ac2c6 ">BNP Paribas Easy</span></li>
                    </ul>
				</li>
			</ul>
		</li>

		<li class="burger-menu__item actualites">
			<a class="main-menu">
				Actualités
			</a>

			<ul class="vertical menu ssmenus-secondary">
				<li class="ssmenu__title--secondary">
					<a class="secondary-link">Bourse</a>
					<ul class="vertical menu">
						<li><span class="gothere L1f4a4c43494b4a1e414fc3c1c24643c11f ">Agenda</span></li>
						<li><span class="gothere L1f46494b464243c21f4a42cbc34a4846cb43c21f4943ccc21f424a421e2b201eb4312020202223202020202518b4311945cb4e48 ">Point des march&#233;s</span></li>
						<li><span class="gothere L1f4a42cbc34a4846cb43c21f4ac446c21e41c14f4743c1c2 ">Recos Analystes</span></li>
						<li><span class="gothere L1f4a42cbc34a4846cb43c21f44c14a4942431f ">France</span></li>
						<li><span class="gothere L1f4a42cbc34a4846cb43c21f43cb4acbc21ec34946c21f ">Etats-Unis</span></li>
						<li><span class="gothere L1f4a42cbc34a4846cb43c21f43c3c14fc0431f ">Europe</span></li>
						<li><span class="gothere L1f4649cbc14f4bc342cb464f49c2 ">Introductions - IPO</span></li>
						<li><span class="gothere L1f4a42cbc34a4846cb43c21fc24e4a48481e4e464b1e424ac0c2 ">Small&amp;Mid Caps</span></li>
					</ul>
				</li>

				<li class="ssmenu__title--secondary">
					<a class="secondary-link">Economie</a>
					<ul class="vertical menu">
						<li><span class="gothere L1f4a42cbc34a4846cb43c21f43424f494f4e4643 ">Economie</span></li>
						<li><span class="gothere L1f4a42cbc34a4846cb43c21f4e4a42c14f43424f494f4e4643 ">Macro Economie</span></li>
						<li><span class="gothere L1f4b43c446c243c21f4a42cbc34a4846cb43c21f4943ccc2 ">Devises</span></li>
						<li><span class="gothere L1f4a42cbc34a4846cb43c21fc143c3cb43c1c2 ">Reuters</span></li>
						<li><span class="gothere L1f42c1c6c0cb4f1e4e4f49494a4643c21f4a42cbc34a4846cb43c2 ">Crypto-monnaies</span></li>
						<li><span class="gothere L1f4a42cbc34a4846cb43c21f4c4a4843c14643c2 ">Galeries Photos</span></li>
					</ul>
				</li>
				<li class="ssmenu__title--secondary">
					<a class="secondary-link">Editorial</a>
					<ul class="vertical menu">
						<li><span class="gothere L1f4a42cbc34a4846cb43c21f4943ccc21e4bc31e4d4fc3c1 ">Fil info du jour</span></a></li>
						<li><span class="gothere L1f4a42cbc34a4846cb43c21fc1c34e43c3c1c2 ">Rumeurs</span></li>
						<li><span class="gothere L1f4a42cbc34a4846cb43c21f4649cb43c1c44643ccc2 ">Interviews</span></li>
						<li><span class="gothere L1f4b4fc2c24643c1c2 ">Dossiers</span></li>
					</ul>
				</li>
				<li class="ssmenu__title--secondary">
					<a class="secondary-link">Secteurs</a>
					<ul class="vertical menu">
						<li><span class="gothere L1fc24342cb43c3c1c21f46494bc3c2cbc14643 ">Industrie</span></li>
						<li><span class="gothere L1fc24342cb43c3c1c21fc243c1c4464243c2 ">Services</span></li>
						<li><span class="gothere L1fc24342cb43c3c1c21f424f4e4ec34946424acb464f49 ">Communication</span></li>
						<li><span class="gothere L1fc24342cb43c3c1c21f4446494a494243 ">Banque / Finance</span></li>
						<li><span class="gothere L1fc24342cb43c3c1c2 ">Tous les secteurs</span></li>
					</ul>
				</li>
				<li class="ssmenu__title--secondary">
					<a class="secondary-link">Matières Premières</a>

					<ul class="vertical menu">
						<li><span class="gothere L1f4e4acb4643c143c21ec0c1434e4643c143c21f424fc3c1c21f41c14349cb1e35b220202026242c2c2b202618bcb11945cb4e48 ">Brent</span></li>
						<li><span class="gothere L1f4e4acb4643c143c21ec0c1434e4643c143c21f424fc3c1c21f4f4942431e4b1e4fc11e35bb202020212c2b2c20212418b2b51945cb4e48 ">Once d&#39;Or</span></li>
					</ul>
				</li>
				<li class="ssmenu__title--secondary">
					<a class="secondary-link">Elections</a>
					<ul class="vertical menu">
                        <li><span class="gothere L1f43484342cb464f49c21f4ec349464246c04a4843c2 ">Actualit&#233;s des Municipales</span></li>
                        <li><span class="gothere L1f43484342cb464f49c21fc0c143c2464b4349cb4643484843 ">Actualit&#233;s de la Pr&#233;sidentielle</span></li>
					</ul>
					<a class="secondary-link top--margin">Résultats</a>
                    <ul class="vertical menu">
                        <li><span class="gothere L1f43484342cb464f49c21f4ec349464246c04a4843c21fc143c2c348cb4acbc21e21202120 ">R&#233;sultats Municipales 2020</span></li>
                        <li><span class="gothere L1f43484342cb464f49c21fc0c143c2464b4349cb46434848431fc143c2c348cb4acbc21e21202a2c ">R&#233;sultats Pr&#233;sidentielle 2017</span></li>
                    </ul>
				</li>
			</ul>
		</li>

		<li class="burger-menu__item crypto">
			<a class="main-menu" href="/crypto-monnaies/actualites">
				Crypto
			</a>
		</li>

		<li class="burger-menu__item placements">
			<a class="main-menu">
				OPCVM
			</a>
			<ul class="vertical menu ssmenus-secondary">
				<li class="ssmenu__title--secondary">
					<a class="secondary-link">SICAV-FCP</a>
					<ul class="vertical menu">
						<li><span class="gothere L1f4fc042c44e1f ">Accueil</span></li>
						<li><span class="gothere L1f4fc042c44e1fc04a484e4ac143c21f ">Palmar&#232;s</span></li>
						<li><span class="gothere L1f4fc042c44e1fc143424543c14245431f ">Recherche</span></li>
						<li><span class="gothere L1f4fc042c44e1fc246424ac41ec243484342cb2a2020 ">Select 100</span></li>
						<li><span class="gothere L1fcbc14a424743c1c2 ">Trackers</span></li>
					</ul>
				</li>
				<li class="ssmenu__title--secondary">
					<a class="secondary-link">Actualités</a>
					<ul class="vertical menu">
						<li><span class="gothere L1f4fc042c44e1f4a42cbc34a4846cb43c21f4943ccc21f ">Actualit&#233;s</span></li>
						<li><span class="gothere L1f4fc042c44e1f4a42cbc34a4846cb43c21f424f49c2434648c21f ">Conseils SICAV</span></li>
						<li><span class="gothere L1f4fc042c44e1f4a42cbc34a4846cb43c21f4649cb43c1c44643ccc21f ">Interviews g&#233;rants</span></li>
					</ul>
				</li>
				<li class="ssmenu__title--secondary">
					<a class="secondary-link">Vidéos</a>
                    <ul class="vertical menu">
                        <li><span class="gothere L1f4fc042c44e1fc4464b434fc21f4446494a4942431ec143c2c04f49c24a4148431e43424f44461e4649c443c2cb46c2c2434e4349cbc2 ">Ecofi ISR</span></li>
                    </ul>
				</li>
			</ul>
		</li>

		<li class="burger-menu__item pdbourse">
			<a class="main-menu">
				Dérivés
			</a>
			<ul class="vertical menu ssmenus-secondary">
				<li class="ssmenu__title--secondary">
					<a class="secondary-link">Produits</a>

					<ul class="vertical menu">
						<li><span class="gothere L1fc0c14f4bc346cbc21e4b431e414fc3c1c2431fc143424543c1424543 ">Palmar&#232;s Produits de Bourse</span></li>
						<li><a href="/produits-de-bourse/warrants/recherche">Warrants</a></li>
						<li><a href="/produits-de-bourse/turbos/recherche">Turbos</a></li>
						<li><span class="gothere L1fc0c14f4bc346cbc21e4b431e414fc3c1c2431f4243c1cb464446424acbc21e4843c44643c11fc143424543c1424543 ">Certificats Levier</span></li>
						<li><span class="gothere L1fc0c14f4bc346cbc21e4b431e414fc3c1c2431f4243c1cb464446424acbc21e4649c443c2cb46c2c2434e4349cb1fc143424543c1424543 ">Certificats Investissements</span></li>
					</ul>
				</li>
				<li class="ssmenu__title--secondary">
					<a class="secondary-link" data-index="4">Conseils</a>

					<ul class="vertical menu">
						<li><span class="gothere L1fc0c14f4bc346cbc21e4b431e414fc3c1c2431f4a42cbc34a4846cb43c21f424f49c2434648c2 ">Conseils Produits de bourse</span></li>
					</ul>
				</li>
				<li class="ssmenu__title--secondary">
					<a class="secondary-link" data-index="5">Statistiques</a>
					<ul class="vertical menu">
						<li><span class="gothere L1fc0c14f4bc346cbc21e4b431e414fc3c1c2431fc2cb4acb46c2cb46cac343c21fc44ac1464acb464f491f ">Palmar&#232;s</span></li>
						<li><span class="gothere L1fc0c14f4bc346cbc21e4b431e414fc3c1c2431fc2cb4acb46c2cb46cac343c21f424ac046cb4ac3c51e4342454a494c43c21f ">Les plus &#233;chang&#233;s</span></li>
						<li><span class="gothere L1fc0c14f4bc346cbc21e4b431e414fc3c1c2431fc2cb4acb46c2cb46cac343c21f424ac046cb4ac3c51e4342454a494c43c21e434e43cbcb43c3c1c21f ">Par &#233;metteur</span></li>
					</ul>
				</li>
			</ul>
		</li>

		<li class="burger-menu__item cfd">
			<a class="main-menu" href="/cfd-bourse">
				CFD
			</a>
		</li>

		<li class="burger-menu__item">
			<a class="main-menu">
				Patrimoine
			</a>
			<ul class="vertical menu ssmenus-secondary">
				<li class="ssmenu__title--secondary">
					<a class="secondary-link">L'argent et vous</a>
					<ul class="vertical menu">
						<li><span class="gothere L45cbcbc0c22d1f1f4ac14c4349cb19414fc3c1c24643c119424f4e1f" target="_blank">Accueil</span></li>
						<li><span class="gothere L45cbcbc0c22d1f1f4ac14c4349cb19414fc3c1c24643c119424f4e1fcac34fcb464b464349" target="_blank">Quotidien</span></li>
						<li><a href="https://argent.boursier.com/immobilier" target="_blank">Immobilier</a></li>
						<li><a href="https://argent.boursier.com/impots" target="_blank">Impôts</a></li>
						<li><a href="https://argent.boursier.com/epargne" target="_blank">Epargne</a></li>
						<li><span class="gothere L45cbcbc0c22d1f1f4ac14c4349cb19414fc3c1c24643c119424f4e1fc04ac2c2464f49" target="_blank">Passion</span></li>
					</ul>
				</li>
			</ul>
		</li>

		<li class="burger-menu__item learning">
			<a class="main-menu">
				Learning
			</a>
			<ul class="vertical menu ssmenus-secondary">
				<li class="ssmenu__title--secondary">
					<a href="" class="secondary-link toe" data-index="2">Boursier.com Learning</a>
					<ul class="vertical menu">
						<li><span class="gothere L1f4cc3464b43 toe">Accueil</span></li>
						<li><span class="gothere L1f4cc3464b431f4b4341c3cb43c11e43491e414fc3c1c243 toe">Novice</span></li>
						<li><span class="gothere L1f4cc3464b431fc2431ec043c1444342cb464f494943c11e43491e414fc3c1c243 toe">Avanc&#233;</span></li>
						<li><span class="gothere L1f4cc3464b431f4b43c4434946c11ecbc14a4b43c11e43491e414fc3c1c243 toe">Expert</span></li>
						<li><span class="gothere L1f4cc3464b431fcb43484342454ac14c434e4349cb toe">Guides Bourse Gratuits</span></li>
					</ul>
				</li>
			</ul>
		</li>

		<li class="burger-menu__item forums">
			<a class="main-menu">
				Forum
			</a>
			<ul class="vertical menu ssmenus-secondary">
				<li class="ssmenu__title--secondary">
					<a class="secondary-link" data-index="0">Réactions sur...</a>
					<ul class="vertical menu">
						<li><span class="gothere L1f444fc1c34e ">Toute l&#39;actualit&#233;</span></li>
						<li><span class="gothere L1f444fc1c34e1f4a42cbc34a4846cb43c21f414fc3c1c243 ">Bourse, Finance</span></li>
						<li><span class="gothere L1f444fc1c34e1f4a42cbc34a4846cb43c21f4c434943c14a4843c2 ">Actualit&#233; G&#233;n&#233;rale</span></li>
						<li><span class="gothere L1f444fc1c34e1f4a42cbc34a4846cb43c21f43424f494f4e4643 ">Economie</span></li>
						<li><span class="gothere L1f444fc1c34e1f4a42cbc34a4846cb43c21f4649cb43c1c44643ccc2 ">Interviews</span></li>
					</ul>
				</li>

				<li class="ssmenu__title--secondary">
					<a class="secondary-link" data-index="1">Thématiques</a>

					<ul class="vertical menu">
						<li><span class="gothere L1f444fc1c34e1fcb45434e4acb46cac3431f4a494a48c6c2431ecb4342454946cac343 ">Analyse Technique</span></li>
						<li><span class="gothere L1f444fc1c34e1fcb45434e4acb46cac3431f4649cbc14f4bc342cb464f491e414fc3c1c243 ">Introductions en Bourse</span></li>
						<li><span class="gothere L1f444fc1c34e1fcb45434e4acb46cac3431f4b4341c3cb43c1 ">D&#233;butant en Bourse</span></li>
						<li><span class="gothere L1f444fc1c34e1fcb45434e4acb46cac3431f43424f494f4e4643 ">Economie</span></li>
						<li><span class="gothere L1f444fc1c34e1fcb45434e4acb46cac3431f464e4e4f4146484643c11ec0484a42434e4349cb ">Immobilier, Patrimoine, OPCVM</span></li>
						<li><span class="gothere L1f444fc1c34e1fcb45434e4acb46cac3431f4146c2cbc14fcb ">Le Bistrot du Boursier</span></li>
					</ul>
				</li>

				<li class="ssmenu__title--secondary">
					<a class="secondary-link" data-index="0">Sujets les plus commentés</a>

					<ul class="vertical menu">
							<li><span class="gothere L1f444fc1c34e1fc44a4843c3c144c11f43c3c14fc0484ac24e4a1f43c3c14fc0484ac24e4a1ec44a1ec0c348c243c11e4621262220262b1945cb4e48">Europlasma va pulser. <span class="icon2016-comment-1">3402</span></span></li>
							<li><span class="gothere L1f444fc1c34e1f4a42cbc34a4846cb43c21f4c434943c14a4843c21f454fc34843cbcb431e424f494446c14e431e48431e41464a46c21e4b431e481e4349cac343cb431e43c2cb464e431e481e4ac44f424acb1e4b431e444648484f491e462220212c222a1945cb4e48">Houlette confirme le biais de l&#39;enqu&#234;te, estime l&#39;avocat de Fillon <span class="icon2016-comment-1">115</span></span></li>
							<li><span class="gothere L1f444fc1c34e1fcb45434e4acb46cac3431f43424f494f4e46431fc0c143c2464b4349cb46434848431e4a4e43c146424a4649431e4d4f431e41464b43491ec0c143494b1e4b431e481e4ac44a4942431ec2c3c11e4b4f494a484b1ecbc1c34ec01e46222021242b241945cb4e48">Pr&#233;sidentielle am&#233;ricaine : Joe Biden prend de l&#39;avance sur Donald Trump <span class="icon2016-comment-1">144</span></span></li>
							<li><span class="gothere L1f444fc1c34e1fc44a4843c3c144c11f4a4e4f43414a1f4a4e4f43414a1e434848431ec0c348c2431e462220202c242a1945cb4e48">Amoeba : elle pulse. <span class="icon2016-comment-1">246</span></span></li>
					</ul>
				</li>
				<li class="ssmenu__title--secondary">

					<a class="secondary-link" data-index="0">Valeurs actives</a>

					<ul class="vertical menu">
							<li>
								<span class="gothere L1f4a42cb464f49c21f444fc1c34e1fc44f48cb4a48464a1eb43120202a2a26262323252518b4311945cb4e48 ">Voltalia</span>
							</li>
							<li>
								<span class="gothere L1f4a42cb464f49c21f444fc1c34e1f424a421e2b201eb4312020202223202020202518b4311945cb4e48 ">CAC 40</span>
							</li>
							<li>
								<span class="gothere L1f4a42cb464f49c21f444fc1c34e1f4a46c141c3c21e4cc14fc3c01e43c51e434a4bc21eb9b8202020202122232a262018b4311945cb4e48 ">Airbus Group (ex-EADS)</span>
							</li>
							<li>
								<span class="gothere L1f4a42cb464f49c21f444fc1c34e1f43c3c14fc0484ac24e4a1eb43120202020202b2b252a2018b4311945cb4e48 ">Europlasma</span>
							</li>
							<li>
								<span class="gothere L1f4a42cb464f49c21f444fc1c34e1f4e42c045c61e434943c14cc61eb43120202a2a2c2b2122212618b4311945cb4e48 ">McPhy Energy</span>
							</li>
							<li>
								<span class="gothere L1f4a42cb464f49c21f444fc1c34e1fcb45431e41484f424742454a46491e4cc14fc3c01e43c51e48434a4b4e434b464a1eb43120202a2a20232224222418b4311945cb4e48 ">The Blockchain Group (ex-Leadmedia)</span>
							</li>
							<li>
								<span class="gothere L1f4a42cb464f49c21f444fc1c34e1f41464fc2c64943c51eb43120202a2a20202326222218b4311945cb4e48 ">Biosynex</span>
							</li>
					</ul>
				</li>
			</ul>
		</li>

		<li class="burger-menu__item privileges">
			<a class="premium main-menu" data-index="0">Privilèges</a>
			<ul class="vertical menu ssmenus-secondary">
				<li class="ssmenu__title--secondary">
					<a class="secondary-link" data-index="1">Articles</a>

					<ul class="vertical menu">
						<li><span class="gothere L1fc0c146c44648434c43c2 ">Accueil Privil&#232;ges</span></li>
						<li><span class="gothere L1fc0c146c44648434c43c21f424f49c2434648c21fc143424f1e4bc31e4d4fc3c11f2a ">La Reco du Jour</span></li>
						<li><span class="gothere L1fc0c146c44648434c43c21f424f49c2434648c21f4a42cb464f49c21f2a ">Conseils Actions</span></li>
						<li><span class="gothere L1fc0c146c44648434c43c21f4649444fc14e4acb464f49c21f43c54248c3c246c443c21f2a ">Infos Exclusives</span></li>
					</ul>
				</li>

				<li class="ssmenu__title--secondary">
					<a class="secondary-link" data-index="2">Opportunités</a>


					<ul class="vertical menu">
						<li class="mag-premium">
							<span class="gothere L1fc0c146c44648434c43c21f4b4fcc49484f4a4b1f4fc0c04fc1cbc34946cb43c21f484ac2cb1fc04b44">N°1245 - le 23/06/2020</span>
							<img alt="Lettre Opportunités Bourse" src="/UI/v5/images/core/menu-premium_mag-cover.png" />
							<span class="gothere L1fc0c146c44648434c43c21f4b4fcc49484f4a4b1f4fc0c04fc1cbc34946cb43c21f484ac2cb1fc04b44 btn-more premium">
								<span class="bt-label">Télécharger</span>
							</span>
						</li>
					</ul>
				</li>

				<li class="ssmenu__title--secondary">
					<a class="secondary-link" data-index="3">Portefeuilles</a>

					<ul class="vertical menu">
						<li class="portfolio">
										<span class="gothere L1fc0c146c44648434c43c21fc04fc1cb434443c346484843c21f4b43444349c24644">
				<span class="indice-title">
					Perf. depuis le 10/11/1991
				</span>
				<strong class="indice-box">
					<span class="s-btn iconm-defensif">
						D&#233;fensif
						<b class="up">+405,63%
					</span>
					<span class="indice">Indice CAC 40 <span class="up">+189,73%</span></span>
				</strong>
			</span>

										<span class="gothere L1fc0c146c44648434c43c21fc04fc1cb434443c346484843c21f43cac346484641c143">
				<span class="indice-title">
					Perf. depuis le 30/06/2001
				</span>
				<strong class="indice-box">
					<span class="s-btn iconm-equilibre">
						Equilibr&#233;
						<b class="up">+198,33%
					</span>
					<span class="indice">Indice CAC 40 <span class="down">-9,75%</span></span>
				</strong>
			</span>

										<span class="gothere L1fc0c146c44648434c43c21fc04fc1cb434443c346484843c21f4bc6494a4e46cac343">
				<span class="indice-title">
					Perf. depuis le 02/12/2015
				</span>
				<strong class="indice-box">
					<span class="s-btn iconm-dynamique">
						Dynamique
						<b class="up">+25,91%
					</span>
					<span class="indice">Indice CAC 40 <span class="up">+0,51%</span></span>
				</strong>
			</span>


							<span class="btn-more premium gothere L1fc0c146c44648434c43c21fc04fc1cb434443c346484843c2">
								<span class="bt-label">Découvrez nos 3 portefeuilles</span>
								<span class="bt-icon icon2016-right-small"></span>
							</span>
						</li>
					</ul>
				</li>
				<li class="ssmenu__title--secondary shortlist-donnees">
					<a class="secondary-link" data-index="0">données boursières</a>
					<ul class="vertical menu">
						<li>
							<a class="secondary-link" data-index="1">Données boursières</a>
							<ul class="vertical menu">
								<li><span class="gothere L1fc0c146c44648434c43c21f4649444fc14e4acb464f49c21f4a42454acbc21e4649c2464b43c1c21f2a ">Achats des Insiders</span></li>
								<li><span class="gothere L1fc0c146c44648434c43c21f4649444fc14e4acb464f49c21fc44a4843c3c1c21e4fc0434a414843c2 ">Valeurs Op&#233;ables</span></li>
							</ul>
						</li>
					</ul>
				</li>
			</ul>
		</li>
	</ul>
	<span class="btn-close icon2016-close" id="close-menu"></span>
</div>

		<script>
			(function () {
				var active = "accueil";
				$("#burger-menu li[class~=" + active + "] a").addClass("on");
			})();
		</script>
		<!-- /Menu -->

		<div class="quick-menu toggle-desktop">
			<a data-target="highlight" class="active">A la une</a>
			<a data-target="live">Fil info</a>
			<a data-target="mychoice">Listes/PF</a>
			<a data-target="privileges">Privileges</a>
		</div>

	</header><!-- /Header -->

		<div id="banner-wrapper">
			<div id="banner">
				<div>
					<!-- Generic > Mega Bannière --><div id="ad-anx-banner">
</div>
				</div>
			</div><!-- /.banner -->
		</div><!-- /#banner-wrapper -->

	<!-- barre d'indices [ a mettre "V5/_LayoutHeaderMarket" ] -->
	
	<!-- Contenu de la page -->


	 






	

<div data-id="date-breadcrumb" id="date-breadcrumb">
	<div class="wrapper">
		<time datetime="2020-06-26T10:48:58">Vendredi 26 juin 2020, 10h48 |</time>
		<a href="/agenda-boursier/0/" class="daily-schedule"><strong>L'agenda du jour</strong> <span class="icon2016-agenda"></span></a>
	</div>  	 	
</div>

	<section id="actus">
		<div class="wrapper">
			<div id="row_1">
				<div class="custom-grid grid-12">
					<div class="cg cg-3 cg-medium-half cg-small-full">
						 
						
<div id="headlines" data-target="highlight">
				<article id="une" class="dr-mid-full ">
					<a href="/actualites/reuters/aeronautique-la-cgt-appelle-a-une-journee-de-mobilisation-pour-l-emploi-244935.html">
						<h2 class="h1">Aéronautique : La CGT appelle à une journée de mobilisation pour l'emploi</h2>

						<div class="visual-wrapper focus-image">
							<img class="visual" src="//cdn-static.boursier.com/illustrations/feeds/reuters/aeronautique-la-cgt-appelle-a-une-journee-de-mobilisation-pour-l-emploi-small.jpg" alt="A&#233;ronautique&amp;nbsp;: La CGT appelle &#224; une journ&#233;e de mobilisation pour l&#39;emploi" />
						</div>

						<div class="data">
							<p>
								La CGT, première organisation syndicale représentative de la filière aéronautique en Occitanie, appelle à une journée d'action et de mobilisation dans la région le 9 juillet pour défendre l'emploi dans ce secteur très impacté par la crise  <span class="icon2016-comment-1">1</span> 							</p>
						</div>
					</a>
				</article>
				<article class="content ">
					<a href="/actualites/news/air-france-klm-klm-obtient-enfin-l-aide-de-l-etat-neerlandais-826019.html">
						<div class="visual-wrapper">
							<img class="visual" src="//cdn-static.boursier.com/illustrations/photos/200/air-france-klm-liberation-perte-300-millions-euros-2011-500-millions-2012.jpg" alt="&lt;b&gt;Air France KLM&lt;/b&gt;&amp;nbsp;: KLM obtient enfin l&#39;aide de l&#39;Etat n&#233;erlandais" />
						</div>

						<div class="data">
							<h2 class="h3">Air France KLM : KLM obtient enfin l'aide de l'Etat néerlandais</h2>
							<p>
								3,4 milliards d'euros pour surmonter la crise...  <span class="icon2016-comment-1">1</span> 							</p>
						</div>
					</a>
				</article>
				<article class="content ">
					<a href="/opcvm/actualites/interviews/ce-qui-compte-c-est-la-soutenabilite-du-dividende-5163.html">
						<div class="visual-wrapper">
							<img class="visual" src="//cdn-static.boursier.com/illustrations/photos/200/boscher2-fidelity.jpg" alt="&lt;b&gt;&quot;Ce qui compte, c&#39;est la soutenabilit&#233; du dividende&quot;&lt;/b&gt;" />
						</div>

						<div class="data">
							<h2 class="h3">"Ce qui compte, c'est la soutenabilité du dividende"</h2>
							<p>
								Interview de Romain Boscher, Responsable mondial des investissements en actions de Fidelity International. 							</p>
						</div>
					</a>
				</article>
				<article class="content ">
					<a href="/actualites/economie/coronavirus-pour-eviter-une-seconde-vague-le-gouvernement-veut-traquer-le-virus-44262.html">
						<div class="visual-wrapper">
							<img class="visual" src="//cdn-static.boursier.com/illustrations/photos/200/olivier-veran.jpg" alt="Coronavirus&amp;nbsp;: pour &#233;viter une seconde vague, le gouvernement veut &quot;traquer le virus&quot;" />
						</div>

						<div class="data">
							<h2 class="h3">Coronavirus : pour éviter une seconde vague, le gouvernement veut "traquer le virus"</h2>
							<p>
								Dans un entretien au 'Monde', le ministre de la Santé Olivier Véran a notamment annoncé qu'environ 1,3 million de personnes recevront un "bon" de l'Assurance maladie leur permettant d'effectuer un test virologique...  <span class="icon2016-comment-1">15</span> 							</p>
						</div>
					</a>
				</article>
				<article class="content ">
					<a href="/actualites/news/bouygues-grimpe-avec-la-belle-operation-dans-les-telecoms-826035.html">
						<div class="visual-wrapper">
							<img class="visual" src="//cdn-static.boursier.com/illustrations/photos/200/bouygues-telecom-logo.jpg" alt="&lt;b&gt;Bouygues&lt;/b&gt; grimpe avec la belle op&#233;ration dans les t&#233;l&#233;coms" />
						</div>

						<div class="data">
							<h2 class="h3">Bouygues grimpe avec la belle opération dans les télécoms</h2>
							<p>
								Protocole d'exclusivité avec le Crédit Mutuel pour l'acquisition de l'opérateur alternatif Euro-Information Telecom...  <span class="icon2016-comment-1">1</span> 							</p>
						</div>
					</a>
				</article>
	<div class="quick-menu toggle-desktop">
		<a data-target="live" class="btn-more">
			<span class="bt-label">Accédez au fil info</span>
			<span class="bt-icon icon2016-right-small"></span>
		</a>
	</div>
</div>

							
									<div class="box ads"><!-- Generic > Investisseur --><div id="ad-anx-partner-button">
</div></div>
								
<div id="tips" data-target="highlight">
	<h2>A ne pas manquer</h2>
		<ul class="hot-news">
				<li>
					<a href="/actualites/news/impots-tout-savoir-sur-le-dispositif-pinel-824969.html">
						Impôts : tout savoir sur le dispositif Pinel !
					</a>
				</li>
				<li>
					<a href="/actions/actualites/news/focus-home-interactive-annonces-saluees-826038.html">
						Focus Home Interactive : annonces saluées !
					</a>
				</li>
				<li>
					<a href="/actions/actualites/news/bouygues-grimpe-avec-la-belle-operation-dans-les-telecoms-826035.html">
						Bouygues grimpe avec la belle opération dans les télécoms
					</a>
				</li>
				<li>
					<a href="/actions/actualites/news/wirecard-ey-dans-l-oeil-du-cyclone-826022.html">
						Wirecard : E&Y dans l'oeil du cyclone
					</a>
				</li>
		</ul>
</div>



						

						
						
							<div id="morningAdvice" class="col col-12 w-background" data-target="highlight" data-href="child">
								<h2>Le dernier conseil Bourse</h2>

								<h3>
									Seb : des réalisations moins dégradées que prévu...

									<small>
										Ce matin à 10h29
									</small>
								</h3>

								<p>
									Trimestre. Seb traverse la crise que nous connaissons sans trop de casse. La présence géographique diversifiée de l'entreprise se traduit par un ...
								</p>

								<a href="/actions/actualites/conseils/seb-des-realisations-moins-degradees-que-prevu-42868.html" class="btn-more btn-self border premium">
									<span class="bt-label">Voir le conseil</span>
									<span class="bt-icon icon2016-right-small"></span>
								</a>
							</div>
						
						

					</div>
					<div class="cg cg-2 cg-medium-half cg-small-full border" id="actu-wrapper">
								<div data-id="listing-home" id="listing-home" data-target="live">
		<div class="outer">
			<div class="title-link">
				<h2 class="title">Fil info</h2>
				<a href="/actualites/news-du-jour" class="btn-more">
					<span class="bt-label">Tout le fil</span>
					<span class="bt-icon icon2016-right-small"></span>
				</a>
			</div>

			<div class="news-list">
				<div class="item-wrapper" ss-container>
						<div class="item item--type-economie">
							<time class="date" datetime="2020-06-26T10:41:00">10h41</time>
							<div class="data">
									<div class="text-media">
										<div class="text">
											<a href="/actualites/economie/l-emploi-premiere-preoccupation-des-jeunes-en-france-44267.html">L'emploi, première préoccupation des jeunes en France</a>
										</div>
										<div class="media ">
											<a href="/actualites/economie/l-emploi-premiere-preoccupation-des-jeunes-en-france-44267.html">
												<img width="90" class="visual ea_image" src="//cdn-static.boursier.com/illustrations/photos/100/jeunes-emploi-formation.jpg" data-ea-parsed="true" data-ea-dsp="a" alt="L&#39;emploi, premi&#232;re pr&#233;occupation des jeunes en France" />
											</a>
										</div>
									</div>									
							</div>
						</div>
						<div class="item item--type-news priv">
							<time class="date" datetime="2020-06-26T10:39:00">10h39</time>
							<div class="data">
									<a href="/actions/actualites/news/seche-environnement-coup-de-chaud-826042.html">

										<span class="text">
											Séché Environnement : coup de chaud
										</span>
											<img class="icon partner-icon" src="/Content/img/ico-snmd.png" alt="Small&Mid Cap">
									</a>												</div>
								<span class="iconm-lock"></span>
						</div>
						<div class="item item--type-reuters">
							<time class="date" datetime="2020-06-26T10:37:28">10h37</time>
							<div class="data">
									<a href="/actualites/reuters/taxe-numerique-londres-paris-rome-et-madrid-proposent-une-approche-graduelle-244938.html">

										<span class="text">
											Taxe numérique: Londres, Paris, Rome et Madrid proposent une "approche graduelle"
										</span>
									</a>												</div>
						</div>
						<div class="item item--type-reuters">
							<time class="date" datetime="2020-06-26T10:37:04">10h37</time>
							<div class="data">
									<a href="/actualites/reuters/les-actions-bien-orientees-mais-la-prudence-s-impose-toujours-244937.html">

										<span class="text">
											Les actions bien orientées mais la prudence s'impose toujours
										</span>
									</a>												</div>
						</div>
						<div class="item item--type-news">
							<time class="date" datetime="2020-06-26T10:35:00">10h35</time>
							<div class="data">
									<a href="/actualites/news/impots-tout-savoir-sur-le-dispositif-pinel-824969.html">

										<span class="text">
											Impôts : tout savoir sur le dispositif Pinel !
										</span>
									</a>												</div>
						</div>
						<div class="item item--type-reuters">
							<time class="date" datetime="2020-06-26T10:32:47">10h32</time>
							<div class="data">
									<a href="/actualites/reuters/macron-a-nouakchott-mardi-pour-le-sommet-g5-sahel-244936.html">

										<span class="text">
											Macron à Nouakchott mardi pour le sommet G5 Sahel
										</span>
									</a>												</div>
						</div>
						<div class="item item--type-news">
							<time class="date" datetime="2020-06-26T10:31:00">10h31</time>
							<div class="data">
									<a href="/actions/actualites/news/focus-home-interactive-des-resultats-salues-826039.html">

										<span class="text">
											Focus Home Interactive : des résultats salués
										</span>
											<img class="icon partner-icon" src="/Content/img/ico-snmd.png" alt="Small&Mid Cap">
									</a>												</div>
						</div>
						<div class="item item--type-conseils priv">
							<time class="date" datetime="2020-06-26T10:29:00">10h29</time>
							<div class="data">
									<a href="/actions/actualites/conseils/des-realisations-moins-degradees-que-prevu-42868.html">

										<span class="text">
											<strong>Seb</strong> : des réalisations moins dégradées que prévu...
										</span>
									</a>												</div>
								<span class="iconm-lock"></span>
						</div>
						<div class="item item--type-news">
							<time class="date" datetime="2020-06-26T10:29:00">10h29</time>
							<div class="data">
									<a href="/actions/actualites/news/metabolic-explorer-peu-de-reaction-826041.html">

										<span class="text">
											Metabolic Explorer : peu de réaction
										</span>
											<img class="icon partner-icon" src="/Content/img/ico-snmd.png" alt="Small&Mid Cap">
									</a>												</div>
						</div>
						<div class="item item--type-news hot">
							<time class="date" datetime="2020-06-26T10:21:00">10h21</time>
							<div class="data">
									<a href="/actualites/news/marches-des-avis-d-analystes-mise-a-jour-826020.html">

										<span class="text">
											Marchés : des avis d'analystes (mise à jour)
										</span>
									</a>												</div>
						</div>
						<div class="item item--type-reuters">
							<time class="date" datetime="2020-06-26T10:19:00">10h19</time>
							<div class="data">
									<a href="/actualites/reuters/aeronautique-la-cgt-appelle-a-une-journee-de-mobilisation-pour-l-emploi-244935.html">

										<span class="text">
											Aéronautique : La CGT appelle à une journée de mobilisation pour l'emploi
 <span class="icon2016-comment-1">1</span> 										</span>
									</a>												</div>
						</div>
						<div class="item item--type-reuters">
							<time class="date" datetime="2020-06-26T10:18:22">10h18</time>
							<div class="data">
									<a href="/actualites/reuters/hm-accuse-une-perte-un-peu-plus-importante-que-prevu-au-t2-244934.html">

										<span class="text">
											H&M accuse une perte un peu plus importante que prévu au T2
										</span>
									</a>												</div>
						</div>
						<div class="item item--type-news hot">
							<time class="date" datetime="2020-06-26T10:17:00">10h17</time>
							<div class="data">
									<a href="/actualites/news/restez-informes-de-l-actualite-avec-notre-offre-a-1-euro-le-premier-mois-suivez-minute-par-minute-les-conseils-de-nos-specialistes-818547.html">

										<span class="text">
											Restez informés de l'actualité avec notre offre à 1 euro le premier mois, suivez minute par minute les conseils de nos spécialistes.
										</span>
									</a>												</div>
						</div>
						<div class="item item--type-news">
							<time class="date" datetime="2020-06-26T10:07:00">10h07</time>
							<div class="data">
									<a href="/actions/actualites/news/bassac-arguments-en-soutien-826040.html">

										<span class="text">
											Bassac : arguments en soutien
										</span>
											<img class="icon partner-icon" src="/Content/img/ico-snmd.png" alt="Small&Mid Cap">
									</a>												</div>
						</div>
						<div class="item item--type-news">
							<time class="date" datetime="2020-06-26T10:00:00">10h00</time>
							<div class="data">
									<a href="/actualites/news/investir-l-argent-d-un-rachat-d-assurance-vie-en-scpi-825121.html">

										<span class="text">
											Investir l'argent d'un rachat d'assurance vie en SCPI
										</span>
									</a>												</div>
						</div>
						<div class="item item--type-news">
							<time class="date" datetime="2020-06-26T09:58:00">09h58</time>
							<div class="data">
									<a href="/actions/actualites/news/focus-home-interactive-annonces-saluees-826038.html">

										<span class="text">
											Focus Home Interactive : annonces saluées !
										</span>
											<img class="icon partner-icon" src="/Content/img/ico-snmd.png" alt="Small&Mid Cap">
									</a>												</div>
						</div>
						<div class="item item--type-news">
							<time class="date" datetime="2020-06-26T09:52:00">09h52</time>
							<div class="data">
									<a href="/actions/actualites/news/bouygues-grimpe-avec-la-belle-operation-dans-les-telecoms-826035.html">

										<span class="text">
											Bouygues grimpe avec la belle opération dans les télécoms
 <span class="icon2016-comment-1">1</span> 										</span>
									</a>												</div>
						</div>
						<div class="item item--type-reuters">
							<time class="date" datetime="2020-06-26T09:47:19">09h47</time>
							<div class="data">
									<a href="/actualites/reuters/le-pire-de-la-crise-est-passe-estime-lagarde-bce-244933.html">

										<span class="text">
											Le pire de la crise est passé, estime Lagarde (BCE)
 <span class="icon2016-comment-1">3</span> 										</span>
									</a>												</div>
						</div>
						<div class="item item--type-news">
							<time class="date" datetime="2020-06-26T09:44:00">09h44</time>
							<div class="data">
									<a href="/actions/actualites/news/actiplay-plan-de-continuation-en-preparation-826034.html">

										<span class="text">
											Actiplay : plan de continuation en préparation
										</span>
											<img class="icon partner-icon" src="/Content/img/ico-snmd.png" alt="Small&Mid Cap">
									</a>												</div>
						</div>
						<div class="item item--type-news">
							<time class="date" datetime="2020-06-26T09:43:00">09h43</time>
							<div class="data">
									<a href="/actions/actualites/news/ffp-au-vert-826036.html">

										<span class="text">
											FFP : au vert !
										</span>
									</a>												</div>
						</div>
						<div class="item item--type-reuters">
							<time class="date" datetime="2020-06-26T09:41:42">09h41</time>
							<div class="data">
									<a href="/actualites/reuters/amazon-va-acheter-le-specialiste-des-vehicules-autonomes-zoox-244932.html">

										<span class="text">
											Amazon va acheter le spécialiste des véhicules autonomes Zoox
										</span>
									</a>												</div>
						</div>
						<div class="item item--type-news">
							<time class="date" datetime="2020-06-26T09:41:00">09h41</time>
							<div class="data">
									<a href="/actualites/news/la-souscription-de-scpi-a-credit-reste-t-elle-pertinente-825469.html">

										<span class="text">
											La souscription de SCPI à crédit reste-t-elle pertinente ?
										</span>
									</a>												</div>
						</div>
						<div class="item item--type-generales">
							<time class="date" datetime="2020-06-26T09:33:00">09h33</time>
							<div class="data">
									<a href="/opcvm/actualites/generales/treezor-et-idemia-annoncent-le-lancement-de-la-premiere-carte-bancaire-eco-responsable-en-france-826037.html">

										<span class="text">
											Treezor et IDEMIA annoncent le lancement de la première carte bancaire éco-responsable en France
										</span>
									</a>												</div>
						</div>
						<div class="item item--type-news">
							<time class="date" datetime="2020-06-26T09:30:00">09h30</time>
							<div class="data">
									<a href="/actions/actualites/news/encres-dubuit-ag-sans-surprise-a-huis-clos-826030.html">

										<span class="text">
											Encres Dubuit : AG (sans surprise) à huis clos
										</span>
											<img class="icon partner-icon" src="/Content/img/ico-snmd.png" alt="Small&Mid Cap">
									</a>												</div>
						</div>
						<div class="item item--type-news hot">
							<time class="date" datetime="2020-06-26T09:30:00">09h30</time>
							<div class="data">
									<a href="/indices/actualites/news/ouverture-paris-de-nouveau-les-5-000-points-dans-le-viseur-826031.html">

										<span class="text">
											Ouverture Paris : de nouveau les 5.000 points dans le viseur
										</span>
									</a>												</div>
						</div>
						<div class="item item--type-news">
							<time class="date" datetime="2020-06-26T09:27:00">09h27</time>
							<div class="data">
									<a href="/actions/actualites/news/vetoquinol-vive-hausse-826028.html">

										<span class="text">
											Vetoquinol : vive hausse
										</span>
											<img class="icon partner-icon" src="/Content/img/ico-snmd.png" alt="Small&Mid Cap">
									</a>												</div>
						</div>
						<div class="item item--type-reuters">
							<time class="date" datetime="2020-06-26T09:26:18">09h26</time>
							<div class="data">
									<a href="/actualites/reuters/le-pdg-d-adp-n-exclut-pas-des-suppressions-d-emploi-244931.html">

										<span class="text">
											Le PDG d'ADP n'exclut pas des suppressions d'emploi
										</span>
									</a>												</div>
						</div>
						<div class="item item--type-news">
							<time class="date" datetime="2020-06-26T09:23:00">09h23</time>
							<div class="data">
									<a href="/actions/actualites/news/total-montee-en-puissance-de-la-production-de-iara-avec-le-demarrage-du-second-fpso-826033.html">

										<span class="text">
											Total : montée en puissance de la production de Iara avec le démarrage du second FPSO
										</span>
									</a>												</div>
						</div>
						<div class="item item--type-news">
							<time class="date" datetime="2020-06-26T09:15:00">09h15</time>
							<div class="data">
									<a href="/actualites/news/immobilier-10-750-euros-le-metre-carre-a-paris-dernier-record-avant-la-baisse-825951.html">

										<span class="text">
											Immobilier : 10.750 euros le mètre carré à Paris, dernier record avant la baisse ?
										</span>
									</a>												</div>
						</div>
						<div class="item item--type-generales">
							<time class="date" datetime="2020-06-26T09:14:00">09h14</time>
							<div class="data">
									<a href="/actions/actualites/news/azqore-signe-un-partenariat-strategique-avec-le-fournisseur-suisse-de-technologie-financiere-evooq-826032.html">

										<span class="text">
											Azqore signe un partenariat stratégique avec le fournisseur suisse de technologie financière Evooq
										</span>
									</a>												</div>
						</div>
						<div class="item item--type-economie">
							<time class="date" datetime="2020-06-26T09:12:00">09h12</time>
							<div class="data">
									<div class="text-media">
										<div class="text">
											<a href="/actualites/economie/impots-un-montant-a-payer-ou-un-remboursement-a-recevoir-comment-faire-44253.html">Impôts : un montant à payer ou un remboursement à recevoir, comment faire ?</a>
										</div>
										<div class="media ">
											<a href="/actualites/economie/impots-un-montant-a-payer-ou-un-remboursement-a-recevoir-comment-faire-44253.html">
												<img width="90" class="visual ea_image" src="//cdn-static.boursier.com/illustrations/photos/100/dix-euros.jpg" data-ea-parsed="true" data-ea-dsp="a" alt="Imp&#244;ts : un montant &#224; payer ou un remboursement &#224; recevoir, comment faire ?" />
											</a>
										</div>
									</div>									
							</div>
						</div>
						<div class="item item--type-news">
							<time class="date" datetime="2020-06-26T09:12:00">09h12</time>
							<div class="data">
									<a href="/actions/actualites/news/seb-rassure-le-titre-grimpe-826027.html">

										<span class="text">
											SEB rassure, le titre grimpe
										</span>
									</a>												</div>
						</div>
						<div class="item item--type-news">
							<time class="date" datetime="2020-06-26T09:11:00">09h11</time>
							<div class="data">
									<a href="/actions/actualites/news/installux-s-installe-sur-euronext-growth-826029.html">

										<span class="text">
											Installux s'installe sur Euronext Growth
										</span>
											<img class="icon partner-icon" src="/Content/img/ico-snmd.png" alt="Small&Mid Cap">
									</a>												</div>
						</div>
						<div class="item item--type-news hot">
							<time class="date" datetime="2020-06-26T09:01:00">09h01</time>
							<div class="data">
									<a href="/actualites/news/le-cac40-ouvre-en-hausse-de-0-96-826025.html">

										<span class="text">
											Le CAC40 ouvre en hausse de 0,96%
										</span>
									</a>												</div>
						</div>
						<div class="item item--type-news">
							<time class="date" datetime="2020-06-26T08:58:00">08h58</time>
							<div class="data">
									<a href="/actions/actualites/news/dbv-technologies-annonce-un-projet-de-plan-de-restructuration-826026.html">

										<span class="text">
											DBV Technologies annonce un projet de plan de restructuration
										</span>
											<img class="icon partner-icon" src="/Content/img/ico-snmd.png" alt="Small&Mid Cap">
									</a>												</div>
						</div>
						<div class="item item--type-macroeconomie hot">
							<time class="date" datetime="2020-06-26T08:56:00">08h56</time>
							<div class="data">
									<a href="/actualites/macroeconomie/les-menages-retrouvent-le-moral-en-juin-826024.html">

										<span class="text">
											Les ménages retrouvent le moral en juin
										</span>
									</a>												</div>
						</div>
						<div class="item item--type-economie">
							<time class="date" datetime="2020-06-26T08:48:00">08h48</time>
							<div class="data">
									<div class="text-media">
										<div class="text">
											<a href="/actualites/economie/internet-bond-du-trafic-de-30-en-france-pendant-le-confinement-44263.html">Internet : bond du trafic de 30% en France pendant le confinement !</a>
										</div>
										<div class="media ">
											<a href="/actualites/economie/internet-bond-du-trafic-de-30-en-france-pendant-le-confinement-44263.html">
												<img width="90" class="visual ea_image" src="//cdn-static.boursier.com/illustrations/photos/100/video-ligne-netflix.jpg" data-ea-parsed="true" data-ea-dsp="a" alt="Internet : bond du trafic de 30% en France pendant le confinement !" />
											</a>
										</div>
									</div>									
							</div>
						</div>
						<div class="item item--type-news">
							<time class="date" datetime="2020-06-26T08:46:00">08h46</time>
							<div class="data">
									<a href="/actions/actualites/news/wirecard-ey-dans-l-oeil-du-cyclone-826022.html">

										<span class="text">
											Wirecard : E&Y dans l'oeil du cyclone
										</span>
									</a>												</div>
						</div>
						<div class="item item--type-reuters">
							<time class="date" datetime="2020-06-26T08:40:00">08h40</time>
							<div class="data">
									<a href="/actualites/reuters/a-tokyo-le-nikkei-finit-en-hausse-de-plus-de-1-244929.html">

										<span class="text">
											A Tokyo, le Nikkei finit en hausse de plus de 1%
										</span>
									</a>												</div>
						</div>
						<div class="item item--type-reuters">
							<time class="date" datetime="2020-06-26T08:39:13">08h39</time>
							<div class="data">
									<a href="/actualites/reuters/les-valeurs-a-suivre-a-paris-et-en-europe-244930.html">

										<span class="text">
											Les valeurs à suivre à Paris et en Europe
										</span>
									</a>												</div>
						</div>
						<div class="item item--type-news">
							<time class="date" datetime="2020-06-26T08:32:00">08h32</time>
							<div class="data">
									<a href="/actions/actualites/news/air-france-klm-sous-les-resistances-une-consolidation-est-probable-at-756776.html">

										<span class="text">
											Air France KLM : sous les résistances, une consolidation est probable (AT)
 <span class="icon2016-comment-1">17</span> 										</span>
									</a>												</div>
						</div>
						<div class="item item--type-news hot">
							<time class="date" datetime="2020-06-26T08:30:00">08h30</time>
							<div class="data">
									<a href="/indices/actualites/news/preouverture-paris-le-cac40-de-nouveau-sujet-a-un-regain-d-optimisme-826021.html">

										<span class="text">
											Préouverture Paris : le CAC40 de nouveau sujet à un regain d'optimisme
 <span class="icon2016-comment-1">1</span> 										</span>
									</a>												</div>
						</div>
						<div class="item item--type-economie">
							<time class="date" datetime="2020-06-26T08:22:00">08h22</time>
							<div class="data">
									<div class="text-media">
										<div class="text">
											<a href="/actualites/economie/coronavirus-pour-eviter-une-seconde-vague-le-gouvernement-veut-traquer-le-virus-44262.html">Coronavirus : pour éviter une seconde vague, le gouvernement veut "traquer le virus"</a>
										</div>
										<div class="media ">
											<a href="/actualites/economie/coronavirus-pour-eviter-une-seconde-vague-le-gouvernement-veut-traquer-le-virus-44262.html">
												<img width="90" class="visual ea_image" src="//cdn-static.boursier.com/illustrations/photos/100/olivier-veran.jpg" data-ea-parsed="true" data-ea-dsp="a" alt="Coronavirus : pour &#233;viter une seconde vague, le gouvernement veut &quot;traquer le virus&quot;" />
											</a>
										</div>
									</div>									
							</div>
						</div>
						<div class="item item--type-conseils priv">
							<time class="date" datetime="2020-06-26T08:20:00">08h20</time>
							<div class="data">
									<a href="/actions/actualites/conseils/precisions-attendues-42867.html">

										<span class="text">
											<strong>ALTUR Investissement </strong> : précisions attendues
										</span>
											<img class="icon partner-icon" src="/Content/img/ico-snmd-dark.png" alt="Small&Mid Cap">
									</a>												</div>
								<span class="iconm-lock"></span>
						</div>
						<div class="item item--type-news">
							<time class="date" datetime="2020-06-26T08:17:00">08h17</time>
							<div class="data">
									<a href="/actions/actualites/news/carrefour-la-situation-technique-est-plutot-incertaine-at-756796.html">

										<span class="text">
											Carrefour : la situation technique est plutôt incertaine (AT)
										</span>
									</a>												</div>
						</div>
						<div class="item item--type-news">
							<time class="date" datetime="2020-06-26T08:11:00">08h11</time>
							<div class="data">
									<a href="/actions/actualites/news/air-france-klm-klm-obtient-enfin-l-aide-de-l-etat-neerlandais-826019.html">

										<span class="text">
											Air France KLM : KLM obtient enfin l'aide de l'Etat néerlandais
 <span class="icon2016-comment-1">1</span> 										</span>
									</a>												</div>
						</div>
						<div class="item item--type-news">
							<time class="date" datetime="2020-06-26T08:08:00">08h08</time>
							<div class="data">
									<a href="/actions/actualites/news/stmicroelectronics-l-indecision-domine-at-756881.html">

										<span class="text">
											STMicroelectronics : l'indécision domine (AT)
 <span class="icon2016-comment-1">1</span> 										</span>
									</a>												</div>
						</div>
						<div class="item item--type-news">
							<time class="date" datetime="2020-06-26T08:03:00">08h03</time>
							<div class="data">
									<a href="/actions/actualites/news/bouygues-telecom-a-signe-un-protocole-d-exclusivite-avec-le-credit-mutuel-pour-l-acquisition-d-euro-information-telecom-826018.html">

										<span class="text">
											Bouygues Telecom a signé un protocole d'exclusivité avec le Crédit Mutuel pour l'acquisition d'Euro-Information Telecom
										</span>
									</a>												</div>
						</div>
						<div class="item item--type-news">
							<time class="date" datetime="2020-06-26T08:01:00">08h01</time>
							<div class="data">
									<a href="/actualites/news/ze-top-conseil-marches-baissiers-comment-utiliser-les-etf-825626.html">

										<span class="text">
											Ze top conseil : marchés baissiers, comment utiliser les ETF ?
										</span>
									</a>												</div>
						</div>
						<div class="item item--type-news priv">
							<time class="date" datetime="2020-06-26T08:00:00">08h00</time>
							<div class="data">
									<a href="/actualites/news/tableau-de-bord-indices-calendrier-et-brokers-826017.html">

										<span class="text">
											Tableau de Bord : Indices, calendrier et brokers
										</span>
									</a>												</div>
								<span class="iconm-lock"></span>
						</div>
						<div class="item item--type-news">
							<time class="date" datetime="2020-06-26T07:56:00">07h56</time>
							<div class="data">
									<a href="/actions/actualites/news/psa-groupe-l-indecision-domine-at-756816.html">

										<span class="text">
											PSA Groupe : l'indécision domine (AT)
										</span>
									</a>												</div>
						</div>
						<div class="item item--type-news">
							<time class="date" datetime="2020-06-26T07:54:00">07h54</time>
							<div class="data">
									<a href="/actions/actualites/news/cgg-la-tendance-baissiere-peut-reprendre-at-770094.html">

										<span class="text">
											CGG : la tendance baissière peut reprendre (AT)
 <span class="icon2016-comment-1">3</span> 										</span>
									</a>												</div>
						</div>
						<div class="item item--type-reuters">
							<time class="date" datetime="2020-06-26T07:51:00">07h51</time>
							<div class="data">
									<a href="/actualites/reuters/france-et-pays-bas-s-accordent-sur-une-aide-a-klm-de-3-4-mdse-244928.html">

										<span class="text">
											France et Pays-Bas s'accordent sur une aide à KLM de 3,4 MdsE
										</span>
									</a>												</div>
						</div>
						<div class="item item--type-economie">
							<time class="date" datetime="2020-06-26T07:50:00">07h50</time>
							<div class="data">
									<div class="text-media">
										<div class="text">
											<a href="/actualites/economie/consommation-responsable-l-ufc-que-choisir-lance-une-consultation-citoyenne-44264.html">"Consommation responsable" : l'UFC-Que choisir lance une consultation citoyenne</a>
										</div>
										<div class="media ">
											<a href="/actualites/economie/consommation-responsable-l-ufc-que-choisir-lance-une-consultation-citoyenne-44264.html">
												<img width="90" class="visual ea_image" src="//cdn-static.boursier.com/illustrations/photos/100/plan-gaspillage-alimentaire.jpg" data-ea-parsed="true" data-ea-dsp="a" alt="&quot;Consommation responsable&quot; : l&#39;UFC-Que choisir lance une consultation citoyenne" />
											</a>
										</div>
									</div>									
							</div>
						</div>
						<div class="item item--type-news">
							<time class="date" datetime="2020-06-26T07:44:00">07h44</time>
							<div class="data">
									<a href="/actions/actualites/news/pharmasimple-forte-progression-de-l-activite-a-fin-mai-a-24-2-me-826016.html">

										<span class="text">
											Pharmasimple : forte progression de l'activité à fin mai, à 24,2 ME
										</span>
											<img class="icon partner-icon" src="/Content/img/ico-snmd.png" alt="Small&Mid Cap">
									</a>												</div>
						</div>
						<div class="item item--type-news">
							<time class="date" datetime="2020-06-26T07:38:00">07h38</time>
							<div class="data">
									<a href="/actions/actualites/news/intrasense-convocation-a-une-nouvelle-ag-mixte-le-8-juillet-826015.html">

										<span class="text">
											Intrasense : convocation à une nouvelle AG Mixte le 8 juillet
 <span class="icon2016-comment-1">1</span> 										</span>
											<img class="icon partner-icon" src="/Content/img/ico-snmd.png" alt="Small&Mid Cap">
									</a>												</div>
						</div>
						<div class="item item--type-news">
							<time class="date" datetime="2020-06-26T07:35:00">07h35</time>
							<div class="data">
									<a href="/actions/actualites/news/edf-une-consolidation-vers-les-supports-est-probable-at-756851.html">

										<span class="text">
											EDF : une consolidation vers les supports est probable (AT)
 <span class="icon2016-comment-1">2</span> 										</span>
									</a>												</div>
						</div>
						<div class="item item--type-news">
							<time class="date" datetime="2020-06-26T07:34:00">07h34</time>
							<div class="data">
									<a href="/actualites/news/asie-fin-de-semaine-en-hausse-826014.html">

										<span class="text">
											Asie : fin de semaine en hausse
										</span>
									</a>												</div>
						</div>
						<div class="item item--type-economie">
							<time class="date" datetime="2020-06-26T07:27:00">07h27</time>
							<div class="data">
									<div class="text-media">
										<div class="text">
											<a href="/actualites/economie/teletravail-84-des-salaries-souhaitent-continuer-44258.html">Télétravail : 84% des salariés souhaitent continuer !</a>
										</div>
										<div class="media ">
											<a href="/actualites/economie/teletravail-84-des-salaries-souhaitent-continuer-44258.html">
												<img width="90" class="visual ea_image" src="//cdn-static.boursier.com/illustrations/photos/100/coronavirus-confinement-domicile.jpg" data-ea-parsed="true" data-ea-dsp="a" alt="T&#233;l&#233;travail : 84% des salari&#233;s souhaitent continuer !" />
											</a>
										</div>
									</div>									
							</div>
						</div>
						<div class="item item--type-news">
							<time class="date" datetime="2020-06-26T07:26:00">07h26</time>
							<div class="data">
									<a href="/actions/actualites/news/orange-la-tendance-baissiere-peut-reprendre-at-756838.html">

										<span class="text">
											Orange : la tendance baissière peut reprendre (AT)
 <span class="icon2016-comment-1">48</span> 										</span>
									</a>												</div>
						</div>
						<div class="item item--type-news">
							<time class="date" datetime="2020-06-26T07:22:00">07h22</time>
							<div class="data">
									<a href="/actions/actualites/news/cellectis-publie-une-methode-de-fabrication-simplifiee-pour-generer-des-therapies-cellulaires-car-t-allogeniques-ultra-pures-826012.html">

										<span class="text">
											Cellectis publie une méthode de fabrication simplifiée pour générer des thérapies cellulaires CAR-T allogéniques ultra-pures
										</span>
											<img class="icon partner-icon" src="/Content/img/ico-snmd.png" alt="Small&Mid Cap">
									</a>												</div>
						</div>
						<div class="item item--type-news">
							<time class="date" datetime="2020-06-26T07:18:00">07h18</time>
							<div class="data">
									<a href="/actions/actualites/news/cnim-le-resultat-net-2019-part-du-groupe-s-etablit-a-200-7-me-826011.html">

										<span class="text">
											CNIM : le résultat net 2019 part du Groupe s'établit à -200,7 ME
										</span>
											<img class="icon partner-icon" src="/Content/img/ico-snmd.png" alt="Small&Mid Cap">
									</a>												</div>
						</div>
						<div class="item item--type-news">
							<time class="date" datetime="2020-06-26T07:11:00">07h11</time>
							<div class="data">
									<a href="/indices/actualites/news/nasdaq-composite-la-situation-technique-est-plutot-incertaine-at-756885.html">

										<span class="text">
											Nasdaq Composite : la situation technique est plutôt incertaine (AT)
										</span>
									</a>												</div>
						</div>
						<div class="item item--type-generales">
							<time class="date" datetime="2020-06-26T07:05:00">07h05</time>
							<div class="data">
									<a href="/actualites/news/arpege-prevoyance-nomination-de-la-nouvelle-presidence-paritaire-826023.html">

										<span class="text">
											Arpege Prévoyance : nomination de la nouvelle présidence paritaire
										</span>
									</a>												</div>
						</div>
						<div class="item item--type-news">
							<time class="date" datetime="2020-06-26T07:03:00">07h03</time>
							<div class="data">
									<a href="/actions/actualites/news/vallourec-une-consolidation-vers-les-supports-est-probable-at-823613.html">

										<span class="text">
											Vallourec : une consolidation vers les supports est probable (AT)
										</span>
									</a>												</div>
						</div>
						<div class="item item--type-news">
							<time class="date" datetime="2020-06-26T06:58:00">06h58</time>
							<div class="data">
									<a href="/actions/actualites/news/tipiak-retour-d-assemblee-generale-826013.html">

										<span class="text">
											Tipiak : retour d'Assemblée générale
										</span>
											<img class="icon partner-icon" src="/Content/img/ico-snmd.png" alt="Small&Mid Cap">
									</a>												</div>
						</div>
						<div class="item item--type-reuters">
							<time class="date" datetime="2020-06-26T06:57:15">06h57</time>
							<div class="data">
									<a href="/actualites/reuters/verizon-suspend-ses-publicites-sur-facebook-244927.html">

										<span class="text">
											Verizon suspend ses publicités sur Facebook
 <span class="icon2016-comment-1">2</span> 										</span>
									</a>												</div>
						</div>
						<div class="item item--type-economie">
							<time class="date" datetime="2020-06-26T06:56:00">06h56</time>
							<div class="data">
									<div class="text-media">
										<div class="text">
											<a href="/actualites/economie/quels-sont-les-impacts-de-la-crise-sur-les-pratiques-de-paiement-des-francais-44257.html">Quels sont les impacts de la crise sur les pratiques de paiement des Français ?</a>
										</div>
										<div class="media ">
											<a href="/actualites/economie/quels-sont-les-impacts-de-la-crise-sur-les-pratiques-de-paiement-des-francais-44257.html">
												<img width="90" class="visual ea_image" src="//cdn-static.boursier.com/illustrations/photos/100/carte-bancaire-banque.jpg" data-ea-parsed="true" data-ea-dsp="a" alt="Quels sont les impacts de la crise sur les pratiques de paiement des Fran&#231;ais ?" />
											</a>
										</div>
									</div>									
							</div>
						</div>
						<div class="item item--type-news">
							<time class="date" datetime="2020-06-26T06:51:00">06h51</time>
							<div class="data">
									<a href="/actions/actualites/news/teleperformance-se-distingue-au-portugal-826010.html">

										<span class="text">
											Teleperformance se distingue au Portugal
										</span>
									</a>												</div>
						</div>
						<div class="item item--type-news">
							<time class="date" datetime="2020-06-26T06:44:00">06h44</time>
							<div class="data">
									<a href="/actions/actualites/news/theradiag-retour-d-assemblee-generale-826009.html">

										<span class="text">
											Theradiag : retour d'Assemblée générale
										</span>
											<img class="icon partner-icon" src="/Content/img/ico-snmd.png" alt="Small&Mid Cap">
									</a>												</div>
						</div>
						<div class="item item--type-news">
							<time class="date" datetime="2020-06-26T06:40:00">06h40</time>
							<div class="data">
									<a href="/indices/actualites/news/dow-jones-industrial-l-indecision-domine-at-756756.html">

										<span class="text">
											Dow Jones Industrial : l'indécision domine (AT)
										</span>
									</a>												</div>
						</div>
						<div class="item item--type-news">
							<time class="date" datetime="2020-06-26T06:37:00">06h37</time>
							<div class="data">
									<a href="/actions/actualites/news/cogelec-retour-d-assemblee-generale-826008.html">

										<span class="text">
											Cogelec : retour d'Assemblée générale
										</span>
											<img class="icon partner-icon" src="/Content/img/ico-snmd.png" alt="Small&Mid Cap">
									</a>												</div>
						</div>
						<div class="item item--type-news">
							<time class="date" datetime="2020-06-26T06:30:00">06h30</time>
							<div class="data">
									<a href="/actualites/news/agenda-a-suivre-aujourd-hui-sur-les-marches-financiers-826006.html">

										<span class="text">
											Agenda : à suivre aujourd'hui sur les marchés financiers
										</span>
									</a>												</div>
						</div>
						<div class="item item--type-reuters">
							<time class="date" datetime="2020-06-26T06:26:00">06h26</time>
							<div class="data">
									<a href="/actualites/reuters/paris-optimiste-sur-un-accord-sur-le-plan-de-relance-en-juillet-244922.html">

										<span class="text">
											Paris "optimiste" sur un accord sur le plan de relance en juillet
 <span class="icon2016-comment-1">3</span> 										</span>
									</a>												</div>
						</div>
						<div class="item item--type-economie">
							<time class="date" datetime="2020-06-26T06:25:00">06h25</time>
							<div class="data">
									<div class="text-media">
										<div class="text">
											<a href="/actualites/economie/coronavirus-les-etats-unis-confrontes-a-une-acceleration-de-l-epidemie-44266.html">Coronavirus : les Etats-Unis confrontés à une accélération de l'épidémie</a>
										</div>
										<div class="media ">
											<a href="/actualites/economie/coronavirus-les-etats-unis-confrontes-a-une-acceleration-de-l-epidemie-44266.html">
												<img width="90" class="visual ea_image" src="//cdn-static.boursier.com/illustrations/photos/100/coronavirus-illustration-dans-aeroport.jpg" data-ea-parsed="true" data-ea-dsp="a" alt="Coronavirus : les Etats-Unis confront&#233;s &#224; une acc&#233;l&#233;ration de l&#39;&#233;pid&#233;mie" />
											</a>
										</div>
									</div>									
							</div>
						</div>
						<div class="item item--type-news">
							<time class="date" datetime="2020-06-26T06:22:00">06h22</time>
							<div class="data">
									<a href="/actions/actualites/news/samse-le-chiffre-d-affaires-recule-de-15-7-a-fin-mai-avec-la-crise-sanitaire-826007.html">

										<span class="text">
											Samse : le chiffre d'affaires recule de 15,7% à fin mai avec la crise sanitaire
										</span>
											<img class="icon partner-icon" src="/Content/img/ico-snmd.png" alt="Small&Mid Cap">
									</a>												</div>
						</div>
						<div class="item item--type-news">
							<time class="date" datetime="2020-06-26T06:20:00">06h20</time>
							<div class="data">
									<a href="/indices/actualites/news/cac-40-l-indecision-domine-at-756755.html">

										<span class="text">
											CAC 40 : l'indécision domine (AT)
 <span class="icon2016-comment-1">8</span> 										</span>
									</a>												</div>
						</div>
						<div class="item item--type-news">
							<time class="date" datetime="2020-06-26T06:15:00">06h15</time>
							<div class="data">
									<a href="/actions/actualites/news/etats-unis-les-bancaires-partagees-entre-volcker-et-les-stress-tests-826003.html">

										<span class="text">
											Etats-Unis : les bancaires partagées entre Volcker et les "stress tests"
										</span>
									</a>												</div>
						</div>
						<div class="item item--type-reuters">
							<time class="date" datetime="2020-06-26T06:09:00">06h09</time>
							<div class="data">
									<a href="/actualites/reuters/la-fed-jauge-la-resistance-des-banques-limite-les-dividendes-244926.html">

										<span class="text">
											La Fed jauge la résistance des banques, limite les dividendes
										</span>
									</a>												</div>
						</div>
						<div class="item item--type-news hot">
							<time class="date" datetime="2020-06-26T06:08:00">06h08</time>
							<div class="data">
									<a href="/actions/actualites/news/focus-home-interactive-les-benefices-s-envolent-a-13-me-pour-l-exercice-826005.html">

										<span class="text">
											Focus Home Interactive : les bénéfices s'envolent à 13 ME pour l'exercice
										</span>
											<img class="icon partner-icon" src="/Content/img/ico-snmd.png" alt="Small&Mid Cap">
									</a>												</div>
						</div>
						<div class="item item--type-news">
							<time class="date" datetime="2020-06-26T06:03:00">06h03</time>
							<div class="data">
									<a href="/actions/actualites/news/nike-pertes-et-plongeon-des-ventes-au-4e-trimestre-le-titre-flanche-826004.html">

										<span class="text">
											Nike : pertes et plongeon des ventes au 4e trimestre, le titre flanche
										</span>
									</a>												</div>
						</div>
						<div class="item item--type-news">
							<time class="date" datetime="2020-06-26T06:00:00">06h00</time>
							<div class="data">
									<a href="/devises/actualites/news/eur-usd-la-situation-technique-est-plutot-incertaine-at-756760.html">

										<span class="text">
											EUR/USD : la situation technique est plutôt incertaine (AT)
										</span>
									</a>												</div>
						</div>
						<div class="item item--type-news">
							<time class="date" datetime="2020-06-26T05:55:00">05h55</time>
							<div class="data">
									<a href="/actions/actualites/news/wirecard-faillite-en-vue-le-titre-plonge-de-71-825907.html">

										<span class="text">
											Wirecard : faillite en vue, le titre plonge de 71% !
										</span>
									</a>												</div>
						</div>
						<div class="item item--type-economie">
							<time class="date" datetime="2020-06-26T05:44:00">05h44</time>
							<div class="data">
									<div class="text-media">
										<div class="text">
											<a href="/actualites/economie/cybersecurite-quel-risque-pour-les-banques-44256.html">Cybersécurité : quel risque pour les banques ?</a>
										</div>
										<div class="media ">
											<a href="/actualites/economie/cybersecurite-quel-risque-pour-les-banques-44256.html">
												<img width="90" class="visual ea_image" src="//cdn-static.boursier.com/illustrations/photos/100/cyberattaque.jpg" data-ea-parsed="true" data-ea-dsp="a" alt="Cybers&#233;curit&#233; : quel risque pour les banques ?" />
											</a>
										</div>
									</div>									
							</div>
						</div>
						<div class="item item--type-news">
							<time class="date" datetime="2020-06-26T05:32:00">05h32</time>
							<div class="data">
									<a href="/actualites/galeries/emploi-et-logement-quelles-sont-les-villes-les-plus-attractives-en-france-342,6842.html">

										<span class="text">
											Emploi et logement, quelles sont les villes les plus attractives en France ?
										</span>
									</a>												</div>
						</div>
						<div class="item item--type-reuters">
							<time class="date" datetime="2020-06-26T05:23:00">05h23</time>
							<div class="data">
									<a href="/actualites/reuters/condamne-en-appel-sur-le-levothyrox-merck-va-en-cassation-244920.html">

										<span class="text">
											Condamné en appel sur le Levothyrox, Merck va en cassation
										</span>
									</a>												</div>
						</div>
						<div class="item item--type-news">
							<time class="date" datetime="2020-06-26T04:03:00">04h03</time>
							<div class="data">
									<a href="/actualites/news/credit-immobilier-quand-l-erreur-de-teg-ne-joue-plus-en-faveur-de-l-emprunteur-825697.html">

										<span class="text">
											Crédit immobilier : quand l'erreur de TEG ne joue plus en faveur de l'emprunteur
										</span>
									</a>												</div>
						</div>
						<div class="item item--type-news">
							<time class="date" datetime="2020-06-26T02:15:00">02h15</time>
							<div class="data">
									<a href="/actualites/news/immobilier-les-idees-ne-manquent-pas-pour-un-plan-de-relance-825910.html">

										<span class="text">
											Immobilier : les idées ne manquent pas pour un plan de relance
										</span>
									</a>												</div>
						</div>
						<div class="item item--type-reuters">
							<time class="date" datetime="2020-06-26T01:44:00">01h44</time>
							<div class="data">
									<a href="/actualites/reuters/le-plan-de-sauvetage-de-lufthansa-approuve-par-les-actionnaires-244898.html">

										<span class="text">
											Le plan de sauvetage de Lufthansa approuvé par les actionnaires
										</span>
									</a>												</div>
						</div>
						<div class="item item--type-reuters">
							<time class="date" datetime="2020-06-26T01:24:00">01h24</time>
							<div class="data">
									<a href="/actualites/reuters/brexit-les-negociations-reprennent-lundi-en-face-a-face-244917.html">

										<span class="text">
											Brexit : Les négociations reprennent lundi, en face-à-face
										</span>
									</a>												</div>
						</div>
						<div class="item item--type-news">
							<time class="date" datetime="2020-06-26T01:02:00">01h02</time>
							<div class="data">
									<a href="/actualites/news/immobilier-tout-savoir-sur-le-pret-a-taux-zero-ptz-en-2020-812508.html">

										<span class="text">
											Immobilier : tout savoir sur le Prêt à Taux Zéro (PTZ) en 2020
										</span>
									</a>												</div>
						</div>
						<div class="item item--type-economie">
							<time class="date" datetime="2020-06-26T01:01:00">01h01</time>
							<div class="data">
									<div class="text-media">
										<div class="text">
											<a href="/actualites/economie/renouveau-urbain-et-renovation-mission-confiee-au-plan-batiment-durable-et-a-la-rics-44255.html">Renouveau urbain et rénovation : mission confiée au Plan Bâtiment Durable et à la RICS</a>
										</div>
										<div class="media ">
											<a href="/actualites/economie/renouveau-urbain-et-renovation-mission-confiee-au-plan-batiment-durable-et-a-la-rics-44255.html">
												<img width="90" class="visual ea_image" src="//cdn-static.boursier.com/illustrations/photos/100/travaux-levallois.jpg" data-ea-parsed="true" data-ea-dsp="a" alt="Renouveau urbain et r&#233;novation : mission confi&#233;e au Plan B&#226;timent Durable et &#224; la RICS" />
											</a>
										</div>
									</div>									
							</div>
						</div>
						<div class="item item--type-reuters">
							<time class="date" datetime="2020-06-26T00:26:00">00h26</time>
							<div class="data">
									<a href="/actualites/reuters/coronavirus-21-nouveaux-deces-enregistres-en-france-244923.html">

										<span class="text">
											Coronavirus : 21 nouveaux décès enregistrés en France
 <span class="icon2016-comment-1">4</span> 										</span>
									</a>												</div>
						</div>
						<div class="item item--type-news">
							<time class="date" datetime="2020-06-26T00:20:00">00h20</time>
							<div class="data">
									<a href="/actualites/news/avoirs-non-reclames-les-genealogistes-a-la-rescousse-825825.html">

										<span class="text">
											Avoirs non réclamés : les généalogistes à la rescousse
										</span>
									</a>												</div>
						</div>
						<div class="item item--type-economie">
							<time class="date" datetime="2020-06-25T23:39:00">25/06</time>
							<div class="data">
									<div class="text-media">
										<div class="text">
											<a href="/actualites/economie/coronavirus-ne-dites-plus-chomage-partiel-mais-activite-partielle-44251.html">Coronavirus : ne dites plus chômage partiel, mais "activité partielle" !</a>
										</div>
										<div class="media ">
											<a href="/actualites/economie/coronavirus-ne-dites-plus-chomage-partiel-mais-activite-partielle-44251.html">
												<img width="90" class="visual ea_image" src="//cdn-static.boursier.com/illustrations/photos/100/airbus-chantier.jpg" data-ea-parsed="true" data-ea-dsp="a" alt="Coronavirus : ne dites plus ch&#244;mage partiel, mais &quot;activit&#233; partielle&quot; !" />
											</a>
										</div>
									</div>									
							</div>
						</div>
						<div class="item item--type-reuters">
							<time class="date" datetime="2020-06-25T22:32:10">25/06</time>
							<div class="data">
									<a href="/actualites/reuters/wall-street-finit-en-hausse-grace-aux-valeurs-bancaires-244925.html">

										<span class="text">
											Wall Street finit en hausse grâce aux valeurs bancaires
										</span>
									</a>												</div>
						</div>
						<div class="item item--type-news">
							<time class="date" datetime="2020-06-25T22:30:00">25/06</time>
							<div class="data">
									<a href="/indices/actualites/news/cloture-de-wall-street-en-progression-avec-les-banques-malgre-le-covid-19-826000.html">

										<span class="text">
											Clôture de Wall Street : en progression avec les banques, malgré le Covid-19
										</span>
									</a>												</div>
						</div>
						<div class="item item--type-news">
							<time class="date" datetime="2020-06-25T22:25:00">25/06</time>
							<div class="data">
									<a href="/actualites/news/avis-d-expert-donner-du-sens-a-son-epargne-un-pari-gagnant-825795.html">

										<span class="text">
											Avis d'expert : " Donner du sens à son épargne, un pari gagnant ? "
										</span>
									</a>												</div>
						</div>
						<div class="item item--type-news">
							<time class="date" datetime="2020-06-25T22:22:00">25/06</time>
							<div class="data">
									<a href="/actions/actualites/news/uv-germi-retour-d-assemblee-generale-826002.html">

										<span class="text">
											UV Germi : retour d'Assemblée générale
										</span>
											<img class="icon partner-icon" src="/Content/img/ico-snmd.png" alt="Small&Mid Cap">
									</a>												</div>
						</div>
						<div class="item item--type-economie">
							<time class="date" datetime="2020-06-25T22:09:00">25/06</time>
							<div class="data">
									<div class="text-media">
										<div class="text">
											<a href="/actualites/economie/laurent-vachey-conduira-la-conference-de-prefiguration-de-la-nouvelle-branche-autonomie-44259.html">Laurent Vachey conduira la conférence de préfiguration de la nouvelle branche autonomie</a>
										</div>
										<div class="media ">
											<a href="/actualites/economie/laurent-vachey-conduira-la-conference-de-prefiguration-de-la-nouvelle-branche-autonomie-44259.html">
												<img width="90" class="visual ea_image" src="//cdn-static.boursier.com/illustrations/photos/100/retraite-cour-comptes-pension-effort-dette.jpg" data-ea-parsed="true" data-ea-dsp="a" alt="Laurent Vachey conduira la conf&#233;rence de pr&#233;figuration de la nouvelle branche autonomie" />
											</a>
										</div>
									</div>									
							</div>
						</div>
				</div>
				<a href="/actualites/news-du-jour" class="btn-more">
					<span class="bt-label">Tout le fil</span>
					<span class="bt-icon icon2016-right-small"></span>
				</a>
			</div>			
		</div>

	</div>

						<div class="section-separator"></div>
						<div data-id="liste-pf" id="liste-pf" data-target="mychoice">
							<div class="outer">
								<div data-script="mode=sync;autosize=false;defaut=0" class="tabs">
									<h2 class="tab on">
										<a href="#" class="title">Mes listes</a>
									</h2>
									<h2 class="tab">
										<a href="#" class="title">Mes portefeuilles</a>
									</h2>
								</div>
								<div class="tabs-content">
									<div style="display: block;">
										<div id="block-mes-listes" class="block-mes-listes-home" data-ajax-href="/ajax/membres/listes/ajaxmylist"></div>
									</div>
									<div style="display: none;">
										<div id="block-mon-portefeuille" class="block-mes-listes-home" data-ajax-href="/ajax/membres/portefeuilles/ajaxmyportfolio"></div>
									</div>
								</div>
							</div>
						</div>
					</div>
					<div class="cg cg-2 right">
						<div class="no-sticky courtier" id="courtiers-pave">
							<div class="courtier-block">
								<!-- Generic > Vignette 1 --><div id="ad-anx-sidebar1">
</div><!-- Generic > Vignette 2 --><div id="ad-anx-sidebar2">
</div><!-- Generic > Vignette 3 --><div id="ad-anx-sidebar3">
</div><!-- Generic > Vignette LMNP -->
<a data-vendor="c:google" href="https://argent.boursier.com/immobilier/guides/guide-gratuit-loi-pinel?xtor=AD-4-[hpcoldroite]" target="_blank"><img src="https://cdn-static.boursier.com/illustrations/campaigns/btn-promo-pinel-2020.jpg" alt="" width="300" height="66" style="width:300px !important; height:66px !important" border="0" /></a>
							</div>
						</div>
						<div>
							<div class="sticky-container" data-sticky-container>
								<div class="box courtier stickyads sticky" id="partner-ads" data-sticky data-anchor="actus-ads">
									<div class="stack">
										<!-- Generic > Pavé 1 --><div id="ad-anx-mpu1">
</div>
									</div>
								</div>
							</div>
						</div>
					</div>
				</div>
				<div class="custom-grid">
					<div class="cg full cg-small-full">
						<div data-id="subscription" id="subscription" class="toggleit cg-full">
	<div class="col col-12 medium-12">
		<a href="/membres/abonnement?utm_source=boursier&amp;utm_medium=bannierehp&amp;utm_campaign=privileges" target="_blank" rel="nofollow">
			<p>
				Testez les performances de
				nos conseils boursiers
			</p>

			<span class="price"><strong>1</strong><span>€</span> le 1er mois</span>
			<span class="btn-more premium">S'abonner</span>
		</a>
	</div>
</div>
					</div>
				</div>
			</div>
		</div>
	</section>
	
	<section data-target="highlight" id="tete-a-tete" class="w-background grid-12">
		<div class="wrapper">
			<div class="row">
				<h2 class="title-img">
					BNP Paribas Easy
									</h2>
				<div data-href="child" class="col col-8 medium-12">
					<div class="col col-6 small-12">
						<div class="media">
							<a href="https://www.boursier.com/actualites/news/marches-baissiers-comment-utiliser-les-etf-825626.html"  data-vid-height="16:9" data-vid-media="fuplll" data-vid-type="ultimedia" id="vid-player1">
								<img alt="ZE TOP CONSEIL : march&#233;s baissiers, comment utiliser les ETF ?" src="//cdn-static.boursier.com/illustrations/webcasts/l_broadcast-63.jpg">
							</a>
						</div>
					</div>
					<div class="col col-6 middle small-12">
						<p class="profil">
							<strong class="h2 name">ZE TOP CONSEIL : marchés baissiers, comment utiliser les ETF ?</strong>
						</p>
						<div class="citations">
							<blockquote>
								Avec Bertrand Alfandari, Responsable du développement ETF - BNP Paribas Asset Management.
							</blockquote>
						</div>
							<a href="https://www.boursier.com/actualites/news/marches-baissiers-comment-utiliser-les-etf-825626.html" class="btn-more">
								<span class="bt-label">Voir la vid&#233;o</span>
								<span class="bt-icon icon2016-right-small"></span>
							</a>
					</div>
				</div>
			</div>
		</div>

	</section>

	
<section data-target="highlight" id="actu-gerants" class="grid-12">
	<div class="wrapper">
		<h2><a href="/opcvm/">OPCVM : L'actu des sociétés de gestion</a></h2>
		<div class="row">
			<div class="grid-12 week__fund bottom--margin" style="display: block;">
				

			</div>

			<div id="opcvm-wrapper" class="top--margin">
				<div class="custom-grid">
					<div class="cg cg-3 cg-medium-half cg-small-full">
							<h3 class="title-border">L'interview de gerant</h3>
							<a href="/opcvm/actualites/interviews/romain-boscher-responsable-mondial-des-investissements-en-actions-de-fidelity-international-5163.html">
								<div class="profil">
									<div class="media">
										<img src="//cdn-static.boursier.com/illustrations/interviews/200/boscher-fidelity.jpg" alt="Romain Boscher">
									</div>
									<p class="text">
										<strong class="h3 name">Romain Boscher</strong>
										
										 Responsable mondial des investissements en actions de Fidelity International
									</p>
								</div>

								<div class="citations">
									<blockquote>
										<span class="quote">“</span>
										Un seul facteur a supplanté tous les autres : la qualité!
									</blockquote>
								</div>
							</a>
							<div class="news-list">
								<a href="/opcvm/actualites/interviews/" class="btn-more">
									<span class="bt-label">Plus d'interviews de Gérants</span>
									<span class="bt-icon icon2016-right-small"></span>
								</a>
							</div>
							<div class="home--conseil conseil">
								<h3 class="title-border">Le conseil de la semaine</h3>
								<div class="news-list">
											<div class="items">
												<div class="item ">
													<time class="date" datetime="2020-06-25T15:14:00">
														25/06
													</time>
													<div class="data">
														<a href="/opcvm/actualites/conseils/la-sicav-de-la-semaine-invest-latitude-croissance-42865.html">
															La Sicav de la semaine : Invest Latitude Croissance
														</a>
													</div>
												</div>
											</div>
											<a href="/opcvm/actualites/conseils/" class="btn-more">
												<span class="bt-label">Plus de conseils</span>
												<span class="bt-icon icon2016-right-small"></span>
											</a>
								</div>
							</div>
					</div>

					<div class="cg cg-2 cg-medium-half cg-small-full border one">
						<div class="outer">
							<div class="news-list">
								<h3 class="title-border">Actualités OPCVM</h3>
									<div class="items">
											<div class="item ">
												<time class="date" datetime="2020-06-26T09:33:00">09h33</time>
												<div class="data"><a href="/opcvm/actualites/generales/treezor-et-idemia-annoncent-le-lancement-de-la-premiere-carte-bancaire-eco-responsable-en-france-826037.html">Treezor et IDEMIA annoncent le lancement de la première carte bancaire éco-responsable en France</a></div>
											</div>
											<div class="item ">
												<time class="date" datetime="2020-06-26T09:14:00">09h14</time>
												<div class="data"><a href="/opcvm/actualites/news/azqore-signe-un-partenariat-strategique-avec-le-fournisseur-suisse-de-technologie-financiere-evooq-826032.html">Azqore signe un partenariat stratégique avec le fournisseur suisse de technologie financière Evooq</a></div>
											</div>
											<div class="item ">
												<time class="date" datetime="2020-06-26T07:05:00">07h05</time>
												<div class="data"><a href="/opcvm/actualites/generales/arpege-prevoyance-nomination-de-la-nouvelle-presidence-paritaire-826023.html">Arpege Prévoyance : nomination de la nouvelle présidence paritaire</a></div>
											</div>
											<div class="item ">
												<time class="date" datetime="2020-06-25T17:11:00">25/06</time>
												<div class="data"><a href="/opcvm/actualites/generales/social-bonds-la-croissance-2020-contraste-avec-le-reste-de-l-obligataire-825972.html">"Social Bonds" : la croissance 2020 contraste avec le reste de l'obligataire</a></div>
											</div>
											<div class="item ">
												<time class="date" datetime="2020-06-25T15:09:00">25/06</time>
												<div class="data"><a href="/opcvm/actualites/generales/mma-lance-son-plan-epargne-retraite-825949.html">MMA lance son Plan Epargne Retraite</a></div>
											</div>
									</div>

								<a href="/opcvm/actualites/news/" class="btn-more">
									<span class="bt-label">Plus d’actualités</span>
									<span class="bt-icon icon2016-right-small"></span>
								</a>
							</div>
						</div>
					</div>

					<div class="cg cg-2 right sticky-container" data-sticky-container>
						<div class="box courtier stickyads sticky" id="opcvm-ads" data-sticky data-anchor="opcvm-ads">
							<div class="stack">
								<!-- Generic > Pavé 2 --><div id="ad-anx-mpu2">
</div>
							</div>
						</div>
					</div>
				</div>
			</div>
			
			<div class="grid-12 week__fund top--margin" style="display: block;">
				

			</div>

			<div class="top--margin">
				<div class="wrapper opcvm--push">
					<div class="w-background">
						<p>
							Retrouvez le palmarès OPCVM et les performances des fonds
						</p>
						<a href="/opcvm/" class="btn-more btn-self">
							<span class="bt-label">Découvrez la <br /> rubrique OPCVM</span>
							<span class="bt-icon icon2016-right-small"></span>
						</a>
					</div>
				</div>
			</div>
		</div>
	</div>
</section>



	

	<section class="grid-12" data-target="highlight">
        <div class="wrapper">
            <div class="row">
                <div class="custom-grid">
					<div class="cg full cg-small-full">
                        
					    


<section data-id="rumeurs-marches" data-target="highlight" id="rumeurs-marches" class="grid-12 top-bordered">
		<div class="col col-6 small-12">
			<h2>Rumeurs des marchés</h2>

			<article class="quick-actu">
				<a href="/actions/actualites/rumeurs/europcar-de-retour-chez-volkswagen-825776.html">
					<div class="media">
						<img src="//cdn-static.boursier.com/illustrations/photos/300/europcar1.jpg" alt="Europcar : de retour chez Volkswagen ?">
					</div>
					<div class="text">
						<h3>Europcar : de retour chez Volkswagen ?</h3>

						<p>
							Europcar Mobility de retour chez Volkswagen ? Citant des sources proches du dossier, 'Reuters' et 'Bloomberg' affirment que le constructeur allemand...
						</p>
					</div>
				</a>
			</article>

			<a href="/actualites/rumeurs" class="btn-more">
				<span class="bt-label">Toutes les rumeurs</span>
				<span class="bt-icon icon2016-right-small"></span>
			</a>
		</div>
			<div class="col col-6 middle small-12">
			<h2>Introductions</h2>
			<div class="news-list">
				<div class="items items-introduction items-introduction--home">

						<div class="item status status-error">
							<time class="date" datetime="2020-03-04T00:00:00">04/03</time>
							<div class="data">
								<a href="/introductions/societe/nacon-FR0013482791,FR.html" title="Nacon - MR - Compartiment B" class="toe">
									Nacon <br /> MR - Compartiment B
								</a>
							</div>
							<span class="status">Effectuée</span>
						</div>
						<div class="item status status-error">
							<time class="date" datetime="2020-02-18T00:00:00">18/02</time>
							<div class="data">
								<a href="/introductions/societe/paulic-meunerie-FR0013479730,FR.html" title="Paulic Meunerie - Euronext Growth" class="toe">
									Paulic Meunerie <br /> Euronext Growth
								</a>
							</div>
							<span class="status">Effectuée</span>
						</div>
						<div class="item status status-error">
							<time class="date" datetime="2020-02-10T00:00:00">10/02</time>
							<div class="data">
								<a href="/introductions/societe/munic-FR0013462231,FR.html" title="Munic - Euronext Growth" class="toe">
									Munic <br /> Euronext Growth
								</a>
							</div>
							<span class="status">Effectuée</span>
						</div>
						<div class="item status status-error">
							<time class="date" datetime="2019-12-04T00:00:00">04/12</time>
							<div class="data">
								<a href="/introductions/societe/mare-nostrum-FR0013400835,FR.html" title="Mare Nostrum - Euronext Growth" class="toe">
									Mare Nostrum <br /> Euronext Growth
								</a>
							</div>
							<span class="status">Effectuée</span>
						</div>
						<div class="item status status-error">
							<time class="date" datetime="2019-11-21T00:00:00">21/11</time>
							<div class="data">
								<a href="/introductions/societe/francaise-des-jeux-FR0013451333,FR.html" title="Fran&#231;aise des Jeux - MR - Compartiment A" class="toe">
									Française des Jeux <br /> MR - Compartiment A
								</a>
							</div>
							<span class="status">Effectuée</span>
						</div>
				</div>
				<a href="/introductions" class="btn-more">
					<span class="bt-label">Plus de conseils</span>
					<span class="bt-icon icon2016-right-small"></span>
				</a>
			</div>
		</div>

</section>
						

<div data-id="small-mid" data-target="highlight" id="small-mid">
	<div class="row">
		<h2 class="title-img top-bordered">
			L’actu des small&miD caps
			<img src="/UI/v5/images/core/logo-s-and-mid.jpg" alt="Actualités des Small&Mid Caps">
		</h2>
		<div class="custom-grid">
				<div class="cg cg-3 cg-medium-half cg-small-full">
					<div class="news-list communiques">
						<h3 class="title-border">Communiqués</h3>
						<div class="items">
								<div class="item">
									<time class="date" datetime="2020-06-12T10:12:00">12/06</time>
									<div class="data">
										<a href="/actions/actualites/news/ashler-et-manson-resultats-2019-824975.html">
											<div class="media">
												<img class="" src="https://logos.cofisem.fr/FR0012968485.jpg" onerror="fix(this)">
											</div>
											<p>Ashler et Manson : résultats 2019</p>
										</a>
									</div>
								</div>
								<div class="item">
									<time class="date" datetime="2020-05-07T17:55:00">07/05</time>
									<div class="data">
										<a href="/actions/actualites/news/delfingen-toujours-eligible-au-pea-pme-822526.html">
											<div class="media">
												<img class="" src="https://logos.cofisem.fr/FR0000054132.jpg" onerror="fix(this)">
											</div>
											<p>DELFINGEN toujours éligible au PEA-PME</p>
										</a>
									</div>
								</div>
								<div class="item">
									<time class="date" datetime="2020-05-07T17:45:00">07/05</time>
									<div class="data">
										<a href="/actions/actualites/news/delfingen-industry-chiffre-d-affaires-du-1er-trimestre-2020-822517.html">
											<div class="media">
												<img class="" src="https://logos.cofisem.fr/FR0000054132.jpg" onerror="fix(this)">
											</div>
											<p>DELFINGEN Industry : Chiffre d'affaires du 1er trimestre 2020</p>
										</a>
									</div>
								</div>
						</div>
						<a href="/actualites/communiques-de-presse" class="btn-more">
							<span class="bt-label">Plus de communiqués</span>
							<span class="bt-icon icon2016-right-small"></span>
						</a>
					</div>
				</div>
							<div class="cg cg-2 cg-medium-half cg-small-full border one">
					<div class="outer">
						<div class="news-list">
						<h3 class="title-border">Actualités</h3>
						<div class="items">
								<div class="item">
									<time class="date" datetime="2020-06-26T10:31:00">10h31</time>
									<div class="data">
										<a href="/actions/actualites/news/focus-home-interactive-des-resultats-salues-826039.html">
											Focus Home Interactive : des résultats salués
										</a>
									</div>
								</div>
								<div class="item">
									<time class="date" datetime="2020-06-26T10:29:00">10h29</time>
									<div class="data">
										<a href="/actions/actualites/news/metabolic-explorer-peu-de-reaction-826041.html">
											Metabolic Explorer : peu de réaction
										</a>
									</div>
								</div>
								<div class="item">
									<time class="date" datetime="2020-06-26T10:07:00">10h07</time>
									<div class="data">
										<a href="/actions/actualites/news/bassac-arguments-en-soutien-826040.html">
											Bassac : arguments en soutien
										</a>
									</div>
								</div>
								<div class="item">
									<time class="date" datetime="2020-06-26T09:58:00">09h58</time>
									<div class="data">
										<a href="/actions/actualites/news/focus-home-interactive-annonces-saluees-826038.html">
											Focus Home Interactive : annonces saluées !
										</a>
									</div>
								</div>
								<div class="item">
									<time class="date" datetime="2020-06-26T09:44:00">09h44</time>
									<div class="data">
										<a href="/actions/actualites/news/actiplay-plan-de-continuation-en-preparation-826034.html">
											Actiplay : plan de continuation en préparation
										</a>
									</div>
								</div>
						</div>
						<a href="/actualites/small-mid-caps" class="btn-more">
							<span class="bt-label">Plus d’actualités</span>
							<span class="bt-icon icon2016-right-small"></span>
						</a>
					</div>
					</div>
				</div>
		</div>
	</div>

</div>

						

						


<div data-id="produit-bourse" data-target="highlight" id="produit-bourse">
	<div class="wrapper">
		<div class="row">
			<div class="col col-12 medium-12 sm">
					<div class="col col-7 small-12">
						<div class="news-list">
							<h2>Conseils produits de bourse</h2>
							<div class="items">
									<div class="item priv">
										<time class="date" datetime="2020-06-15T08:18:00">15/06</time>
										<div class="data"><a href="/produits-de-bourse/actualites/conseils/put-cac40-jamais-trop-tard-42832.html">Put CAC40 : jamais trop tard</a></div>
									</div>
									<div class="item priv">
										<time class="date" datetime="2020-06-12T08:12:00">12/06</time>
										<div class="data"><a href="/produits-de-bourse/actualites/conseils/petrole-consolidation-en-cours-42828.html">Pétrole : consolidation en cours</a></div>
									</div>
									<div class="item ">
										<time class="date" datetime="2020-06-05T11:25:00">05/06</time>
										<div class="data"><a href="/produits-de-bourse/actualites/conseils/vivendi-au-son-du-violon-42809.html">Vivendi : au son du violon !</a></div>
									</div>
									<div class="item ">
										<time class="date" datetime="2020-06-05T11:14:00">05/06</time>
										<div class="data"><a href="/produits-de-bourse/actualites/conseils/bnp-paribas-rebond-justifie-42808.html">BNP Paribas : rebond justifié !</a></div>
									</div>
									<div class="item ">
										<time class="date" datetime="2020-06-03T16:58:00">03/06</time>
										<div class="data"><a href="/produits-de-bourse/actualites/conseils/petrole-trop-vite-42800.html">Pétrole : trop vite ?</a></div>
									</div>
							</div>
							<a href="/produits-de-bourse/actualites/conseils" class="btn-more">
								<span class="bt-label">Plus de conseils</span>
								<span class="bt-icon icon2016-right-small"></span>
							</a>
						</div>
					</div>
				<div class="col col-5 small-12">
					<div class="partenaire-bourse border-box">
						<div class="inner">
							<h3>
								Nos partenaires
								<span>produits de bourse</span>
							</h3>
							<a href="https://www.produitsdebourse.bnpparibas.fr/" target="_blank"><img src="/UI/v5/images/files/partenaire-01.jpg" alt="Produits de Bourse BNP Paribas"/></a>
							<a href="https://bourse.societegenerale.fr/" target="_blank"><img src="/UI/v5/images/files/partenaire-02.jpg" alt="Produits de Bourse Société Générale" /></a>
						</div>
					</div>
				</div>
			</div>
		</div>
	</div>
</div>

						



<div data-id="patrimoine" data-target="highlight" id="patrimoine">
	<div class="patrimoine-title_wrapper top-bordered">
		<h2>Patrimoine</h2>

		<ul class="patrimoine-link_list">
			<li>
				<a href="https://argent.boursier.com">Accueil</a>
			</li>
			<li>
				<a href="https://argent.boursier.com/quotidien">Quotidien</a>
			</li>
			<li>
				<a href="https://argent.boursier.com/immobilier">Immobilier</a>
			</li>
			<li>
				<a href="https://argent.boursier.com/impots">Impôts</a>
			</li>
			<li>
				<a href="https://argent.boursier.com/epargne">Epargne</a>
			</li>
			<li>
				<a href="https://argent.boursier.com/passion">Passion</a>
			</li>
		</ul>
	</div>
	
		<div class="list-items">
				<article class="item col small-12">
					<div class="media">
						<a href="https://argent.boursier.com/immobilier/actualites/10-750-le-m-a-paris-dernier-record-avant-une-baisse-6042.html" target="_blank">
							<img alt="10.750 € le m&#178; &#224; Paris, dernier record avant une baisse ?" width="90" src="//cdn-static.boursier.com/illustrations/photos/200/pollution.jpg" onerror="fix(this)">
						</a>
					</div>

					<div class="text col small-12">
						<a href="https://argent.boursier.com/immobilier" target="_blank" class="category">
							Immobilier
						</a>

						<a href="https://argent.boursier.com/immobilier/actualites/10-750-le-m-a-paris-dernier-record-avant-une-baisse-6042.html" target="_blank">
							<h3>10.750 € le m² à Paris, dernier record avant une baisse ?</h3>
							<p>
								Depuis le 11 mai, les notaires observent une forte reprise du marché immobilier résidentiel d’Ile-de-France, le nombre de ventes de logements étant remonté à plus de 90% de l’activité pré confinement.
							</p>
						</a>
					</div>
				</article>
				<article class="item col small-12">
					<div class="media">
						<a href="https://argent.boursier.com/immobilier/actualites/les-idees-ne-manquent-pas-pour-la-relance-du-secteur-immobilier-6041.html" target="_blank">
							<img alt="Les id&#233;es ne manquent pas pour la relance du secteur immobilier" width="90" src="//cdn-static.boursier.com/illustrations/photos/200/beaugrenelle.jpg" onerror="fix(this)">
						</a>
					</div>

					<div class="text col small-12">
						<a href="https://argent.boursier.com/immobilier" target="_blank" class="category">
							Immobilier
						</a>

						<a href="https://argent.boursier.com/immobilier/actualites/les-idees-ne-manquent-pas-pour-la-relance-du-secteur-immobilier-6041.html" target="_blank">
							<h3>Les idées ne manquent pas pour la relance du secteur immobilier</h3>
							<p>
								La commission des affaires économiques du Sénat a remis un rapport contenant 170 propositions de relance économique dans lequel le logement tient une place importante.
							</p>
						</a>
					</div>
				</article>
				<article class="item col small-12">
					<div class="media">
						<a href="https://argent.boursier.com/epargne/actualites/avoirs-non-reclames-les-genealogistes-a-la-rescousse-6040.html" target="_blank">
							<img alt="Avoirs non r&#233;clam&#233;s : les g&#233;n&#233;alogistes &#224; la rescousse" width="90" src="//cdn-static.boursier.com/illustrations/photos/200/billets.jpg" onerror="fix(this)">
						</a>
					</div>

					<div class="text col small-12">
						<a href="https://argent.boursier.com/epargne" target="_blank" class="category">
							Epargne
						</a>

						<a href="https://argent.boursier.com/epargne/actualites/avoirs-non-reclames-les-genealogistes-a-la-rescousse-6040.html" target="_blank">
							<h3>Avoirs non réclamés : les généalogistes à la rescousse</h3>
							<p>
								L’enjeu est de faciliter la recherche de bénéficiaires de plusieurs milliards d’euros de contrats d’assurance-vie, produits d’épargne inactifs ou contrats de retraite supplémentaire…
							</p>
						</a>
					</div>
				</article>
		</div>
		<div class="col col-8 small-12">
			<div class="more-suggestions">
				<ul>
						<li>
							<a href="https://argent.boursier.com/immobilier" class="category">Immobilier</a> <span class="separator"></span>
							<a href="https://argent.boursier.com/immobilier/actualites/l-encadrement-des-loyers-a-paris-semble-toujours-facile-a-contourner-6039.html">L'encadrement des loyers à Paris semble toujours facile à contourner</a>
						</li>
						<li>
							<a href="https://argent.boursier.com/epargne" class="category">Epargne</a> <span class="separator"></span>
							<a href="https://argent.boursier.com/epargne/points-de-vue/donner-du-sens-a-son-epargne-un-pari-gagnant-6036.html">« Donner du sens à son épargne, un pari gagnant ? »</a>
						</li>
						<li>
							<a href="https://argent.boursier.com/epargne" class="category">Epargne</a> <span class="separator"></span>
							<a href="https://argent.boursier.com/epargne/actualites/contrats-de-retraite-supplementaire-bientot-une-meilleure-information-pour-ne-plus-oublier-de-les-reclamer-6028.html">Contrats de retraite supplémentaire : bientôt une meilleure information pour ne plus oublier de les réclamer !</a>
						</li>
						<li>
							<a href="https://argent.boursier.com/epargne" class="category">Epargne</a> <span class="separator"></span>
							<a href="https://argent.boursier.com/epargne/actualites/alerte-aux-faux-mails-de-l-acpr-6037.html">Alerte aux faux mails de l'ACPR </a>
						</li>
						<li>
							<a href="https://argent.boursier.com/epargne" class="category">Epargne</a> <span class="separator"></span>
							<a href="https://argent.boursier.com/epargne/actualites/le-livret-a-continue-de-faire-le-plein-6038.html">Le Livret A continue de faire le plein</a>
						</li>
				</ul>
				<a href="https://argent.boursier.com" class="btn-more">
					<span class="bt-label">Plus d'actus patrimoine</span>
					<span class="bt-icon icon2016-right-small"></span>
				</a>
			</div>
		</div>
	<div class="col col-4 small-12">
			<div class="fiche">
				<div class="inner">
					<h3>Fiches pratiques</h3>

					<span class="icon2016-file"></span>
					<ul>
							<li>
								<a href="https://argent.boursier.com/epargne/fiches-pratiques/assurance-vie-et-transmission-les-pieges-a-eviter-4899.html">
									<strong class="category">Epargne</strong>
									Assurance-vie et transmission : les pièges à éviter
								</a>
							</li>
							<li>
								<a href="https://argent.boursier.com/immobilier/fiches-pratiques/parkings-le-rendement-brut-nest-pas-le-rendement-net-5565.html">
									<strong class="category">Immobilier</strong>
									Parkings : le rendement brut n’est pas le rendement net
								</a>
							</li>
					</ul>
					<a href="https://argent.boursier.com/fiches-pratiques" class="btn-more btn-white top--margin">
						<span class="bt-label">Toutes les fiches</span>
						<span class="bt-icon icon2016-right-small"></span>
					</a>
				</div>

			</div>
	</div>
</div>

						


	<div data-target="highlight" id="economie">
		<div class="wrapper">
			<div class="row">
				<h2>Économie</h2>

				<div class="col col-12 medium-12">
					<div class="list-items">
							<article class="item col small-12">
								<div class="media">
									<a href="/actualites/economie/l-emploi-premiere-preoccupation-des-jeunes-en-france-44267.html">
										<img alt="L&#39;emploi, premi&#232;re pr&#233;occupation des jeunes en France" width="90" src="//cdn-static.boursier.com/illustrations/photos/200/jeunes-emploi-formation.jpg" onerror="fix(this)" />
									</a>
								</div>

								<div class="text">
									<a href="/actualites/economie/l-emploi-premiere-preoccupation-des-jeunes-en-france-44267.html">
										<h3>L'emploi, première préoccupation des jeunes en France</h3>
										<p>
											Selon une enquête initiée par les missions locales, un tiers des jeunes se disent "inquiets" ou "très inquiets" pour leur avenir, notamment par crainte de ne pas trouver d'emploi en raison de la crise du Covid-19...
										</p>
									</a>
								</div>
							</article>
							<article class="item col small-12">
								<div class="media">
									<a href="/actualites/economie/impots-un-montant-a-payer-ou-un-remboursement-a-recevoir-comment-faire-44253.html">
										<img alt="Imp&#244;ts&amp;nbsp;: un montant &#224; payer ou un remboursement &#224; recevoir, comment faire&amp;nbsp;?" width="90" src="//cdn-static.boursier.com/illustrations/photos/200/dix-euros.jpg" onerror="fix(this)" />
									</a>
								</div>

								<div class="text">
									<a href="/actualites/economie/impots-un-montant-a-payer-ou-un-remboursement-a-recevoir-comment-faire-44253.html">
										<h3>Impôts : un montant à payer ou un remboursement à recevoir, comment faire ?</h3>
										<p>
											Pensez à mettre à jour vos coordonnées bancaires...
										</p>
									</a>
								</div>
							</article>
							<article class="item col small-12">
								<div class="media">
									<a href="/actualites/economie/internet-bond-du-trafic-de-30-en-france-pendant-le-confinement-44263.html">
										<img alt="Internet&amp;nbsp;: bond du trafic de 30% en France pendant le confinement&amp;nbsp;!" width="90" src="//cdn-static.boursier.com/illustrations/photos/200/video-ligne-netflix.jpg" onerror="fix(this)" />
									</a>
								</div>

								<div class="text">
									<a href="/actualites/economie/internet-bond-du-trafic-de-30-en-france-pendant-le-confinement-44263.html">
										<h3>Internet : bond du trafic de 30% en France pendant le confinement !</h3>
										<p>
											Selon l'Arcep, près d'un quart du trafic internet en France provient de la plateforme de vidéos Netflix.
										</p>
									</a>
								</div>
							</article>
							<article class="item col small-12">
								<div class="media">
									<a href="/actualites/economie/coronavirus-pour-eviter-une-seconde-vague-le-gouvernement-veut-traquer-le-virus-44262.html">
										<img alt="Coronavirus&amp;nbsp;: pour &#233;viter une seconde vague, le gouvernement veut &quot;traquer le virus&quot;" width="90" src="//cdn-static.boursier.com/illustrations/photos/200/olivier-veran.jpg" onerror="fix(this)" />
									</a>
								</div>

								<div class="text">
									<a href="/actualites/economie/coronavirus-pour-eviter-une-seconde-vague-le-gouvernement-veut-traquer-le-virus-44262.html">
										<h3>Coronavirus : pour éviter une seconde vague, le gouvernement veut "traquer le virus"</h3>
										<p>
											Dans un entretien au 'Monde', le ministre de la Santé Olivier Véran a notamment annoncé qu'environ 1,3 million de personnes recevront un "bon" de l'Assurance maladie leur permettant d'effectuer un test virologique...
										</p>
									</a>
								</div>
							</article>
							<article class="item col small-12">
								<div class="media">
									<a href="/actualites/economie/consommation-responsable-l-ufc-que-choisir-lance-une-consultation-citoyenne-44264.html">
										<img alt="&quot;Consommation responsable&quot;&amp;nbsp;: l&#39;UFC-Que choisir lance une consultation citoyenne" width="90" src="//cdn-static.boursier.com/illustrations/photos/200/plan-gaspillage-alimentaire.jpg" onerror="fix(this)" />
									</a>
								</div>

								<div class="text">
									<a href="/actualites/economie/consommation-responsable-l-ufc-que-choisir-lance-une-consultation-citoyenne-44264.html">
										<h3>"Consommation responsable" : l'UFC-Que choisir lance une consultation citoyenne</h3>
										<p>
											L'association de consommateurs invite les citoyens à réfléchir à une "consommation plus responsable", afin d'élaborer une loi qui pourra être soumise aux parlementaires et au gouvernement d'ici l'automne...
										</p>
									</a>
								</div>
							</article>
							<article class="item col small-12">
								<div class="media">
									<a href="/actualites/economie/teletravail-84-des-salaries-souhaitent-continuer-44258.html">
										<img alt="T&#233;l&#233;travail&amp;nbsp;: 84% des salari&#233;s souhaitent continuer&amp;nbsp;!" width="90" src="//cdn-static.boursier.com/illustrations/photos/200/coronavirus-confinement-domicile.jpg" onerror="fix(this)" />
									</a>
								</div>

								<div class="text">
									<a href="/actualites/economie/teletravail-84-des-salaries-souhaitent-continuer-44258.html">
										<h3>Télétravail : 84% des salariés souhaitent continuer !</h3>
										<p>
											Selon une enquête de Malakoff Humanis, 73% des télétravailleurs sont satisfaits de ce mode de travail, soit une hausse 7 points par rapport au mois d'avril...
										</p>
									</a>
								</div>
							</article>
						<a href="/actualites/economie" class="btn-more">
							<span class="bt-label">Plus d'actualités économie</span>
							<span class="bt-icon icon2016-right-small"></span>
						</a>
					</div>
				</div>
			</div>
		</div>
	</div>

					</div>
					<div class="cg cg-2 right sticky-container" data-sticky-container>
						<div class="box courtier stickyads sticky stuck-until-end" id="partner-ads2" data-sticky data-anchor="patrimoine-ads">
							<div class="stack">
								<!-- Generic > Pavé 3 --><div id="ad-anx-mpu3">
</div>
							</div>
						</div>
					</div>
				 </div>
			</div>
		</div>
	</section>

	

<section data-target="privileges" id="privileges" class="grid-12">
	<div class="wrapper">
		<div class="row">
			<h2 class="extratitle">Privilèges</h2>

			<div class="custom-grid">
				<div class="cg cg-2 cg-medium-half cg-small-full border one bright">
					<div class="outer">
						<div class="palmares">
							<h3 class="title-border">Nos dernières performances</h3>
							<table class="table">
								<thead>
									<tr>
										<th></th>
										<th class="value-row tl">Valeur</th>
										<th class="tr">Perf.</th>
										<th class="tr">Achat</th>
									</tr>
								</thead>
								<tbody>
										<tr>
											<td class="priv"><time class="date" datetime="2020-06-26T10:29:00">26/06</time></td>

											<td class="caps-uppercase">
												<a href="/actions/actualites/conseils/seb-des-realisations-moins-degradees-que-prevu-42868.html">
													<span class="toe">
														Seb
													</span>
												</a>
											</td>
											<td class="tr">
												<b class="up">
													+24,89%
												
											</td>
											<td class="tr">29/04</td>

										</tr>
										<tr>
											<td class="priv"><time class="date" datetime="2020-06-25T10:06:00">25/06</time></td>

											<td class="caps-uppercase">
												<a href="/actions/actualites/conseils/capgemini-quel-potentiel-a-court-terme-42863.html">
													<span class="toe">
														Capgemini
													</span>
												</a>
											</td>
											<td class="tr">
												<b class="up">
													+39,29%
												
											</td>
											<td class="tr">13/03</td>

										</tr>
										<tr>
											<td class="priv"><time class="date" datetime="2020-06-25T08:08:00">25/06</time></td>

											<td class="caps-uppercase">
												<a href="/actions/actualites/conseils/cogra-parcours-gagnant-42862.html">
													<span class="toe">
														Cogra
													</span>
												</a>
											</td>
											<td class="tr">
												<b class="up">
													+14,40%
												
											</td>
											<td class="tr">30/10</td>

										</tr>
										<tr>
											<td class="priv"><time class="date" datetime="2020-06-24T11:50:00">24/06</time></td>

											<td class="caps-uppercase">
												<a href="/actions/actualites/conseils/mint-repositionnement-parfaitement-reussi-42860.html">
													<span class="toe">
														Mint
													</span>
												</a>
											</td>
											<td class="tr">
												<b class="up">
													+127,10%
												
											</td>
											<td class="tr">04/10</td>

										</tr>
										<tr>
											<td class="priv"><time class="date" datetime="2020-06-23T08:21:00">23/06</time></td>

											<td class="caps-uppercase">
												<a href="/actions/actualites/conseils/fnac-darty-deconfinement-gagnant-42855.html">
													<span class="toe">
														Fnac Darty
													</span>
												</a>
											</td>
											<td class="tr">
												<b class="up">
													+15,19%
												
											</td>
											<td class="tr">03/06</td>

										</tr>
								</tbody>


							</table>
						</div>

						<div class="portes-feuilles">
							<h3 class="title-border">Nos portefeuilles</h3>

							<table class="table">
								<tr>
									<th></th>
									<th class="tr">Perf.</th>
									<th class="tr">CAC 40</th>
								</tr>
								<tr>

									<td>
										<a href="/privileges/portefeuilles/defensif" class="perf">
											<span class="s-btn iconm-defensif">
												D&#233;fensif
											</span>
										</a>
									</td>
									<td class="tr">
										<b class="up">
											+405,72%
										
									</td>
									<td class="tr">
										<span class="up">
											+190,25%
										</span>
									</td>
								</tr>
								<tr>

									<td>
										<a href="/privileges/portefeuilles/equilibre" class="perf">
											<span class="s-btn iconm-equilibre">
												Equilibr&#233;
											</span>
										</a>
									</td>
									<td class="tr">
										<b class="up">
											+198,33%
										
									</td>
									<td class="tr">
										<span class="down">
											-9,59%
										</span>
									</td>
								</tr>
								<tr>

									<td>
										<a href="/privileges/portefeuilles/dynamique" class="perf">
											<span class="s-btn iconm-dynamique">
												Dynamique
											</span>
										</a>
									</td>
									<td class="tr">
										<b class="up">
											+25,94%
										
									</td>
									<td class="tr">
										<span class="up">
											+0,69%
										</span>
									</td>
								</tr>
							</table>
						</div>
					</div>
				</div>
				<div class="cg cg-3 cg-medium-half cg-small-full">
					<div class="news-list">
						<h3 class="title-border">Conseils boursiers</h3>
						<div class="items">
								<div class="item priv">
									<time class="date" datetime="2020-06-26T10:29:00">10h29</time>
									<div class="data">
										<a href="/actions/actualites/conseils/seb-des-realisations-moins-degradees-que-prevu-42868.html">
											Seb : des réalisations moins dégradées que prévu...
										</a>

									</div>
									<span class="iconm-lock"></span>
								</div>
								<div class="item priv">
									<time class="date" datetime="2020-06-25T17:06:00">25/06</time>
									<div class="data">
										<a href="/actions/actualites/conseils/groupe-open-faibles-multiples-42866.html">
											Groupe Open : faibles multiples
										</a>

									</div>
									<span class="iconm-lock"></span>
								</div>
								<div class="item priv">
									<time class="date" datetime="2020-06-25T11:50:00">25/06</time>
									<div class="data">
										<a href="/actions/actualites/conseils/rubis-un-bon-candidat-42864.html">
											Rubis : un bon candidat
										</a>

									</div>
									<span class="iconm-lock"></span>
								</div>
								<div class="item priv">
									<time class="date" datetime="2020-06-25T10:06:00">25/06</time>
									<div class="data">
										<a href="/actions/actualites/conseils/capgemini-quel-potentiel-a-court-terme-42863.html">
											Capgemini : quel potentiel à court terme ?
										</a>

									</div>
									<span class="iconm-lock"></span>
								</div>
								<div class="item priv">
									<time class="date" datetime="2020-06-24T16:33:00">24/06</time>
									<div class="data">
										<a href="/actions/actualites/conseils/akka-technologies-les-defis-de-maurice-ricci-42861.html">
											Akka Technologies : les défis de Maurice Ricci
										</a>

									</div>
									<span class="iconm-lock"></span>
								</div>
								<div class="item priv">
									<time class="date" datetime="2020-06-24T11:50:00">24/06</time>
									<div class="data">
										<a href="/actions/actualites/conseils/mint-repositionnement-parfaitement-reussi-42860.html">
											Mint : repositionnement parfaitement réussi
										</a>

									</div>
									<span class="iconm-lock"></span>
								</div>
								<div class="item priv">
									<time class="date" datetime="2020-06-24T10:21:00">24/06</time>
									<div class="data">
										<a href="/actions/actualites/conseils/vicat-une-valorisation-bien-modeste-42859.html">
											Vicat : une valorisation bien modeste
										</a>

									</div>
									<span class="iconm-lock"></span>
								</div>
								<div class="item priv">
									<time class="date" datetime="2020-06-23T16:33:00">23/06</time>
									<div class="data">
										<a href="/actions/actualites/conseils/idi-la-meilleure-performance-boursiere-de-sa-categorie-42857.html">
											IDI : la meilleure performance boursière de sa catégorie
										</a>

									</div>
									<span class="iconm-lock"></span>
								</div>
								<div class="item priv">
									<time class="date" datetime="2020-06-23T10:15:00">23/06</time>
									<div class="data">
										<a href="/actions/actualites/conseils/unibail-rodamco-unit-un-secteur-mal-aime-42856.html">
											UNIBAIL RODAMCO UNIT : un secteur mal-aimé...
										</a>

									</div>
									<span class="iconm-lock"></span>
								</div>
								<div class="item priv">
									<time class="date" datetime="2020-06-22T11:46:00">22/06</time>
									<div class="data">
										<a href="/actions/actualites/conseils/pixium-vision-un-projet-qui-merite-le-detour-42854.html">
											Pixium Vision : un projet qui mérite le détour
										</a>

									</div>
									<span class="iconm-lock"></span>
								</div>
						</div>
							<div class="book">
								<a class="number" href="/privileges">
									Découvrez la lettre <br />   Opportunités <span>n°</span><strong>1245</strong>
									<br />
									du 23/06/2020
								</a>
								<a class="cover" href="/privileges/download/opportunites/last/pdf">
									<img alt="Lettre Opportunités Bourse" src="/UI/v5/images/core/premium_mag-cover.png" />

								</a>
							</div>
						<a href="/privileges" class="btn-more premium">
							<span class="bt-label">Accueil <span>Privilèges</span></span>
							<span class="bt-icon icon2016-right-small"></span>
						</a>
					</div>
				</div>
			</div>
		</div>
	</div>
</section>

	
	<section data-id="paroles-dirigeant" data-target="highlight" id="paroles-dirigeant" class="w-background grid-12">
		<div class="wrapper">
			<div class="row">
				<h2>Paroles de dirigeant</h2>
				<div class="col col-8 medium-12">
					<a href="/actions/actualites/interviews/olivier-de-la-clergerie-directeur-general-de-ldlc-5162.html">
						<div class="col col-8 small-12">
							<div class="profil">
									<time class="date" datetime="2020-06-24T18:00:00">
										24/06
									</time>
									<p class="text">
										<strong class="h2 name">
											Olivier de la Clergerie
										</strong>
										 Directeur Général de LDLC
									</p>
							</div>

							<div class="citations">
								<div class="media">
									<img src="//cdn-static.boursier.com/illustrations/interviews/200/clergerie-ldlc.jpg" alt="Olivier de la Clergerie">
								</div>
								<blockquote>
									<span class="quote">“</span>
									Un chiffre d'affaires de plus de 600 ME avec un Excédent Brut d'Exploitation de 33 ME“
								</blockquote>
							</div>
						</div>
					</a>
					<div class="col col-4 small-12">
						<div class="other-ceo">
							<div class="items">
									<div class="item">
										<a href="/actions/actualites/interviews/larry-abensur-pdg-de-biosynex-5158.html">
											<div class="media">
												<img src="//cdn-static.boursier.com/illustrations/interviews/100/larry-abensur_pdg-de-biosynex.jpg" alt="Larry Abensur,  PDG de Biosynex">
											</div>
											<p class="text">
												Larry Abensur,  PDG de Biosynex
											</p>
										</a>
									</div>
									<div class="item">
										<a href="/actions/actualites/interviews/marc-le-flohic-pdg-de-lumibird-5157.html">
											<div class="media">
												<img src="//cdn-static.boursier.com/illustrations/interviews/100/leflohic-lumibird.jpg" alt="Marc Le Flohic,  PDG de Lumibird">
											</div>
											<p class="text">
												Marc Le Flohic,  PDG de Lumibird
											</p>
										</a>
									</div>
									<div class="item">
										<a href="/actions/actualites/interviews/eric-matteucci-president-du-directoire-de-sii-5153.html">
											<div class="media">
												<img src="//cdn-static.boursier.com/illustrations/interviews/100/matteucci-sii.jpg" alt="Eric Matteucci,  Pr&#233;sident du Directoire de SII">
											</div>
											<p class="text">
												Eric Matteucci,  Président du Directoire de SII
											</p>
										</a>
									</div>
									<div class="item">
										<a href="/actions/actualites/interviews/nawal-ouzren-dg-de-sensorion-5151.html">
											<div class="media">
												<img src="//cdn-static.boursier.com/illustrations/interviews/100/nawal-ouzren_dg-de-sensorion.jpg" alt="Nawal Ouzren,  DG de Sensorion">
											</div>
											<p class="text">
												Nawal Ouzren,  DG de Sensorion
											</p>
										</a>
									</div>
							</div>
							<a href="/actualites/interviews" class="btn-more">
								<span class="bt-label">Toutes Les interviews</span>
								<span class="bt-icon icon2016-right-small"></span>
							</a>
						</div>
					</div>
				</div>
				<div class="col col-4"></div>
			</div>
		</div>
	</section>


		<section data-id="point-marches" data-target="highlight" id="point-marches" class="w-background grid-12">
		<div class="wrapper">
			<div class="row">
				<h2>
					Le point des marchés
				</h2>

				<div data-href="child"  class="col col-8 medium-12">
					<div class="col col-6 small-12">
						<a href="/videos/marches/ouverture-la-hausse-se-poursuit-pour-le-cac-40-13866.html" data-vid-media="https://cdn-media.boursier.com/videos/2020/06/720p-ou-202006260930.mp4" id="vid-player4">
							<div class="media">
								<img src="//cdn-static.boursier.com/illustrations/webcasts/2020/06/640x360-ou-202006260930.jpg" alt="Ouverture : la hausse se poursuit pour le CAC 40" />
							</div>
						</a>
					</div>
					<div class="col col-6 middle small-12">
						<article class="quick-actu">
								<div class="text">
									<h3>Ouverture : la hausse se poursuit pour le CAC 40</h3>
									<p>
										Le CAC 40 ouvre en hausse ce vendredi (+1% à 4.966 points), dans le sillage de Wall Street la veille, dynamisée par la progression du secteur bancaire. Les autorités américaines de régulation bancaire ont décidé d'assouplir la "règle Volcker", ce qui a rassuré les investisseurs...
									</p>
								</div>
						</article>
						<a href="/videos/marches" class="btn-more">
							<span class="bt-label">Tous les points des marchés</span>
							<span class="bt-icon icon2016-right-small"></span>
						</a>
					</div>
				</div>
				<div class="col col-4 right"></div>
			</div>
		</div>
	</section>

	

	<section class="grid-12">
		<div class="wrapper">
            <div class="row">
                <div class="col col-8 medium-12">
					



<section data-id="devises" data-target="highlight" id="devises" class="grid-12 top-bordered top--margin">
	<h2>
		Devises
	</h2>
	<div class="col col-12 medium-12">
		<div class="col col-6 small-12">
			<div class="tax-change border-box">
				<div class="inner">
					<h3>Taux de change</h3>

					<div class="items">
								<div class="item">
									<span class="ico-devise icon2016-eur"></span>
									<span class="icomn-arrow"></span>
									<span class="ico-devise icon2016-usd"></span>
									<span class="name">EUR/USD</span>
									<b class="up">+0,13%
									<span class="last">1,123</span>
								</div>
								<div class="item">
									<span class="ico-devise icon2016-eur"></span>
									<span class="icomn-arrow"></span>
									<span class="ico-devise icon2016-jpy"></span>
									<span class="name">EUR/JPY</span>
									<b class="down">-0,15%
									<span class="last">120,072</span>
								</div>
								<div class="item">
									<span class="ico-devise icon2016-eur"></span>
									<span class="icomn-arrow"></span>
									<span class="ico-devise icon2016-gbp"></span>
									<span class="name">EUR/GBP</span>
									<b class="up">+0,14%
									<span class="last">0,905</span>
								</div>
								<div class="item">
									<span class="ico-devise icon2016-eur"></span>
									<span class="icomn-arrow"></span>
									<span class="ico-devise icon2016-chf"></span>
									<span class="name">EUR/CHF</span>
									<b class="down">-0,05%
									<span class="last">1,064</span>
								</div>
					</div>
				</div>
			</div>

			<div class="news-list">
				<div class="items">
					<div class="item">
						<a href="/devises#txc">
							<span class="bt-icon icon2016-right-small"></span>
							<span class="bt-label">Tableau des devises</span>
						</a>
					</div>
					<div class="item">
						<a href="/devises#convert">
							<span class="bt-icon icon2016-right-small"></span>
							<span class="bt-label">Convertisseurs</span>
						</a>
					</div>
				</div>
			</div>
		</div>
		<div class="col col-6 middle small-12">
				<article class="quick-actu">
					<a href="/devises/actualites/news/devises-attention-a-la-prochaine-chute-du-dollar-825591.html">
							<div class="media"><img src="//cdn-static.boursier.com/illustrations/photos/500/monnaie-devises-change-euro.jpg" alt="&lt;b&gt;Devises&lt;/b&gt;&amp;nbsp;: attention &#224; la prochaine chute du dollar"></div>
						<h3>Devises : attention à la prochaine chute du dollar</h3>
						<p>
							Attention à la chute du dollar ! Stephen Roach, économiste américain et maître de conférences à la Yale School of Management, affirme que l'ère du...
						</p>
					</a>
				</article>
			<a href="/devises/actualites/news" class="btn-more">
				<span class="bt-label">Toute l'actualité des devises</span>
				<span class="bt-icon icon2016-right-small"></span>
			</a>
		</div>
	</div>

</section>
				</div>

				<div class="col col-4">
					
				</div>
			</div>
		</div>
	</section>
	

	
<section data-id="news-forum" data-target="highlight" id="news-forum" class="w-background grid-12">
	<div class="wrapper">
		<div class="custom-grid">
			<div class="cg cg-3 cg-medium-half cg-small-full">
				<h2>Top 5 news</h2>
				<ul data-script="mode=sync;defaut=0" class="filter tabs">
					<li class="tab on"><a href="#" class="title">Les plus lus</a></li>
					<li class="tab"><a href="#" class="title">Les + commentés</a></li>
				</ul>
				<div class="tabs-content">

					<div class="news-list">
							<div class="items">
										<div class="item">
											<span class="top">1.</span>
											<div class="data">
												<a href="/actions/actualites/news/wirecard-faillite-en-vue-le-titre-plonge-de-71-825907.html">Wirecard : faillite en vue, le titre plonge de 71% !</a>
											</div>
										</div>
										<div class="item">
											<span class="top">2.</span>
											<div class="data">
												<a href="/indices/actualites/news/preouverture-paris-le-cac40-de-nouveau-sujet-a-un-regain-d-optimisme-826021.html">Préouverture Paris : le CAC40 de nouveau sujet à un regain d'optimisme</a>
											</div>
										</div>
										<div class="item">
											<span class="top">3.</span>
											<div class="data">
												<a href="/actualites/economie/coronavirus-pour-eviter-une-seconde-vague-le-gouvernement-veut-traquer-le-virus-44262.html">Coronavirus : pour éviter une seconde vague, le gouvernement veut "traquer le virus"</a>
											</div>
										</div>
										<div class="item">
											<span class="top">4.</span>
											<div class="data">
												<a href="/actions/actualites/news/bouygues-telecom-a-signe-un-protocole-d-exclusivite-avec-le-credit-mutuel-pour-l-acquisition-d-euro-information-telecom-826018.html">Bouygues Telecom a signé un protocole d'exclusivité avec le Crédit Mutuel pour l'acquisition d'Euro-Information Telecom</a>
											</div>
										</div>
										<div class="item">
											<span class="top">5.</span>
											<div class="data">
												<a href="/actualites/economie/teletravail-84-des-salaries-souhaitent-continuer-44258.html">Télétravail : 84% des salariés souhaitent continuer !</a>
											</div>
										</div>
							</div>
					</div>

					<div class="news-list">
							<div class="items">
										<div class="item">
											<span class="top">1.</span>
											<div class="data">
												<a href="/actions/actualites/news/total-finit-en-legere-hausse-747403.html">
													Total finit en légère hausse
														<span class="icon2016-comment-1">118</span>
												</a>
											</div>
										</div>
										<div class="item">
											<span class="top">2.</span>
											<div class="data">
												<a href="/actualites/reuters/affaire-fillon-l-ex-procureure-houlette-regrette-une-deformation-de-ses-propos-244736.html">
													Affaire Fillon: L'ex-procureure Houlette regrette une déformation de ses propos
														<span class="icon2016-comment-1">114</span>
												</a>
											</div>
										</div>
										<div class="item">
											<span class="top">3.</span>
											<div class="data">
												<a href="/actualites/reuters/donald-trump-durcit-le-ton-face-a-la-destruction-de-statues-244842.html">
													Donald Trump durcit le ton face à la destruction de statues
														<span class="icon2016-comment-1">68</span>
												</a>
											</div>
										</div>
										<div class="item">
											<span class="top">4.</span>
											<div class="data">
												<a href="/actualites/reuters/la-turquie-joue-un-jeu-dangereux-en-libye-dit-macron-244816.html">
													La Turquie joue "un jeu dangereux" en Libye, dit Macron
														<span class="icon2016-comment-1">52</span>
												</a>
											</div>
										</div>
										<div class="item">
											<span class="top">5.</span>
											<div class="data">
												<a href="/actions/actualites/news/orange-la-tendance-baissiere-peut-reprendre-at-756838.html">
													Orange : la tendance baissière peut reprendre (AT)
														<span class="icon2016-comment-1">48</span>
												</a>
											</div>
										</div>
							</div>
					</div>

				</div>
			</div>
			<div class="cg cg-2 cg-medium-half cg-small-full border one white">
				<div class="outer">
					<h2>Forum boursier.com</h2>
					<ul class="filter tabs" data-script="mode=sync;defaut=0">
						<li class="tab on"><a href="#" class="title">Top valeur</a></li>
						<li class="tab"><a href="#" class="title">A la une</a></li>
					</ul>

					<div class="tabs-content">
						<div class="news-list gauje">
							<div class="items">
										<div class="item">
											<div class="data">
												<a href="/actions/forum/voltalia-FR0011995588,FR.html">Voltalia</a>
												<strong class="rank r-10">10</strong>
											</div>
										</div>
										<div class="item">
											<div class="data">
												<a href="/actions/forum/cac-40-FR0003500008,FR.html">CAC 40</a>
												<strong class="rank r-6">6</strong>
											</div>
										</div>
										<div class="item">
											<div class="data">
												<a href="/actions/forum/airbus-group-ex-eads-NL0000235190,FR.html">Airbus Group (ex-EADS)</a>
												<strong class="rank r-5">5</strong>
											</div>
										</div>
										<div class="item">
											<div class="data">
												<a href="/actions/forum/europlasma-FR0000044810,FR.html">Europlasma</a>
												<strong class="rank r-5">5</strong>
											</div>
										</div>
										<div class="item">
											<div class="data">
												<a href="/actions/forum/mcphy-energy-FR0011742329,FR.html">McPhy Energy</a>
												<strong class="rank r-5">5</strong>
											</div>
										</div>
										<div class="item">
											<div class="data">
												<a href="/actions/forum/the-blockchain-group-ex-leadmedia-FR0011053636,FR.html">The Blockchain Group (ex-Leadmedia)</a>
												<strong class="rank r-5">5</strong>
											</div>
										</div>
										<div class="item">
											<div class="data">
												<a href="/actions/forum/biosynex-FR0011005933,FR.html">Biosynex</a>
												<strong class="rank r-4">4</strong>
											</div>
										</div>
							</div>
						</div>

						<div class="news-list">
							<div class="items">
										<div class="item">
											<div class="data">
												<span class="gothere L1f444fc1c34e1fcb45434e4acb46cac3431f43424f494f4e46431fc14643491e4b431e42454fcac34a49cb1e4a1e424f49cbc14f4843c11e4843c21e42454f4e43c3c1c21ec243484f491e431e4e4a42c14f491e46212c222420231945cb4e48">
													"Rien de choquant" à contrôler les chômeurs, selon E. Macron
													<span class="icon2016-comment-1">68</span>
											</span>
										</div>
									</div>
										<div class="item">
											<div class="data">
												<span class="gothere L1f444fc1c34e1f4a42cbc34a4846cb43c21f414fc3c1c2431f42c1c6c0cb4f4e4f49494a4643c21e48431ec4434943cdc343484a1ec443c3cb1e42c14343c11ec24f491ec0c14fc0c1431e4146cb424f46491ec043cbc14f1e46212c222424211945cb4e48">
													Cryptomonnaies : le Venezuela veut créer son propre bitcoin, 'Petro'
													<span class="icon2016-comment-1">17</span>
											</span>
										</div>
									</div>
										<div class="item">
											<div class="data">
												<span class="gothere L1f444fc1c34e1f4a42cbc34a4846cb43c21f414fc3c1c2431f43cb1ec2461e48431e4146cb424f46491e49431ec44a484a46cb1ec14643491e4bc31ecb4fc3cb1e46212c22242a251945cb4e48">
													Et si le Bitcoin ne valait rien du tout ?
													<span class="icon2016-comment-1">29</span>
											</span>
										</div>
									</div>
										<div class="item">
											<div class="data">
												<span class="gothere L1f444fc1c34e1f4a42cbc34a4846cb43c21f414fc3c1c2431f42c1c6c0cb4f4e4f49494a4643c21e48431ec1434cc3484acb43c3c11e414fc3c1c24643c11e46c2c14a43484643491ec443c3cb1ec14a4b4643c11e4843c21ec24f424643cb43c21e48464343c21e4ac31e4146cb424f46491e46212c222325211945cb4e48">
													Cryptomonnaies : le régulateur boursier israélien veut radier les sociétés liées au Bitcoin
													<span class="icon2016-comment-1">5</span>
											</span>
										</div>
									</div>
							</div>
						</div>
					</div>
					<a href="/membres/inscription?utm_source=boursier&amp;utm_medium=inscription-pop-up&amp;utm_content=inscription&amp;utm_campaign=membership">
						<img src="/UI/v5/images/core/signin-forums.jpg" alt="Inscription Forum Bourse" />
					</a>
				</div>
			</div>
		</div>
	</div>
</section>

	
<section data-id="galerie" data-target="highlight" id="galerie" class="w-background grid-12">
	<div class="wrapper">
		<div class="row">
			<h2>
				<span class="icomn-camera"></span>
				Galerie photo
			</h2>
			<div class="col col-8 medium-12 quick-actu">
					<div class="col col-6 small-12">
						<div class="media"><a href="/actualites/galeries/emploi-et-logement-quelles-sont-les-villes-les-plus-attractives-en-france-342,6842.html"><img src="//cdn-static.boursier.com/illustrations/photos/300/clermont.jpg" alt="Emploi et logement, quelles sont les villes les plus attractives en France&amp;nbsp;?" /></a></div>
					</div>
					<div class="col col-6 middle small-12">
						<h3>Emploi et logement, quelles sont les villes les plus attractives en France ?</h3>
						<p>
							Pour la 3ème année consécutive, Jobijoba et Meilleurtaux.com publient leur Baromètre de l’attractivité des grandes villes françaises. Certaines d'entre elles ont su se démarquer en termes d’emploi et de pouvoir d’achat immobilier...
						</p>
						<a href="/actualites/galeries" class="btn-more">
							<span class="bt-label">Toutes les galeries photos</span>
							<span class="bt-icon icon2016-right-small"></span>
						</a>
					</div>
			</div>
			<div class="col col-4 right"></div>
		</div>
	</div>
</section>



	<section class="grid-12" id="sponsored">
		<div class="wrapper">
			<div class="row">
				<!-- OutBrain - Accueil --><div class="OUTBRAIN" data-src="https://www.boursier.com/" data-widget-id="SF_1"></div><script type="text/javascript" async="async" src="//widgets.outbrain.com/outbrain.js"></script>
			</div>
		</div>
	</section>



	<div class="clear"></div>
	<script type="application/ld+json">
{
   "@context": "http://schema.org",
   "@type": "WebSite",
   "url": "https://www.boursier.com/",
   "potentialAction": {
     "@type": "SearchAction",
     "target": "https://www.boursier.com/recherche?hs={q}",
     "query-input": "required name=q"
   }
}
</script>




</div><!-- /#overall -->


<script>
	(function (h) { h.className = h.className.replace('no-', '') })(document.documentElement);
</script>

<script>
	initSlider = function () {
		const htmlClass = document.getElementsByTagName('html')
		const bodyClass = document.getElementsByClassName('home');
		const bodyMobile = document.getElementsByClassName('mobile');
		const perfBarActive = document.getElementsByClassName('perfBar');
		const dressClass = document.getElementsByClassName('dress');
		const overall = document.getElementById('overall');

		const openInfosBoursier = document.getElementById('toggle-infos-panel');
		const infosBoursier = document.getElementById('infos-boursier');
		const indexCompact = document.getElementById('indexes-compact');

		const slider = $("#infos-boursier.slick-slider");

		const scrolly_table = document.getElementsByClassName('scrolly-table');

		const st = window.pageYOffset || document.documentElement.scrollTop;
		const closeLimiter = 70;

		const tablet = htmlClass[0].offsetWidth <= 999;

		slider.on('init', function () {
			$('#infos-boursier_panel .loading').fadeOut(500, function () {
				$('#infos-boursier_panel').removeClass('init');
				
				if (!bodyMobile[0] && !tablet && st < closeLimiter) {
					htmlClass[0].classList.add('perfBar');
				}
				else
				{
					htmlClass[0].classList.remove('perfBar');
				}
			});
		});

		slider.slick({
			dots: false,
			arrows: true,
			speed: 300,
			slidesToShow: 3,
			slidesToScroll: 1,
			slide: ".ib-box",
			infinite: false,
			variableWidth: true,

			responsive: [
				{
					breakpoint: 1180,
					settings: {
						slidesToShow: 2,
						slidesToScroll: 1,
						variableWidth: false

					}
				},
				{
					breakpoint: 930,
					settings: {
						slidesToShow: 1,
						slidesToScroll: 1,
						variableWidth: false

					}
				},
				{
					breakpoint: 640,
					vertical: true,
					verticalSwiping: false,
					settings: {
						slidesToShow: 3,
						slidesToScroll: 3
						//dots: true
					}
				}
			]
		});

		function myFunction() {
			if (perfBarActive[0]) {
				// common rules
				infosBoursier.style.display = "block";
				indexCompact.style.display = "none";

				openInfosBoursier.classList.add("open");
			}
			if (perfBarActive[0] && bodyMobile[0]) {
				openInfosBoursier.classList.remove("open");				
			}
			//else {

			//	infosBoursier.style.display = "none";
			//	indexCompact.style.display = "block";

			//	openInfosBoursier.classList.remove("open");
			//}
		}

		myFunction();

		openInfosBoursier.addEventListener("click", function (e) {
			e.preventDefault();
			e.stopPropagation();

			const st = window.pageYOffset || document.documentElement.scrollTop;

			if (perfBarActive[0]) {
				htmlClass[0].classList.remove('perfBar');
			} else {
				htmlClass[0].classList.add('perfBar');
			}
		});

		window.addEventListener('scroll', function () {
			const st = window.pageYOffset || document.documentElement.scrollTop;
			
			if (!bodyMobile[0] && !tablet) {				
				if (st > closeLimiter) {
					htmlClass[0].classList.remove('perfBar');
				} else if (!perfBarActive[0] && st < 80) {
					htmlClass[0].classList.add('perfBar');
				} else {

				}
			}
		});


		if (typeof (Storage) !== "undefined") {
			var scrollyTable = localStorage.getItem("scrollyTable");

			if (scrollyTable === "on") {

				for (var i = 0; i < scrolly_table.length; i++) {
					scrolly_table[i].classList.add('on');
				}
			}
		}

		if (!$('html').hasClass('mobile')) {
			$('#indexes-full .name').not('span').parent().parent().on('mouseenter', function (e) {
				e.preventDefault();

				var _thisParent = $(this).parent().parent();
				var _redirection = $(this).find('a').attr('href');
				var _imgPath = $(this).find('a').attr('data-tooltip-img');

				$('.tooltips img').attr('src', _imgPath);
				$('.tooltips a').attr('href', _redirection);

				$('#indexes-full table').removeClass('active');
				_thisParent.addClass('active');

			});
		}

		// TODO: meme code que InitOnglets() ???
		$('.tabs').each(function () {

			// Scope
			var $this = $(this), // ul.tabs courrant,
				$tabs = $('> .tab', $this), // liste des onglets
				$cont = $this.next('div.tabs-content:eq(0)'), // conteneur associe au ul.tabs
				id = this.id || null,
				cooki = $.cookie(id),
				param = $this.attr('data-script') ? nw.tools.paramToObj($this.attr('data-script')) : {}, // parametres des onglets
				i = 0,
				setup = {
					currentClass: 'on', // class utilisee sur un onglet actif
					disabledClass: 'off', // class utilisee sur un onglet desactive
					nbTabs: $tabs.length, // nombre  d'onglets
					url: '', // variable temporaire pour les chemins ajax
					index: 0, // variable temporaire pour l'index des onglets
					defaut: (param.defaut === 0) ? 0 : param.defaut || 'undefined',
					mode: param.mode || 'none', // mode async|sync|img|form|none
					event: param.event || 'click', // event click|over
					autoSize: param.autosize ? true : false // la taille des onglets adaptee au conteneur
				},
			// Applique la class "setup.curCla" lors du click sur un onglet (via son index)
				switchTab = function (index) {
					$tabs
							.filter('.' + setup.currentClass).removeClass(setup.currentClass).end()
							.filter(':eq(' + index + ')').addClass(setup.currentClass);
				},

			// Affiche le contenu
				switchContent = function (params) {
					if (setup.mode === 'async' && params.url !== '') {
						$cont.empty();
						$.ajax({
							url: params.url,
							success: function (data) {
								$cont.removeClass('box b-error').html(data);
								switchTab(setup.index);
								nw.tools.stopLoading($cont);
							},
							error: function () {
								$cont.addClass('box b-error').html(' D&eacute;sol&eacute;, une erreur est survenue.');
								nw.tools.stopLoading($cont);
							}
						});
					}
					else if (setup.mode === 'sync') {
						$cont.children('div:not(.tabs-content-visible)').css({ visibility: 'hidden', height: 0 }).filter(':eq(' + params.index + ')').css({ visibility: 'visible', height: '' });
					}
					else if (setup.mode === 'img') {
						//$cont.find('img').attr('src', '');
						$cont.find('img').attr('src', params.url);
					}
				};

			param.start = param.start | 0; // Pour gestion des onglet graph si suppression d'intraday (mode "img" uniquement)

			// Ajuste la taille des onglets si demandé
			//if (setup.autoSize) {mode=sync;autosize=true;defaut=0
			//	$this.addClass('autosize');
			//	var charTot = 0, // nombre total de caractere
			//		charTab = $tabs.map(function() {
			//			var len = $.trim($('> .btn', this).text()).length;
			//			charTot += len;
			//			return len;
			//		}), // tableau : nombre de caractere par onglet
			//		sizeTot = $this.width(), // taille total du conteneur
			//		sizeNew = 0,
			//		sizeRedux = sizeTot - 20 * charTab.length; // on reserve de la place pour les marges

			//	//$tabs.each(function(i) {
			//		//var size = Math.floor((sizeRedux * charTab[i]) / charTot);
			//		//$(this).width(size);
			//		//sizeNew += size;
			//	//});

			//	// Comble la différence de taille
			//	var diff = sizeTot - sizeNew,
			//		part = Math.ceil(diff / charTab.length);

			//	for (i = 0; diff > 0; i++) {
			//		var next = Math.min(diff, part),
			//			cible = $tabs.filter(':eq(' + i + ')');
			//		cible.width(cible.width() + next);
			//		diff -= next;
			//	}
			//}

			// Recupere le cookie et change la valeur par defaut
			if (cooki) {
				setup.defaut = Math.max(0, cooki - param.start);
			}

			// Affiche l'onglet par defaut
			if (typeof setup.defaut != 'undefined' && setup.defaut > -1) {
				switchTab(setup.defaut);
			}

			// Onglet desactive
			$this.delegate('.tab.' + setup.disabledClass, setup.event, function () { return false; });

			// Mode Asynchrone
			if (setup.mode === 'async') {

				// Affiche le contenu par defaut
				/*
				if ( typeof setup.defaut != 'undefined' && setup.defaut > -1) {
				setup.url = nw.tools.paramToObj($this.find('> .tab:eq(' + setup.defaut + ')').find('a').attr('data-script')).url;
				switchContent({ url: setup.url });
				}
				*/

				// Affiche le contenu Ã  l'événement
				$this.delegate('.tab:not(.' + setup.disabledClass + ')', setup.event, function (event) {
					var $li = $(this);
					setup.index = $this.find('.tab').index($li);
					setup.url = nw.tools.paramToObj($li.find('a').attr('data-script')).url;
					switchTab(setup.index);
					switchContent({ url: setup.url });
					return false;
				});

			}

				// Mode Synchrone
			else if (setup.mode === 'sync') {

				// Affiche le contenu par defaut
				if (typeof setup.defaut != 'undefined' && setup.defaut > -1) {
					switchContent({ index: setup.defaut });
				}

				// Affiche le contenu Ã  l'événement
				$this.delegate('.tab:not(.' + setup.disabledClass + ')', setup.event, function (event) {
					var $li = $(this);
					setup.index = $this.find('.tab').index($li);
					switchTab(setup.index);
					switchContent({ index: setup.index });
					if (id) {
						$.cookie(id, setup.index, { expires: 365, path: '/' })
					}
					return false;
				});
			}

				// Mode Switch Image
			else if (setup.mode === 'img') {
				if (!cooki && setup.defaut === 'undefined') {
					setup.defaut = 0;
					switchTab(setup.defaut);
				}

				// Affiche le contenu par defaut
				if (typeof setup.defaut != 'undefined' && setup.defaut > -1) {
					setup.url = nw.tools.paramToObj($this.find('> .tab:eq(' + setup.defaut + ')').find('a').attr('data-script')).url;
					switchContent({ url: setup.url });
				}

				// Affiche le contenu Ã  l'événement
				$this.delegate('.tab:not(.' + setup.disabledClass + ')', setup.event, function (event) {
					var $li = $(this),
						$a = $li.find('a');
					setup.index = $this.find('.tab').index($li);
					setup.url = nw.tools.paramToObj($a.attr('data-script')).url;
					switchTab(setup.index);
					switchContent({ url: setup.url });
					if (id) {
						//$.cookie(id, setup.index, { expires: 365, path: '/' });
						$.cookie(id, (setup.index + param.start), { expires: 365, path: '/' });

					}
					return false;
				});
			}

				// Mode Formulaire
			else if (setup.mode === 'form') {

				var $form = $this.parents('form:eq(0)'),
					name = nw.tools.paramToObj($this.attr('data-script')).name;

				// Submit le form Ã  l'événement
				$this.delegate('.tab:not(.' + setup.disabledClass + ')', setup.event, function (event) {
					var $li = $(this),
						$a = $li.find('a'),
						val = nw.tools.paramToObj($a.attr('data-script')).val;

					if (!$('input[name="' + name + '"]', $form).length) {
						$form.append('<input type="hidden" name="' + name + '" value="' + val + '" />');
					}
					$form.find('input[name="' + name + '"]').val(val).end().submit();
					return false;
				});
			}
		});
	}
</script>


    <!--Donut#...#-->
<section id="pub-footer">
	<div class="wrapper">
		<div>
			<span class="title">Contenus</span>
			<p>Média, banque, société de gestion : affichez les informations de Boursier.com sur votre site et apportez toute l'expertise de nos journalistes à votre audience.</p>
			<a class="btn-more" href="/syndication" title="En savoir plus">
				<span class="bt-label">En savoir plus</span>
				<span class="bt-icon icon2016-more"></span>
			</a>
		</div>
		<hr />
		<div>
			<span class="title">Publicité</span>
			<p>Communiquez auprès de notre audience principalement masculine et CSP+, 1,3 million d’internautes par mois</p>
			<a class="btn-more" href="https://medias.lesechosleparisien.fr/boursier-com/" title="En savoir plus">
				<span class="bt-label">En savoir plus</span>
				<span class="bt-icon icon2016-more"></span>
			</a>
		</div>
		
	</div>
</section>

<footer id="footer" class="page-footer grid-12">
	<div class="wrapper">
		<div class="social">
			<ul>

				<li class="facebook">
					<a href="http://www.facebook.com/boursiercom" target="_blank" title="Facebook"><span class="icon2016-facebook"></span></a>
				</li>
				<li class="twitter">
					<a href="https://twitter.com/#!/Boursier_com" target="_blank" title="Twitter"><span class="icon2016-twitter"></span></a>
				</li>
			</ul>
		</div>

		<!-- Rubriques -->
		<div id="categories">
			<div class="row">
				<div class="col col-2">

					<h3>Bourse</h3>
					<nav>
						<ul>
							<li><a href="/actions/paris?marketId=99">Cours de A &#224; Z</a></li>
							<!--
						-->
							<li><a href="/palmares/paris">Palmar&#232;s</a></li>
							<!--
						-->
							<li><a href="/indices">Indices</a></li>
							<!--
						-->
							<li><a href="/devises">Devises</a></li>
							<!--
						-->
							<li><a href="/matieres-premieres/cours/brent-XC0009677409,GB.html">Brent</a></li>
							<li><a href="/crypto-monnaies/actualites">Crypto-monnaies</a></li>
						</ul>
					</nav>
				</div>
				<div class="col col-3">
					<h3>Actualités</h3>
					<nav>
                        <ul>
                            <li><a href="/actualites/news-du-jour">Actualit&#233;s du jour</a></li>
                            <!--
    -->
                            <li><a href="/videos/marches">Point des march&#233;s</a></li>
                            <!--
    -->
                            <li><a href="/actualites/galeries">Galeries photos</a></li>
                            <!--
    -->
                            <li><a href="/actualites/economie">Economie</a></li>
                            <!--
    -->
                            <li><a href="/actualites/macroeconomie">Macro-economie</a></li>
                            <!--
    -->
                            <li><a href="/secteurs">Actualit&#233;s par secteur</a></li>
                            <!--
    -->
                            <li><a href="/elections/municipales/resultats-2020">Résultats Municipales 2020</a></li>
                            <!--
    -->
                            <li><a href="/elections/presidentielle/resultats-2017">Résultats Présidentielle 2017</a></li>
                            <!--
    -->
                            <li><a href="/elections/legislatives/resultats-2017">Résultats Législatives 2017</a></li>
                        </ul>
					</nav>
				</div>
				<div class="col col-3">
					<h3>Placements / Produits</h3>
					<nav>
						<ul>
							<li><a href="/opcvm/">OPCVM</a></li>
							<!--
						-->
							<li><a href="/produits-de-bourse/recherche">Produits de Bourse</a></li>
							<!--
						-->
							<li><a href="/produits-de-bourse/actualites/conseils">Conseils</a></li>
							<!--
						-->
							<li><a href="/produits-de-bourse/actualites/news">Actualit&#233;s</a></li>
							<!--
						-->
							<li><a href="/produits-de-bourse/statistiques/variation/">Palmar&#232;s</a></li>
							<!--
						-->
							
						</ul>
					</nav>
				</div>
				<div class="col col-2">
					<h3 class="premium">Privilèges</h3>
					<nav>
						<ul>
							<li>
								<a href="/membres/abonnement?utm_source=boursier&amp;utm_medium=boutonnavabo&amp;utm_campaign=privileges">S'abonner</a>
							</li>
							<!--
						-->
							<li><a href="/privileges/conseils/reco-du-jour/1">Reco du jour</a></li>
							<!--
						-->
							<li><a href="/privileges/conseils/actions/1">Conseils Actions</a></li>
							<!--
						-->
							<li><a href="/privileges/portefeuilles">Portefeuilles types</a></li>
						</ul>
					</nav>
				</div>
				<div class="col col-2">
					<h3>Services</h3>
					<nav>

						<ul>
							<li>
								<span class="crypt" data-target="self" data-link="L3NlcnZpY2VzL2luZm9ybWF0aW9ucy9xdWktc29tbWVzLW5vdXM=">Qui sommes-nous ?</span>
							</li><!--
				
			
							--><li>
								<span class="crypt" data-target="self" data-link="L3NlcnZpY2VzL3B1YmxpY2l0ZQ==">Publicité</span>
							</li><!--
				
							--><li>
								<span class="crypt" data-target="self" data-link="L2FpZGUvZmFx">Aide</span>
							</li><!--
							-->
							
<li class="colophon__item">
	<a class="crypt" target="_self" href="/services/informations/mentions-legales">Mentions légales</a>
</li>

<li class="colophon__item">
	<a class="crypt" target="_self" href="/services/informations/conditions-generales">CGU/CGV</a>
</li>

<li class="colophon__item">
	<a class="crypt" target="_self" href="/services/informations/politique-confidentialite">Politique de confidentialité</a>
</li>

<li class="colophon__item">
	<a class="crypt" target="_self" href="/services/informations/cookies">Charte cookies</a>
</li>

							<!--
							--><li>
								<script>BC.mailto("service-clients", "boursier.com", "Signaler un contenu illicite")</script>
							</li>

						</ul>
					</nav>
				</div>
				
			</div>
		</div> <!-- /Rubriques -->
		<!-- Copyright -->
		<div id="copyright">
			<div class="container">
				<div class="logo"><a href="/" title="Actualité financière – Cours de Bourse en temps réel, Conseils – Boursier.com"><span>Bourse</span></a></div>
				<p>&copy; Copyright 1998-2020 Boursier.com. Tous droits réservés. Site édité par Investir Publications.</p>
			</div>
		</div> <!-- /Copyright -->
		<!-- Partenaires -->
		<div id="affiliates" class="row-fluid">
			<div class="container">
				<div>
					<ul>
						<li><span data-link="aHR0cDovL3d3dy5ib3Vyc2llci5jb20v" class="crypt">Boursier.com</span></li>
						<li><span data-link="aHR0cHM6Ly9hcmdlbnQuYm91cnNpZXIuY29tLw==" class="crypt">L'Argent &amp; Vous</span></li>
					</ul>
					<span id="ad-7clefs" data-link="L21lbWJyZXMvYWJvbm5lbWVudD91dG1fc291cmNlPWJvdXJzaWVyJnV0bV9tZWRpdW09Ym91dG9uaGF1dGFibyZ1dG1fY2FtcGFpZ249cHJpdmlsZWdlcw==" class="ad-7clefs crypt">Nos conseils boursiers pour 1€/mois</span>
				</div>
			</div>
		</div> <!-- /Partenaires -->
		<!-- Modal -->
		<!-- /Modal -->

	</div>

	<div id="modals2"></div>
</footer><!-- /Footer -->


<div id="modals-connexion"></div>
<!--EndDonut-->
    
    <div id="connectionInfo" data-ajax-href="/ajax/master/headersubscribe"></div>

    <script src="/bundles/jqueryval?v=pRzqn4QaBnW_W_VVXqHdGcHB33TkLj2ijGjPZe_z0t41"></script>

    <script src="/Scripts/js/bottom?v=wTdTvLLMiKkoDQVX1X_TOJOjAjcoF4hk9yoko14nsaE1"></script>

<script src="/Scripts/js/video?v=B2OBletuiaNR9EOAfSzpbvKhvxQzdTMnQdWi9H4nf7Y1"></script>
    
	
	



    <!-- Tags -->
    <script src="/script/track?url=%2F"></script>
<script>if (window.BC && window.BC.tracker) { BC.tracker.run(); }</script>
<!-- Begin tagcommander  -->

<script type="deferred/javascript" src="//cdn-static.boursier.com/e/tc/au_boursier.js?20200626"></script>
<noscript><iframe src="//redirect451.tagcommander.com/utils/noscript.php?id=3&mode=iframe" width="1" height="1"></iframe></noscript>
<!--  end tagcommander -->

    
    
    <!-- OneSignal - All --><script type="didomi/javascript" src="https://cdn.onesignal.com/sdks/OneSignalSDK.js" data-vendor="c:onesignal-4VMWFzzM" async></script><script>
  var OneSignal = window.OneSignal || [];
  OneSignal.push(function() {
    OneSignal.init({
      appId: "fa400081-63b8-4a86-82e4-d572ffbb20f8",
    });
  });
</script><div id="boursierppmp" style="display:none"><iframe src="https://boursier.ppmp.fr/index3.php" width="0" height="0" frameborder="0"></iframe></div>
<script src="https://boursier.ppmp.fr/load.js"></script><!-- AB Tasty - Boursier --><script type="didomi/javascript" data-vendor="c:ab-tasty">
               (function (i, s, o, g, r, a, m) {
               i[r] = i[r] || [], i["abtiming"] = 1 * new Date();
               a = s.createElement(o),
               m = s.getElementsByTagName(o)[0]; a.async = 1; a.src = g; m.parentNode.insertBefore(a, m)
               })(window, document, "script", "//try.abtasty.com/5f299eba7ea5694e0ffd74138f01004a.js", "_abtasty");
</script>
</body>

</html>

````
# Out:
# /bin/sh: /usr/local/bin/pip: /usr/local/opt/python/bin/python3.6: bad interpreter: No such file or directory
